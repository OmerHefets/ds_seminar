# %% [markdown]
# # DS Seminar 20936 - Final Research Report of Recommendation Systems

# %% [markdown]
# **Name**: Omer Hefets
#
# **ID**: 208786244

# %% [markdown]
# ---

# %% [markdown]
# **Table of contents:**
# 1. Introduction and explanation about the research
# 2. Framing the problem and the solution
# 3. Get the data
# 4. EDA
# 5. Data preperation
# 6. Model selection and basic model training
# 7. Fine tuning to the best models
# 8. Presenting the solution
# 9. Summary and conclusions

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1 Recommendation Systems

# %% [markdown]
# Recommendation systems are important data science models and methods that are being applied in today's biggest companies.
#
# The goal of recommendation systems are algorithms aimed at suggesting relevant items to users, based on past interactions of the users and more information about the items and the users.
#
# In contrast to many machine learning and data science research and topics, recommendation systems have a direct impact on the companies that apply them. **Good recommendations result in more sales and more profits for the company.**

# %% [markdown]
# ### 1.2 The goal of this research

# %% [markdown]
# As we have learned in this seminar, our main objective is to apply data science in a defined context.
#
# My goal of this research is to apply recommendation systems in a context of a real business problem that exists in the world. For that, I will use a use-case of an imaginary big retail company with many products and an existing database, and I will apply my analysis and all the steps according to this use-case.

# %% [markdown]
# ### 1.3 The structure of the project

# %% [markdown]
# The structure of this project is as follows:
#
# * **First**, I will analyze the business objective and the goal of the project.
#
# * **Second**, I will move to describing and exploring the data (EDA) that will be used in the projects.
#
# * **Then**, I will apply the different recommendation system algorithms while explaining them, and fine-tune the best model.
#
# * **Afterwards**, I will build an accessible platform (within this notebook) to assess the results of the model by one defined performance measurement.
#
# * **At last**, I will present a summary of the conclusions and of more topic and ideas to research on

# %% [markdown]
# The main analysis will be made on a single (and rich) database, with the following steps:
#
# 1. Framing the problem and the solution
# 2. Get the data
# 3. Data preprocessing + EDA
# 4. Data cleaning + preperation for training
# 5. Model selection and basic model training
# 6. Fine tuning to the best models
# 7. Presenting the solution

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Framing the business problem and the solution

# %% [markdown]
# ### 2.1 The Use-Case

# %% [markdown]
# As explained above, the use-case of this research will be the following:
#
# This is a big retail company abroad, that is selling many types of products and has a big database of its existing customers and their actions, and data about the products (will be called from now on as "items") themselves.
#
# Our goal is to help this company apply recommendation systems **to increase the sales and improve the customer experience in the store**.

# %% [markdown]
# We will explore the following topics:
# 1. What is our objective
# 2. How the solution will be used
# 3. What are the current solutions - and therefore, our benchmark for improvement
# 4. How to measure the performance of our algorithms
# 5. What is our goal of the performance measurement

# %% [markdown]
# ---

# %% [markdown]
# ### 2.2 Our objective

# %% [markdown]
# By doing research about recommendation systems, I've found that recommendation systems are willing to solve 2 main problems:
#
# 1. Given a user, the system should recommend this user the most relevant items that he will be interested in
# 2. Given a user and an item, the system will predict the rating of this user for this item.
#
# In my perspective, problem (1) can be viewed as a sub-problem of problem (2), and therefore we will focus on problem (2).

# %% [markdown]
# Our goal is to train the best model which will result in the most accurate rating system:
#
# $$ f(i, u) = r $$
#
# where
#
# * i = "item"
# * u = "user"
# * r = "rating"

# %% [markdown]
# ---

# %% [markdown]
# ### 2.3 Usage of the solution

# %% [markdown]
# The solution will be used to recommend the most rated items for a customer (user) which he hasn't rated.

# %% [markdown]
# **The pipeline of the solution is as follows:**

# %% [markdown]
# ![%D7%A9%D7%A8%D7%98%D7%95%D7%98%20%D7%A9%D7%9C%20%D7%94%D7%A4%D7%A8%D7%95%D7%99%D7%A7%D7%98.png](attachment:%D7%A9%D7%A8%D7%98%D7%95%D7%98%20%D7%A9%D7%9C%20%D7%94%D7%A4%D7%A8%D7%95%D7%99%D7%A7%D7%98.png)

# %% [markdown]
# ---

# %% [markdown]
# ### 2.4 The current solution

# %% [markdown]
# We will assume that the current solution, and therefore the current benchmark is to give all the unrated items the average possible rating.
#
# For example, if the rating of an item is between 1 and 5, our benchmark will be 3.

# %% [markdown]
# ---

# %% [markdown]
# ### 2.5 Measurement of performance

# %% [markdown]
# We have learned some metrices to evaluate performance. The main metrices are:
# 1. Accuracy
# 2. Recall
# 3. Precision
# 4. RMSE
# 5. MAE

# %% [markdown]
# According to the existing literature on modern recommendation systems, RMSE and MAE are the main indicators for performance in these systems.
#
# That is because evaluating rating is with ordinal properties, and mistakes needs to be valued by the distance between the prediction and the true value.

# %% [markdown]
# The main difference between RMSE and MAE are that RMSE penalizes large errors (because of the squared error), so that the system will prefer more small errors rather then less big errors.
#
# We will choose **the RMSE measurement since our business objective is to make the smallest error for each item independently**.

# %% [markdown]
# ### 2.6 Goal of measurement performance

# %% [markdown]
# As described, RMSE measures the standard deviation of the errors the system makes in the predictions.
#
# If we assume that the errors of the system distribute normally (which we will be able to check later), according to basic statistics of normal distribution probabilities, we can infer that about 68% of the system predictions will fall within the value of the RMSE.
#
# For example, if ratings are between 1-5 and the RMSE measurement is 0.5, for rating prediction of 4 there is 68% percent that the currect rating is in range:
#
# $$ 3.5 \leq r \leq 4.5 $$

# %% [markdown]
# Therefore, **we will define a goal of 1 RMSE value** for start **as it puts the predicted value between a 2 value range in 68% percent.**

# %% [markdown]
# ## 3. Getting the Data

# %% [markdown]
# ### 3.1 Data source and explanation

# %% [markdown]
# Although many small datasets for recommendation systems are available, in this project we will use the "Amazon product data" provided by the UCSD and available in this link: http://jmcauley.ucsd.edu/data/amazon/links.html

# %% [markdown]
# This database is most suitable for our goal:
# 1. It has many interactions, users and items
# 2. It consists many small databases of different products - therefore, it satisfies our main goal which is to build a system that will work with any kind of product

# %% [markdown]
# The "Amazon review data" has 24 different product types, in a size of ~150 GB in total.

# %% [markdown]
# In this section we will complete the following tasks:
# 1. Parse the "CSV" file into a pandas DataFrame
# 2. Tackle the "JSON" file into a pandas DataFrame as well
# 3. Sample a test set, and put it aside before the EDA and data exploration (the next step)

# %% [markdown]
# ---

# %% [markdown]
# ### 3.2 Getting the data for our use-case - and parsing the "csv" file

# %% [markdown]
# In our example, we will choose one of the datasets to work with and by analyzing him we will get insights about the process.
#
# We will choose for start the "Video Games" category. This category consists of:
# 1. 1,324,753 ratings
# 2. 50,953 products
#
# We chose this database for start **because it has a relative small amount of products, and many ratings.**

# %% [markdown]
# After downloading the files, we are left with 2 types of files:
# 1. CSV file with the ratings
# 2. .gz format file with JSON type records
#
# JSON type records are harder to parse, so we will start loading the csv data

# %% [markdown]
# Import the required libraries for handling this kind of data:

# %%
# import libraries
import pandas as pd
import numpy as np
import json

# %% [markdown]
# Read the csv ratings file into a dataframe:

# %%
# define the columns of the dataframe based on the documentation
# the datasets consists of rows of: "user-id ; item-id ; rating ; timestamp"
videos_ratings_columns = ["user", "item", "rating", "timestamp"]

# load the dataframe
videos_ratings_df = pd.read_csv("data/amazon_review_data/ratings_Video_Games.csv", 
                               names=videos_ratings_columns)

# %% [markdown]
# After loading the dataframe, we will peek into the head of the df before moving to the JSON file:

# %%
videos_ratings_df.head(15)
# Out:
#               user        item  rating   timestamp
# 0    AB9S9279OZ3QO  0078764343     5.0  1373155200
# 1   A24SSUT5CSW8BH  0078764343     5.0  1377302400
# 2    AK3V0HEBJMQ7J  0078764343     4.0  1372896000
# 3   A10BECPH7W8HM7  043933702X     5.0  1404950400
# 4   A2PRV9OULX1TWP  043933702X     5.0  1386115200
# 5    AE7GUHCDQQ4UI  043933702X     1.0  1366156800
# 6    A48ABFDDRMKI8  043933702X     5.0  1374192000
# 7   A26B0P6K95SIKW  0439339960     3.0  1288569600
# 8    AZ3UWOC8QSO6C  0439339987     5.0  1366848000
# 9   A182S3ANC0W7DL  0439342260     4.0  1355875200
# 10   AY5Q951JAZAX9  0439374391     5.0  1356393600
# 11  A1TL721YECDIM8  0439394422     3.0  1389657600
# 12   APDCEJMFDO2YT  0439394422     5.0  1285545600
# 13   AFJ7A9CSEPZNY  043940133X     4.0  1168300800
# 14  A14YVGE643TRJK  043940133X     1.0  1324944000

# %% [markdown]
# The df consists of 4 columns as expected, and **we will explain them and analyze them later on.**

# %% [markdown]
# ---

# %% [markdown]
# ### 3.3 Converting the JSON file to DataFrame

# %% [markdown]
# After loading the csv, comes the harder part of parsing the compressed .gz file.
#
# We will start **by extracting the .gz file manually**, and then parse the json file.

# %% [markdown]
# After the extraction of the .gz file, we will read the json file line by line for further parsing:

# %%
with open('data/amazon_review_data/meta_Video_Games.json', 'r') as f:
    videos_metadata_file = f.readlines()

# %% [markdown]
# Here comes our first challenge of converting our data to manipulatable form - we will explain this challenge by printing the first line to the screen:

# %%
videos_metadata_file[0]
# Out:
# "{'asin': '0078764343', 'description': 'Brand new sealed!', 'price': 37.98, 'imUrl': 'http://ecx.images-amazon.com/images/I/513h6dPbwLL._SY300_.jpg', 'related': {'also_bought': ['B000TI836G', 'B003Q53VZC', 'B00EFFW0HC', 'B003VWGBC0', 'B003O6G5TW', 'B0037LTTRO', 'B002I098JE', 'B008OQTS0U', 'B005EVEODY', 'B008B3AVNE', 'B000PE0HBS', 'B00354NAYG', 'B0050SYPV2', 'B00503E8S2', 'B0050SY77E', 'B0022TNO7S', 'B0056WJA30', 'B0023CBY4E', 'B002SRSQ72', 'B005EZ5GQY', 'B004XACA60', 'B00273Z9WM', 'B004HX1QFY', 'B002I0K50U'], 'bought_together': ['B002I098JE'], 'buy_after_viewing': ['B0050SY5BM', 'B000TI836G', 'B0037LTTRO', 'B002I098JE']}, 'salesRank': {'Video Games': 28655}, 'categories': [['Video Games', 'Xbox 360', 'Games']]}\n"

# %% [markdown]
# As we can see above, this JSON format database **is using single-quotes instead of double-quotes for all the parameters and the data. It makes the file unparsable by pandas or json library.**
#
# For example, if we try to load the dictionary presented above we will get the following error:

# %%
json.loads(videos_metadata_file[0])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-6-0ac4ef2d12e5> in <module>
# ----> 1 json.loads(videos_metadata_file[0])
#
# ~\anaconda3\envs\omertorch\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\envs\omertorch\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\envs\omertorch\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %% [markdown]
# And double quotes error raises as expected.
#
# In order to encouter this error, we will take a manual approach in parsing the file, and write a function for that:

# %%
# import required for the parsing
import ast

# %%
# parsing function for single-quote JSON file seperated by line
def single_quote_json_parser_to_df(json_file_path):
    """Parses a JSON file with single quotes between the parameters to pandas DataFrame
    
    Parameters
    ----------
    json_file_path : str
        The file location
    
    Returns
    -------
    pd.DataFrame
        Pandas DataFrame with all the metadata included
    """
    
    # Empty list for the dicts that will be parsed from the json file
    file_list_of_dicts = []
    
    # Opening the json file
    with open(json_file_path, 'r') as f:
        file_content = f.readlines()
        
    # Saves the lines as dicts with ast.literal_eval function
    for line in file_content:
        file_list_of_dicts.append(ast.literal_eval(line))
        
    # Convert the list of dicts to the DataFrame
    return pd.DataFrame(file_list_of_dicts)

# %% [markdown]
# Now we will use our function to parse the json file:

# %%
videos_metadata_df = single_quote_json_parser_to_df(json_file_path='data/amazon_review_data/meta_Video_Games.json')

# %% [markdown]
# Again, we will take a little peek into our new dataframe head.
#
# All data manipulations and analysis will be made later on.

# %%
videos_metadata_df.head(5)
# Out:
#          asin                                        description  price  \
# 0  0078764343                                  Brand new sealed!  37.98
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95
# 3  0439342260  This software is BRAND NEW. Packaging may diff...    NaN
# 4  0439339960               a scholastic clubs fairs cd rom game    NaN
#
#                                                imUrl  \
# 0  http://ecx.images-amazon.com/images/I/513h6dPb...
# 1  http://ecx.images-amazon.com/images/I/61KKRndV...
# 2  http://ecx.images-amazon.com/images/I/416QZg89...
# 3  http://ecx.images-amazon.com/images/I/61Wvu-Uj...
# 4  http://ecx.images-amazon.com/images/I/51k3oRCF...
#
#                                              related               salesRank  \
# 0  {'also_bought': ['B000TI836G', 'B003Q53VZC', '...  {'Video Games': 28655}
# 1  {'also_viewed': ['B000067NP1', '0439573947', '...  {'Video Games': 44080}
# 2  {'also_bought': ['B000314VVU', 'B000PXUOTE', '...  {'Video Games': 49836}
# 3                    {'also_viewed': ['043934302X']}  {'Video Games': 49156}
# 4                    {'also_viewed': ['B00028D7TG']}  {'Video Games': 52262}
#
#                          categories title brand
# 0  [[Video Games, Xbox 360, Games]]   NaN   NaN
# 1        [[Video Games, PC, Games]]   NaN   NaN
# 2        [[Video Games, PC, Games]]   NaN   NaN
# 3        [[Video Games, PC, Games]]   NaN   NaN
# 4        [[Video Games, PC, Games]]   NaN   NaN

# %% [markdown]
# The columns in this DF seems more messy (for example, the "related", "salesRank" and "categories" have sub-fields that will need to be addressed).
#
# We will apply all exploration and changes to the dataframe in the next section (EDA + exploration).

# %% [markdown]
# ---

# %% [markdown]
# ### 3.4 Test set Sampling

# %% [markdown]
# Before moving on to the EDA and data exploration, we need to sample our test set, put it aside and not look at it until the final evaluation.
#
# That is because conclusions based on the test set will cause "data leakage" - insights we get by looking at the test set, is aimed at improving the performance on the test-set itself.
#
# Therefore, we will now put the test-set aside.

# %% [markdown]
# In our project we have 2 sets of data:
# 1. Ratings (User-Item Interactions)
# 2. Items metadata
#
# We will elaborate more on these two later, but for now on we will split the test set from our data.

# %% [markdown]
# Practically, **we need to take a test set only from our first dataset - the Ratings database.**
#
# That is because **we assume that all items information (items metadata) is known to us, and we can use all items information for user's rating prediction.**

# %% [markdown]
# We will use the sklearn function for the train-test split. Later on, we might split the train set to train-validation set, or use K-FOLD instead.

# %%
# Import the required split train-test function from sklearn library
from sklearn.model_selection import train_test_split

# %% [markdown]
# Sklearn's function samples a percentage of the data and shuffles it randomly. In our example, we don't want to make a completely random split.
#
# That is because **we would like to keep small records for each user rating products, and evaluate ourself on each user.**
# E.g. if user 123 rated 100 items, and our train-test split is 20%, we would like to keep 20 items in the test set.
#
# In that way, we might be able to reduce overfitting the data.

# %% [markdown]
# We will **use the stratify functionality for that split, and will choose a 80%-20% train-test split of the data.**
#
# We chose that percentage because on one hand, we have a lot of data to work with, but on the other hand, we would like to keep enought data about each user in the test set.
#
# In this scenario (this split percentage), **users with >=5 ratings will have ratings in the test set.**

# %%
# Define the split percentage constant
SPLIT_PERCENTAGE = 0.2

# Create a copy of the ratings data
X = videos_ratings_df.copy()

# We will define 'y' as the user only for stratifing purpse. then, we will use the ratings as the real 'y' column
# Using the users as the 'y' column helps us split the data and keep 20% of the rows in the test set for each user
y = X['user']

# using stratify to get data for each user, and random_state (equals meaning of life) for consistency
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=SPLIT_PERCENTAGE, stratify=y, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c2243f91aeb4> in <module>
#      10
#      11 # using stratify to get data for each user, and random_state (equals meaning of life) for consistency
# ---> 12 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=SPLIT_PERCENTAGE, stratify=y, random_state=42)
#
# ~\anaconda3\envs\omertorch\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2150                      random_state=random_state)
#    2151
# -> 2152         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2153
#    2154     return list(chain.from_iterable((_safe_indexing(a, train),
#
# ~\anaconda3\envs\omertorch\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    1339         """
#    1340         X, y, groups = indexable(X, y, groups)
# -> 1341         for train, test in self._iter_indices(X, y, groups):
#    1342             yield train, test
#    1343
#
# ~\anaconda3\envs\omertorch\lib\site-packages\sklearn\model_selection\_split.py in _iter_indices(self, X, y, groups)
#    1666         class_counts = np.bincount(y_indices)
#    1667         if np.min(class_counts) < 2:
# -> 1668             raise ValueError("The least populated class in y has only 1"
#    1669                              " member, which is too few. The minimum"
#    1670                              " number of groups for any class cannot"
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %% [markdown]
# We see that we get an error **for having users that rated only a single item.**
#
# For testing purpuses, **we will remove those users (and their ratings) for now and keep only users with 5+ ratings, so that they will have at least one rating in the test set as explained above**.
#
# Later we will check the number of users with only a single rating, and then decided if to add these rows to the train set.

# %%
MINIMUM_RATINGS_AMOUNT = 5

# Here we set our ratings dataframe X with only users that rated more than one item
# We use the groupby and count for the implementation
X = X[X.groupby('user').user.transform('count') >= MINIMUM_RATINGS_AMOUNT]

# %% [markdown]
# First, we will check how many rows were removed by printing the dataframes shape to the screen and the difference:

# %%
print("The original dataframe shape is: " + str(videos_ratings_df.shape))
print("The new dataframe shape without minimum ratings is: " + str(X.shape))
print("The difference is " + str(videos_ratings_df.shape[0] - X.shape[0]) + " rows, which is " +
      str(int(100 * (1 - (X.shape[0] / videos_ratings_df.shape[0])))) + "% of the original dataframe.")
# Out:
# The original dataframe shape is: (1324753, 4)
# The new dataframe shape without minimum ratings is: (300003, 4)
# The difference is 1024750 rows, which is 77% of the original dataframe.

# %% [markdown]
# **We lost more than 3/4 of our data by removing those users!** We will probably have to add them later to the train set to improve performance.
#
# We will perform the split again:

# %%
# Define 'y' again on the smaller ratings dataframe
y = X['user']

# using stratify to get data for each user, and random_state (equals meaning of life) for consistency
# We don't need the 'y_train' and 'y_test' because as we explained before, y only used for  stratifing
X_train, X_test, _, _ = train_test_split(X, y, test_size=SPLIT_PERCENTAGE, stratify=y, random_state=42)

# %% [markdown]
# We will sample an example to show that split was done correctly:

# %%
# View the head of the dataframe to sample an user
X_train.head()
# Out:
#                    user        item  rating   timestamp
# 1240868  A35BKARXRL7XDD  B00DBCAS7E     5.0  1397088000
# 241655   A1BHXHZHSLYU0P  B0007Z70YM     4.0  1315785600
# 747078   A2T3KP9PIE5D9Y  B003BVIXWW     5.0  1397260800
# 760599    ATDXFI4YZRGOM  B003JVCA9Q     4.0  1309996800
# 90350    A13TO1ZFAH9SVN  B00005N6K3     5.0  1099958400

# %% [markdown]
# We will sample the first user with ID 'A35BKARXRL7XDD' for example, and print to the screen how many ratings he has in the train and in the test sets respectively:

# %%
USER = "A35BKARXRL7XDD"

print("Amount of ratings in the train dataset for user " + USER + " is " + 
      str(len(X_train.loc[X_train['user'] == 'A35BKARXRL7XDD'])))
print("Amount of ratings in the test dataset for user " + USER + " is " + 
      str(len(X_test.loc[X_test['user'] == 'A35BKARXRL7XDD'])))
# Out:
# Amount of ratings in the train dataset for user A35BKARXRL7XDD is 4
# Amount of ratings in the test dataset for user A35BKARXRL7XDD is 1

# %% [markdown]
# And as we can see, the split for this example was done as expected.

# %% [markdown]
# Before moving on, we will assemble our train set again, and add all ratings with users of 4 or less ratings:

# %%
# New df with only 4 or less ratings per user
videos_ratings_less_ratings_df = videos_ratings_df[videos_ratings_df.groupby('user').user.transform('count') < MINIMUM_RATINGS_AMOUNT]

# %% [markdown]
# Concating this new dataframe to the existing X_train dataframe:

# %%
X_train = pd.concat([X_train, videos_ratings_less_ratings_df], ignore_index=True)

# %% [markdown]
# We will Validate that now 'X_train' and 'X_test' together produce the same amount of ratings as the original DF:

# %%
print("The difference between the new train and test and the original df is: " + 
      str((X_train.shape[0] + X_test.shape[0]) - videos_ratings_df.shape[0]) + " columns.")
# Out:
# The difference between the new train and test and the original df is: 0 columns.

# %% [markdown]
# And the difference is 0 as required.

# %% [markdown]
# ---

# %% [markdown]
# ## 4 Data Preprocessing and EDA

# %% [markdown]
# ### 4.1 Preprocessing and EDA process explanation

# %% [markdown]
# We successfully splitted the train and the test sets, so now we are free to perform basic preprocess for the train set and perform the EDA.
#
# Note: Later on we might need to use some data preprocessing for the test set as well, so we will build functions for that purpose for later usage.

# %% [markdown]
# **In this section we will perform the followings steps:**
# 1. Apply basic data preprocess to prepare the train set for the EDA
# 2. Study each attribute we have in our datasets and its characteristics:
#         a. Name
#         b. Type (Categorial / Integer / text / etc.)
#         c. % of missing values
#         d. Noise of the attribute (outliers)
#         e. Usefulness analysis for our task
#         f. Data distribution
# 3. Visualize the data for further insights (continuing the EDA)
# 4. Study the possible correlation between features
# 5. Define new possible features that can be extracted with feature engineering

# %% [markdown]
# Before moving on, we will give a short explanation about the datasets we have:
#
# In general, recommendation systems has 3 types of datasets:
#
# 1. Users metadata
# 2. Items metadata
# 3. User-Item interactions data (Ratings)
#
# In our use-case, we have the second and the third databases, **but we are missing the first database - we have no information about our users rather than their ID.**

# %% [markdown]
# ### 4.2 Basic Data Preprocess

# %% [markdown]
# #### 4.2.1 The ratings dataframe

# %% [markdown]
# By viewing the ratings dataframe, we can see that the columns are very simple and do not require any seperation for further exploration:

# %%
X_train.head(5)
# Out:
#              user        item  rating   timestamp
# 0  A35BKARXRL7XDD  B00DBCAS7E     5.0  1397088000
# 1  A1BHXHZHSLYU0P  B0007Z70YM     4.0  1315785600
# 2  A2T3KP9PIE5D9Y  B003BVIXWW     5.0  1397260800
# 3   ATDXFI4YZRGOM  B003JVCA9Q     4.0  1309996800
# 4  A13TO1ZFAH9SVN  B00005N6K3     5.0  1099958400

# %% [markdown]
# We will explore each one of the attributes later on the EDA.

# %% [markdown]
# #### 4.2.2 The items metadata dataframe

# %% [markdown]
# As opposed to the ratings dataframe, the items metadata DF needs to be orginized in order to apply effective EDA.
#
# We will print the head of the dataframe to get a quick view of the columns:

# %%
# Create a copy for the preprocess
items_metadata_df = videos_metadata_df.copy()

items_metadata_df.head(5)
# Out:
#          asin                                        description  price  \
# 0  0078764343                                  Brand new sealed!  37.98
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95
# 3  0439342260  This software is BRAND NEW. Packaging may diff...    NaN
# 4  0439339960               a scholastic clubs fairs cd rom game    NaN
#
#                                                imUrl  \
# 0  http://ecx.images-amazon.com/images/I/513h6dPb...
# 1  http://ecx.images-amazon.com/images/I/61KKRndV...
# 2  http://ecx.images-amazon.com/images/I/416QZg89...
# 3  http://ecx.images-amazon.com/images/I/61Wvu-Uj...
# 4  http://ecx.images-amazon.com/images/I/51k3oRCF...
#
#                                              related               salesRank  \
# 0  {'also_bought': ['B000TI836G', 'B003Q53VZC', '...  {'Video Games': 28655}
# 1  {'also_viewed': ['B000067NP1', '0439573947', '...  {'Video Games': 44080}
# 2  {'also_bought': ['B000314VVU', 'B000PXUOTE', '...  {'Video Games': 49836}
# 3                    {'also_viewed': ['043934302X']}  {'Video Games': 49156}
# 4                    {'also_viewed': ['B00028D7TG']}  {'Video Games': 52262}
#
#                          categories title brand
# 0  [[Video Games, Xbox 360, Games]]   NaN   NaN
# 1        [[Video Games, PC, Games]]   NaN   NaN
# 2        [[Video Games, PC, Games]]   NaN   NaN
# 3        [[Video Games, PC, Games]]   NaN   NaN
# 4        [[Video Games, PC, Games]]   NaN   NaN

# %% [markdown]
# In this peek we can already see a few things:
# 1. Most attributes are non-numbers
# 2. Many attributes seems like dictionaries and lists - which we will have to change to be able to analyze it and later train it
# 3. all titles and brands are missing in these rows - we need to find out more if it is common

# %% [markdown]
# We will get some more metadata about this dataframe:

# %%
items_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50953 entries, 0 to 50952
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   asin         50953 non-null  object
#  1   description  47063 non-null  object
#  2   price        43905 non-null  float64
#  3   imUrl        50733 non-null  object
#  4   related      45089 non-null  object
#  5   salesRank    49016 non-null  object
#  6   categories   50953 non-null  object
#  7   title        2265 non-null   object
#  8   brand        767 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 3.5+ MB

# %% [markdown]
# We can learn that almost all brands and titles are missing, and therefore we will remove them from our dataset for now:

# %%
items_metadata_df = items_metadata_df.drop('title', axis=1)
items_metadata_df = items_metadata_df.drop('brand', axis=1)

# %% [markdown]
# And check that they don't exist anymore:

# %%
items_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50953 entries, 0 to 50952
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   asin         50953 non-null  object
#  1   description  47063 non-null  object
#  2   price        43905 non-null  float64
#  3   imUrl        50733 non-null  object
#  4   related      45089 non-null  object
#  5   salesRank    49016 non-null  object
#  6   categories   50953 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 2.7+ MB

# %% [markdown]
# Also, all except 1 are of object data type, so we will have to get the specific type of each column:

# %%
print("The datatype of 'asin' column is: " + str(type(items_metadata_df['asin'][0])))
print("The datatype of 'description' column is: " + str(type(items_metadata_df['description'][0])))
print("The datatype of 'imUrl' column is: " + str(type(items_metadata_df['imUrl'][0])))
print("The datatype of 'related' column is: " + str(type(items_metadata_df['related'][0])))
print("The datatype of 'salesRank' column is: " + str(type(items_metadata_df['salesRank'][0])))
print("The datatype of 'categories' column is: " + str(type(items_metadata_df['categories'][0])))
# Out:
# The datatype of 'asin' column is: <class 'str'>
# The datatype of 'description' column is: <class 'str'>
# The datatype of 'imUrl' column is: <class 'str'>
# The datatype of 'related' column is: <class 'dict'>
# The datatype of 'salesRank' column is: <class 'dict'>
# The datatype of 'categories' column is: <class 'list'>

# %% [markdown]
# We have 3 strings, 2 dictionaries, and one list.

# %% [markdown]
# For start, we will remove the url column under the assumption that we do not relay on product images for comparison in the basic EDA and training. We might consider this for further research.

# %%
items_metadata_df = items_metadata_df.drop('imUrl', axis=1)

# %%
items_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50953 entries, 0 to 50952
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   asin         50953 non-null  object
#  1   description  47063 non-null  object
#  2   price        43905 non-null  float64
#  3   related      45089 non-null  object
#  4   salesRank    49016 non-null  object
#  5   categories   50953 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 2.3+ MB

# %% [markdown]
# Lets print our current dataframe after removing some columns:

# %%
items_metadata_df.head(5)
# Out:
#          asin                                        description  price  \
# 0  0078764343                                  Brand new sealed!  37.98
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95
# 3  0439342260  This software is BRAND NEW. Packaging may diff...    NaN
# 4  0439339960               a scholastic clubs fairs cd rom game    NaN
#
#                                              related               salesRank  \
# 0  {'also_bought': ['B000TI836G', 'B003Q53VZC', '...  {'Video Games': 28655}
# 1  {'also_viewed': ['B000067NP1', '0439573947', '...  {'Video Games': 44080}
# 2  {'also_bought': ['B000314VVU', 'B000PXUOTE', '...  {'Video Games': 49836}
# 3                    {'also_viewed': ['043934302X']}  {'Video Games': 49156}
# 4                    {'also_viewed': ['B00028D7TG']}  {'Video Games': 52262}
#
#                          categories
# 0  [[Video Games, Xbox 360, Games]]
# 1        [[Video Games, PC, Games]]
# 2        [[Video Games, PC, Games]]
# 3        [[Video Games, PC, Games]]
# 4        [[Video Games, PC, Games]]

# %% [markdown]
# Now we will work on these attributes:
# 1. asin - we have a different asin for each item. We will check that in the EDA.
# 2. description - doesn't need any changes as well
# 3. price - the only number in the dataframe, no changes
# 4. related - **preprocessing required**
# 5. salesRank - **preprocessing required**
# 6. categories - **preprocessing required**

# %% [markdown]
# ---

# %% [markdown]
# ##### 4.2.2.1 The "related" column

# %% [markdown]
# We will start by printing an example of this data:

# %%
# Print the first item to the screen
items_metadata_df['related'][0]
# Out:
# {'also_bought': ['B000TI836G',
#   'B003Q53VZC',
#   'B00EFFW0HC',
#   'B003VWGBC0',
#   'B003O6G5TW',
#   'B0037LTTRO',
#   'B002I098JE',
#   'B008OQTS0U',
#   'B005EVEODY',
#   'B008B3AVNE',
#   'B000PE0HBS',
#   'B00354NAYG',
#   'B0050SYPV2',
#   'B00503E8S2',
#   'B0050SY77E',
#   'B0022TNO7S',
#   'B0056WJA30',
#   'B0023CBY4E',
#   'B002SRSQ72',
#   'B005EZ5GQY',
#   'B004XACA60',
#   'B00273Z9WM',
#   'B004HX1QFY',
#   'B002I0K50U'],
#  'bought_together': ['B002I098JE'],
#  'buy_after_viewing': ['B0050SY5BM', 'B000TI836G', 'B0037LTTRO', 'B002I098JE']}

# %% [markdown]
# We see 3 different keys in this dictionary.
#
# But we don't know if these are the only possible keys in the column. We will try, for example, to print the second item as well:

# %%
# Print the second item to the screen
items_metadata_df['related'][1]
# Out:
# {'also_viewed': ['B000067NP1',
#   '0439573947',
#   'B00005V97H',
#   'B00004DITL',
#   'B0000CE1P7'],
#  'buy_after_viewing': ['B000067NP1', '0439573947', 'B00003W869', '0486406105']}

# %% [markdown]
# Here we have the "also_viewed" key which was missing the first item, and 2 other categories are missing here.
#
# Therefore, we have to check each and every column to find all the possible keys in the dictionaries. We will write a function for that:

# %%
# Function for calculating all keys in a pandas column:
related_dict_keys = []

def calculate_related_dict_keys(x):
    # x is a value from 'related' column, which is a dict. get all the keys
    try:
        dict_keys = list(x.keys())
    except:
        dict_keys = []

    # add the keys to the full list
    related_dict_keys.extend(k for k in dict_keys if k not in related_dict_keys)

# %% [markdown]
# We will apply this function on the 'related' column to get all the keys:

# %%
# Use the 'apply' pandas method
items_metadata_df['related'].apply(calculate_related_dict_keys)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 50948    None
# 50949    None
# 50950    None
# 50951    None
# 50952    None
# Name: related, Length: 50953, dtype: object

# %% [markdown]
# And view the keys in this column:

# %%
related_dict_keys
# Out:
# ['also_bought', 'bought_together', 'buy_after_viewing', 'also_viewed']

# %% [markdown]
# Our conclusion is that although we have seen different keys in the first two values, there are only 4 possible keys in all the column.

# %% [markdown]
# Because the amount of possible keys is rather limited, we will create a new column, and put the value of each of the keys in the corresponding column

# %%
for key in related_dict_keys:
    items_metadata_df[key] = np.NaN

# %% [markdown]
# Let's see our new dataframe:

# %%
items_metadata_df.head()
# Out:
#          asin                                        description  price  \
# 0  0078764343                                  Brand new sealed!  37.98
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95
# 3  0439342260  This software is BRAND NEW. Packaging may diff...    NaN
# 4  0439339960               a scholastic clubs fairs cd rom game    NaN
#
#                                              related               salesRank  \
# 0  {'also_bought': ['B000TI836G', 'B003Q53VZC', '...  {'Video Games': 28655}
# 1  {'also_viewed': ['B000067NP1', '0439573947', '...  {'Video Games': 44080}
# 2  {'also_bought': ['B000314VVU', 'B000PXUOTE', '...  {'Video Games': 49836}
# 3                    {'also_viewed': ['043934302X']}  {'Video Games': 49156}
# 4                    {'also_viewed': ['B00028D7TG']}  {'Video Games': 52262}
#
#                          categories  also_bought  bought_together  \
# 0  [[Video Games, Xbox 360, Games]]          NaN              NaN
# 1        [[Video Games, PC, Games]]          NaN              NaN
# 2        [[Video Games, PC, Games]]          NaN              NaN
# 3        [[Video Games, PC, Games]]          NaN              NaN
# 4        [[Video Games, PC, Games]]          NaN              NaN
#
#    buy_after_viewing  also_viewed
# 0                NaN          NaN
# 1                NaN          NaN
# 2                NaN          NaN
# 3                NaN          NaN
# 4                NaN          NaN

# %% [markdown]
# Now we will write a function for moving the lists into the different columns:

# %%
def parse_dict_items(df, dict_column):
    """
    This function parses a dict pandas column, and moves the values of the dict to new columns according to the key values. 
    The processing is not done in-place.
    
    Parameters
    ----------
    df : pandas.DataFrame
        the dataframe to be processed. The processing is not done in-place.
        
    dict_column : str
        The column name of the dicts
        
    Returns
    -------
    pandas.DataFrame
        a new dataframe after the extraction
    
    """
    # Work on a different df, to not edit the df in place
    temp_df = df.copy()
    
    # iterate over all items in the column
    for index, value in temp_df[dict_column].iteritems():
        
        # if the value is not NaN, save them in the corresponding columns
        try:      
            for key, val in value.items():
                temp_df[key].iloc[index] = val
        
        # else, pass that row
        except:
            pass
    
    # return the df
    return temp_df

# %% [markdown]
# The actual parsing will take 1-2 minutes over all the dataframe:

# %%
items_metadata_df = parse_dict_items(items_metadata_df,
                                     dict_column='related')
# Out:
# C:\Users\Administrator\anaconda3\envs\omertorch\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %% [markdown]
# And now, let's see our new dataframe after adding the new columns with their values:

# %%
items_metadata_df.head(5)
# Out:
#          asin                                        description  price  \
# 0  0078764343                                  Brand new sealed!  37.98
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95
# 3  0439342260  This software is BRAND NEW. Packaging may diff...    NaN
# 4  0439339960               a scholastic clubs fairs cd rom game    NaN
#
#                                              related               salesRank  \
# 0  {'also_bought': ['B000TI836G', 'B003Q53VZC', '...  {'Video Games': 28655}
# 1  {'also_viewed': ['B000067NP1', '0439573947', '...  {'Video Games': 44080}
# 2  {'also_bought': ['B000314VVU', 'B000PXUOTE', '...  {'Video Games': 49836}
# 3                    {'also_viewed': ['043934302X']}  {'Video Games': 49156}
# 4                    {'also_viewed': ['B00028D7TG']}  {'Video Games': 52262}
#
#                          categories  \
# 0  [[Video Games, Xbox 360, Games]]
# 1        [[Video Games, PC, Games]]
# 2        [[Video Games, PC, Games]]
# 3        [[Video Games, PC, Games]]
# 4        [[Video Games, PC, Games]]
#
#                                          also_bought bought_together  \
# 0  [B000TI836G, B003Q53VZC, B00EFFW0HC, B003VWGBC...    [B002I098JE]
# 1                                                NaN             NaN
# 2  [B000314VVU, B000PXUOTE, B00004TJCM, B0006U22X...             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#                                   buy_after_viewing  \
# 0  [B0050SY5BM, B000TI836G, B0037LTTRO, B002I098JE]
# 1  [B000067NP1, 0439573947, B00003W869, 0486406105]
# 2                          [B00004UCUS, B000YFIS00]
# 3                                               NaN
# 4                                               NaN
#
#                                          also_viewed
# 0                                                NaN
# 1  [B000067NP1, 0439573947, B00005V97H, B00004DIT...
# 2                                                NaN
# 3                                       [043934302X]
# 4                                       [B00028D7TG]

# %% [markdown]
# The extraction was done successfully! We now no longer need the original column, and we can drop it:

# %%
items_metadata_df = items_metadata_df.drop("related", axis=1)

# %% [markdown]
# And let's see our dataframe for the last time before moving on to the next column:

# %%
items_metadata_df.head(5)
# Out:
#          asin                                        description  price  \
# 0  0078764343                                  Brand new sealed!  37.98
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95
# 3  0439342260  This software is BRAND NEW. Packaging may diff...    NaN
# 4  0439339960               a scholastic clubs fairs cd rom game    NaN
#
#                 salesRank                        categories  \
# 0  {'Video Games': 28655}  [[Video Games, Xbox 360, Games]]
# 1  {'Video Games': 44080}        [[Video Games, PC, Games]]
# 2  {'Video Games': 49836}        [[Video Games, PC, Games]]
# 3  {'Video Games': 49156}        [[Video Games, PC, Games]]
# 4  {'Video Games': 52262}        [[Video Games, PC, Games]]
#
#                                          also_bought bought_together  \
# 0  [B000TI836G, B003Q53VZC, B00EFFW0HC, B003VWGBC...    [B002I098JE]
# 1                                                NaN             NaN
# 2  [B000314VVU, B000PXUOTE, B00004TJCM, B0006U22X...             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#                                   buy_after_viewing  \
# 0  [B0050SY5BM, B000TI836G, B0037LTTRO, B002I098JE]
# 1  [B000067NP1, 0439573947, B00003W869, 0486406105]
# 2                          [B00004UCUS, B000YFIS00]
# 3                                               NaN
# 4                                               NaN
#
#                                          also_viewed
# 0                                                NaN
# 1  [B000067NP1, 0439573947, B00005V97H, B00004DIT...
# 2                                                NaN
# 3                                       [043934302X]
# 4                                       [B00028D7TG]

# %% [markdown]
# ---

# %% [markdown]
# ##### 4.2.2.2 The "salesRank" column

# %% [markdown]
# The salesRank column is very similar to the "related" column - it has dictionaries with unknown keys in it.
#
# We will try peeking in the first 20 items in the dataframe to get some impression of the keys:

# %%
items_metadata_df['salesRank'].head(20)
# Out:
# 0     {'Video Games': 28655}
# 1     {'Video Games': 44080}
# 2     {'Video Games': 49836}
# 3     {'Video Games': 49156}
# 4     {'Video Games': 52262}
# 5     {'Video Games': 59834}
# 6     {'Video Games': 36531}
# 7     {'Video Games': 17910}
# 8     {'Video Games': 42130}
# 9     {'Video Games': 12108}
# 10     {'Video Games': 7367}
# 11    {'Video Games': 35302}
# 12    {'Video Games': 51360}
# 13    {'Video Games': 18693}
# 14    {'Video Games': 44476}
# 15    {'Video Games': 65611}
# 16    {'Video Games': 68816}
# 17    {'Video Games': 52825}
# 18    {'Video Games': 25951}
# 19    {'Video Games': 55546}
# Name: salesRank, dtype: object

# %% [markdown]
# It seems that only "Video Games" catogery exits. We will build another function like in the "related" part to make sure that no other keys exist:

# %%
# Function for calculating all keys in a pandas column:
sales_dict_keys = []

def calculate_sales_dict_keys(x):
    # x is a value from 'salesRank' column, which is a dict. get all the keys
    try:
        dict_keys = list(x.keys())
    except:
        dict_keys = []

    # add the keys to the full list
    sales_dict_keys.extend(k for k in dict_keys if k not in sales_dict_keys)

# %% [markdown]
# And we will run in the same way as before:

# %%
items_metadata_df['salesRank'].apply(calculate_sales_dict_keys)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 50948    None
# 50949    None
# 50950    None
# 50951    None
# 50952    None
# Name: salesRank, Length: 50953, dtype: object

# %% [markdown]
# Let's view all of our keys:

# %%
sales_dict_keys
# Out:
# ['Video Games',
#  'Toys & Games',
#  'Software',
#  'Electronics',
#  'Movies & TV',
#  'Music',
#  'Sports &amp; Outdoors',
#  'Home &amp; Kitchen',
#  'Computers & Accessories',
#  'Musical Instruments',
#  'Kitchen & Dining',
#  'Beauty',
#  'Clothing',
#  'Cell Phones & Accessories',
#  'Camera &amp; Photo',
#  'Patio, Lawn & Garden',
#  'Arts, Crafts & Sewing',
#  'Industrial & Scientific',
#  'Pet Supplies',
#  'Shoes',
#  'Health & Personal Care',
#  'Jewelry',
#  'Home Improvement']

# %% [markdown]
# And we got much more keys then expected! We got 23 keys instead of the only one we thought we have.
#
# We will operate in the same way as in the 'related' column, and add all these columns and extract the values from it.
#
# Since this part is exactly the same, no explanations will be added.

# %%
for key in sales_dict_keys:
    items_metadata_df[key] = np.NaN

# %%
items_metadata_df = parse_dict_items(items_metadata_df,
                                     dict_column="salesRank")
# Out:
# C:\Users\Administrator\anaconda3\envs\omertorch\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
items_metadata_df = items_metadata_df.drop("salesRank", axis=1)

# %% [markdown]
# After doing all the process again, let's view our dataframe:

# %%
items_metadata_df.head()
# Out:
#          asin                                        description  price  \
# 0  0078764343                                  Brand new sealed!  37.98
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95
# 3  0439342260  This software is BRAND NEW. Packaging may diff...    NaN
# 4  0439339960               a scholastic clubs fairs cd rom game    NaN
#
#                          categories  \
# 0  [[Video Games, Xbox 360, Games]]
# 1        [[Video Games, PC, Games]]
# 2        [[Video Games, PC, Games]]
# 3        [[Video Games, PC, Games]]
# 4        [[Video Games, PC, Games]]
#
#                                          also_bought bought_together  \
# 0  [B000TI836G, B003Q53VZC, B00EFFW0HC, B003VWGBC...    [B002I098JE]
# 1                                                NaN             NaN
# 2  [B000314VVU, B000PXUOTE, B00004TJCM, B0006U22X...             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#                                   buy_after_viewing  \
# 0  [B0050SY5BM, B000TI836G, B0037LTTRO, B002I098JE]
# 1  [B000067NP1, 0439573947, B00003W869, 0486406105]
# 2                          [B00004UCUS, B000YFIS00]
# 3                                               NaN
# 4                                               NaN
#
#                                          also_viewed  Video Games  \
# 0                                                NaN      28655.0
# 1  [B000067NP1, 0439573947, B00005V97H, B00004DIT...      44080.0
# 2                                                NaN      49836.0
# 3                                       [043934302X]      49156.0
# 4                                       [B00028D7TG]      52262.0
#
#    Toys & Games  ...  Cell Phones & Accessories  Camera &amp; Photo  \
# 0           NaN  ...                        NaN                 NaN
# 1           NaN  ...                        NaN                 NaN
# 2           NaN  ...                        NaN                 NaN
# 3           NaN  ...                        NaN                 NaN
# 4           NaN  ...                        NaN                 NaN
#
#    Patio, Lawn & Garden  Arts, Crafts & Sewing  Industrial & Scientific  \
# 0                   NaN                    NaN                      NaN
# 1                   NaN                    NaN                      NaN
# 2                   NaN                    NaN                      NaN
# 3                   NaN                    NaN                      NaN
# 4                   NaN                    NaN                      NaN
#
#    Pet Supplies  Shoes  Health & Personal Care  Jewelry  Home Improvement
# 0           NaN    NaN                     NaN      NaN               NaN
# 1           NaN    NaN                     NaN      NaN               NaN
# 2           NaN    NaN                     NaN      NaN               NaN
# 3           NaN    NaN                     NaN      NaN               NaN
# 4           NaN    NaN                     NaN      NaN               NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# One problem remains, which is that its not very easy to understand our new columns from their names.
#
# The category name does not imply about the value inside the column - the sales rank.
#
# We will add the "salesRank" mark to each one of the column:

# %%
# Adding "salesRank tag before each key"
new_sales_dict_keys = list(map(lambda x : x + " salesRank", sales_dict_keys))

# Creating a dict which is mapping each one of the items to one another
new_columns_names = dict(zip(sales_dict_keys, new_sales_dict_keys))

# %%
# Finally, we will rename the columns:
items_metadata_df.rename(columns=new_columns_names, inplace=True)

# %% [markdown]
# Now, let's view our new dataframe's info and look by the 'info' and 'head' functions:

# %%
items_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50953 entries, 0 to 50952
# Data columns (total 31 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   asin                                 50953 non-null  object
#  1   description                          47063 non-null  object
#  2   price                                43905 non-null  float64
#  3   categories                           50953 non-null  object
#  4   also_bought                          28965 non-null  object
#  5   bought_together                      20654 non-null  object
#  6   buy_after_viewing                    39905 non-null  object
#  7   also_viewed                          14839 non-null  object
#  8   Video Games salesRank                45278 non-null  float64
#  9   Toys & Games salesRank               148 non-null    float64
#  10  Software salesRank                   2236 non-null   float64
#  11  Electronics salesRank                757 non-null    float64
#  12  Movies & TV salesRank                22 non-null     float64
#  13  Music salesRank                      12 non-null     float64
#  14  Sports &amp; Outdoors salesRank      36 non-null     float64
#  15  Home &amp; Kitchen salesRank         26 non-null     float64
#  16  Computers & Accessories salesRank    10 non-null     float64
#  17  Musical Instruments salesRank        9 non-null      float64
#  18  Kitchen & Dining salesRank           2 non-null      float64
#  19  Beauty salesRank                     2 non-null      float64
#  20  Clothing salesRank                   41 non-null     float64
#  21  Cell Phones & Accessories salesRank  17 non-null     float64
#  22  Camera &amp; Photo salesRank         14 non-null     float64
#  23  Patio, Lawn & Garden salesRank       2 non-null      float64
#  24  Arts, Crafts & Sewing salesRank      4 non-null      float64
#  25  Industrial & Scientific salesRank    2 non-null      float64
#  26  Pet Supplies salesRank               1 non-null      float64
#  27  Shoes salesRank                      2 non-null      float64
#  28  Health & Personal Care salesRank     4 non-null      float64
#  29  Jewelry salesRank                    1 non-null      float64
#  30  Home Improvement salesRank           1 non-null      float64
# dtypes: float64(24), object(7)
# memory usage: 12.1+ MB

# %%
items_metadata_df.head()
# Out:
#          asin                                        description  price  \
# 0  0078764343                                  Brand new sealed!  37.98
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95
# 3  0439342260  This software is BRAND NEW. Packaging may diff...    NaN
# 4  0439339960               a scholastic clubs fairs cd rom game    NaN
#
#                          categories  \
# 0  [[Video Games, Xbox 360, Games]]
# 1        [[Video Games, PC, Games]]
# 2        [[Video Games, PC, Games]]
# 3        [[Video Games, PC, Games]]
# 4        [[Video Games, PC, Games]]
#
#                                          also_bought bought_together  \
# 0  [B000TI836G, B003Q53VZC, B00EFFW0HC, B003VWGBC...    [B002I098JE]
# 1                                                NaN             NaN
# 2  [B000314VVU, B000PXUOTE, B00004TJCM, B0006U22X...             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#                                   buy_after_viewing  \
# 0  [B0050SY5BM, B000TI836G, B0037LTTRO, B002I098JE]
# 1  [B000067NP1, 0439573947, B00003W869, 0486406105]
# 2                          [B00004UCUS, B000YFIS00]
# 3                                               NaN
# 4                                               NaN
#
#                                          also_viewed  Video Games salesRank  \
# 0                                                NaN                28655.0
# 1  [B000067NP1, 0439573947, B00005V97H, B00004DIT...                44080.0
# 2                                                NaN                49836.0
# 3                                       [043934302X]                49156.0
# 4                                       [B00028D7TG]                52262.0
#
#    Toys & Games salesRank  ...  Cell Phones & Accessories salesRank  \
# 0                     NaN  ...                                  NaN
# 1                     NaN  ...                                  NaN
# 2                     NaN  ...                                  NaN
# 3                     NaN  ...                                  NaN
# 4                     NaN  ...                                  NaN
#
#    Camera &amp; Photo salesRank  Patio, Lawn & Garden salesRank  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    Arts, Crafts & Sewing salesRank  Industrial & Scientific salesRank  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#    Pet Supplies salesRank  Shoes salesRank  Health & Personal Care salesRank  \
# 0                     NaN              NaN                               NaN
# 1                     NaN              NaN                               NaN
# 2                     NaN              NaN                               NaN
# 3                     NaN              NaN                               NaN
# 4                     NaN              NaN                               NaN
#
#    Jewelry salesRank  Home Improvement salesRank
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                NaN                         NaN
# 3                NaN                         NaN
# 4                NaN                         NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# The dataframe has 30 columns as expected (1 for index), and all the values inserted both from the 'related' and from the 'salesRank' columns.

# %% [markdown]
# ---

# %% [markdown]
# ##### 4.2.2.3 The "categories" column

# %% [markdown]
# Finally, we need to preprocess the categories column. We will treat it the same way as we did in the last two columns, checking the number of tags in the columns and adding them seperately as different columns to the df.
#
# This time, instead of adding a value from a dict, we will add a binary value - 1 if the tag exists in the list, and 0 otherwise.

# %% [markdown]
# First, we will get all the tags in the lists:

# %%
# Function for calculating all keys in a pandas column:
categories_list_values = []

def calculate_categories_list_values(x):
    
    # x is a value from 'category' column, which is a list nested inside a list. we will try to get the nested list:
    try:
        values = list(x[0])
        
    # if the list is empty then no first value will exist, and we will return an empty list:
    except:
        values = []

    # add the values to the full list
    categories_list_values.extend(v for v in values if v not in categories_list_values)

# %% [markdown]
# And apply our function on the dataframe:

# %%
items_metadata_df['categories'].apply(calculate_categories_list_values)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 50948    None
# 50949    None
# 50950    None
# 50951    None
# 50952    None
# Name: categories, Length: 50953, dtype: object

# %% [markdown]
# We will print to the screen the tags to look over them:

# %%
categories_list_values
# Out:
# ['Video Games',
#  'Xbox 360',
#  'Games',
#  'PC',
#  'Mac',
#  'More Systems',
#  'Game Boy Advance',
#  'Nintendo DS',
#  'Home & Kitchen',
#  'Artwork',
#  'Posters & Prints',
#  'Kids & Family',
#  'PlayStation 3',
#  'Accessories',
#  'Controllers',
#  'Microphones',
#  'PlayStation 2',
#  'Remotes',
#  'Wii',
#  'Dance Mats',
#  'Cables & Adapters',
#  'Cables',
#  'Cases & Protectors',
#  'Sony PSP',
#  'Batteries & Chargers',
#  'Batteries',
#  'GameCube',
#  'Xbox',
#  'Nintendo 64',
#  'Hardware',
#  'Digital Games',
#  'PC Game Downloads',
#  'Skins',
#  'Gamepads',
#  'Adapters',
#  'Nintendo 3DS',
#  'Accessory Kits',
#  'Memory',
#  'Fitness Accessories',
#  'Racing Wheels',
#  'CDs & Vinyl',
#  'Christian',
#  '3DO',
#  'Super Nintendo',
#  'PlayStation',
#  'Alternative Rock',
#  'New Wave & Post-Punk',
#  'New Wave',
#  'Software',
#  "Children's",
#  'Toys & Games',
#  'Trading Card Games',
#  'Decks & Sets',
#  'Game Boy Color',
#  'Consoles',
#  'Joysticks',
#  'Sega Dreamcast',
#  'Movies & TV',
#  'Movies',
#  'Nintendo NES',
#  'Game Boy',
#  'Sega Genesis',
#  'Cell Phones & Accessories',
#  'Art & Creativity',
#  'Sports & Outdoors',
#  'Fan Shop',
#  'Video Games & Accessories',
#  'Education & Reference',
#  'History',
#  'Linux Games',
#  'Science',
#  'NEOGEO Pocket',
#  'Languages',
#  'Steering Wheels',
#  'Automotive',
#  'Paint, Body & Trim',
#  'Trim',
#  'Interior',
#  'Electronics',
#  'Computers & Accessories',
#  'Cables & Accessories',
#  'Photography',
#  'Exercise & Fitness',
#  'Exercise Balls & Accessories',
#  'Accessories & Supplies',
#  'Audio & Video Accessories',
#  'Cables & Interconnects',
#  'Power Cables',
#  'Typing',
#  'Religion',
#  'USB Cables',
#  'Early Learning',
#  'Maps & Atlases',
#  'Design & Illustration',
#  'Lifestyle & Hobbies',
#  'Electronics for Kids',
#  'Operating Systems',
#  'PDAs',
#  'Math',
#  'Sega Game Gear',
#  'Sega Saturn',
#  'Tools & Home Improvement',
#  'Lighting & Ceiling Fans',
#  'Ceiling Lights',
#  'Track, Rail & Cable Lighting',
#  'Heads',
#  'Atari Jaguar',
#  'Flight Controls',
#  'Arts',
#  'Fashion & Beauty',
#  'Utilities',
#  'Screen Savers',
#  'Music',
#  'Sports Equipment',
#  'Basketball Equipment',
#  'Basketballs',
#  'Business & Office',
#  'Thinking & Problem Solving',
#  'Test Preparation',
#  'Reading & Language',
#  'Dress Up & Pretend Play',
#  'Pretend Play',
#  'Gaming Mice',
#  'Intellivision',
#  'Office Products',
#  'Office Electronics',
#  'Scanners & Accessories',
#  'Programming & Web Development',
#  'Database',
#  'Writing & Literature',
#  'Science & Nature',
#  'Computer Components',
#  'Camera & Photo',
#  'Geography',
#  "Children's Music",
#  'Disney',
#  'Dictionaries',
#  'Purchase Circles',
#  'United States',
#  'Michigan',
#  'Carleton',
#  'Legal',
#  'Linux & Unix',
#  'Portable Audio & Video',
#  'PC Maintenance',
#  'Mice',
#  'Cooking & Health',
#  'Musical Instruments',
#  'Studio Recording Equipment',
#  'Computer Recording',
#  'Music Creation & Sequencing',
#  'Home Audio',
#  'Stereo Components',
#  'Receivers & Amplifiers',
#  'Component Amplifiers',
#  'Office & School Supplies',
#  'Desk Accessories & Workspace Organizers',
#  'Mouse Pads & Wrist Rests',
#  'Mouse Pads',
#  'Mobile Utilities',
#  'Networking',
#  'Metal',
#  'PlayStation Vita',
#  'Gaming Keyboards',
#  'Gift Cards',
#  'Printers & Accessories',
#  'Printers',
#  'Atari Lynx',
#  'Animation & 3D',
#  'Encyclopedias',
#  'Networking Products',
#  'Network Adapters',
#  'USB Network Adapters',
#  'Labels, Indexes & Stamps',
#  'Labels & Stickers',
#  'Printer Labels: Laser & Inkjet',
#  'Portable DVD Players',
#  'TV',
#  'Plug & Play Video Games',
#  'Remote Controls',
#  'TV Remote Controls',
#  'Auto Accessories',
#  'Batteries, Chargers & Accessories',
#  'AC Adapters',
#  'Hunting & Fishing',
#  'Hunting',
#  'Game Calls',
#  'Turkey',
#  'Distribution',
#  'Selector Switch Boxes',
#  'Headsets',
#  'Wired Headsets',
#  'Document Management',
#  'Headsets & Microphones',
#  'Tactical & Duty',
#  'Personal Defense Equipment',
#  'Rough Plumbing',
#  'Pipes, Pipe Fittings & Accessories',
#  'Pipe Fittings',
#  'Equestrian Sports',
#  'Horse Driving Equipment',
#  'Board Games',
#  'Office Suites',
#  'Television & Video',
#  'Atari 2600',
#  'Digital Cameras',
#  'Point & Shoot Digital Cameras',
#  'Sound Editing',
#  'Data Storage',
#  'USB Flash Drives',
#  'Laptop & Netbook Computer Accessories',
#  'Docking Stations',
#  'Internal Optical Drives',
#  'Internal CD Drives',
#  'Leisure Sports & Game Room',
#  'Casino Equipment',
#  'Poker Equipment',
#  'Poker Chips',
#  'Atari 7800',
#  'Arts, Crafts & Sewing',
#  'Craft Supplies',
#  'Leathercraft',
#  'Connectors & Adapters',
#  'Word Processing',
#  'Drums & Percussion',
#  'Folk & World Hand Drums',
#  'Screen Protectors',
#  'Sega CD',
#  'Hockey Equipment',
#  'Hockey Pucks',
#  'Drum Sets & Set Components',
#  'Drum Sets',
#  'Telephones & Accessories',
#  'Puzzles',
#  'Jigsaw Puzzles',
#  'Commodore 64',
#  'Archery',
#  'Targets',
#  'Sega Master System',
#  'Chargers',
#  'Poker Layouts',
#  'Touch Screen Tablet Accessories',
#  'Skins & Decals',
#  'Other Office Equipment',
#  'Bar Code Scanners',
#  'Memory Cards',
#  'Web Design',
#  'Professional Development',
#  'Action Figures & Statues',
#  'Action Figures',
#  'Speakers',
#  'Mac Operating Systems',
#  'Looping & Remixing',
#  'CAD',
#  'Clothing',
#  'Home & Garden Design',
#  'Voice Recognition',
#  'Classical',
#  'TurboGrafx 16',
#  'Electronic Toys',
#  'Kitchen & Dining',
#  'Dining & Entertaining',
#  'Bowls',
#  'Cereal Bowls',
#  'Faceplates',
#  'Antivirus & Security',
#  'Internet Security',
#  'Car Accessories',
#  'Car Cradles & Mounts',
#  'Car Mounts',
#  'Memory Sticks',
#  'Training',
#  'Pop',
#  'Airsoft, Air Guns & Slingshots',
#  'Air Guns',
#  'Bags & Cases',
#  'Sleeves & Slipcases',
#  'MIDI',
#  'Billiards & Pool',
#  'Billiard Balls',
#  'Commodore Amiga',
#  'Painting Supplies & Wall Treatments',
#  'Wall Stickers & Murals',
#  'Table Tennis',
#  'Rackets',
#  'Video Cables',
#  'Composite Video',
#  'Coffee, Tea & Espresso',
#  'Coffee Makers',
#  'Coffee Machines',
#  'Backup',
#  'Accounting & Finance',
#  'Personal Finance',
#  'Money Management & Budgeting',
#  'Card Games',
#  'VGA Cables',
#  'PC Headsets',
#  'Streaming Media Players',
#  'eBook Readers & Accessories',
#  'Power Adapters',
#  'Travel Chargers',
#  'Blues',
#  'Grocery & Gourmet Food',
#  'Canned, Dry & Packaged Foods',
#  'Canned & Jarred Food',
#  'Soups, Stews & Chili',
#  'Ballets & Dances',
#  'Waltzes',
#  'Blank Video Media',
#  'HDMI Cables',
#  'Poker Sets',
#  'Casual Games',
#  'Baseball Equipment',
#  'Baseball Gear',
#  'Power & Hand Tools',
#  'Hand Tools',
#  'Taps & Dies',
#  'CompactFlash Cards',
#  'Keyboards',
#  'Sensor Bars',
#  'Component Video',
#  'Furniture',
#  'Home Entertainment Furniture',
#  'Media Storage',
#  'Car & Vehicle Electronics',
#  'Guitars',
#  'Single Cards',
#  'Television Stands & Entertainment Centers',
#  'Production Stations',
#  'Boating & Water Sports',
#  'Boating',
#  'Boat Plumbing',
#  'Drums',
#  'Fishing',
#  'Rod & Reel Storage',
#  'Rod Racks',
#  'Instrument Instruction',
#  'Waterskiing & Towsports',
#  'Towables',
#  'Input Devices',
#  'Numeric Keypads',
#  'Building Toys',
#  'Building Sets',
#  'Bluetooth Headsets',
#  'Strength Training Equipment',
#  'Ankle Weights',
#  'Cases',
#  'Basic Cases',
#  'Fans & Cooling',
#  'Case Fans',
#  'Soundtracks',
#  'Video Game Chairs',
#  'DVD Games',
#  'MP3 Players & Accessories',
#  'MP3 Player Accessories',
#  'I/O Port Cards',
#  'Serial Port Cards',
#  'Atari 5200',
#  'Binocular, Camera & Camcorder Straps',
#  'Digital Games & DLC',
#  'Wii U',
#  'Video Projector Accessories',
#  'Lamps',
#  'Computer Cable Adapters',
#  'Hubs',
#  'Golf',
#  'Training Equipment',
#  'Other Sports',
#  'Martial Arts',
#  'Bag Gloves',
#  'ColecoVision',
#  'Car Chargers',
#  'Home Office Furniture',
#  'Home Office Desk Chairs',
#  'Adjustable Chairs',
#  'PC Microphones',
#  'Apps for Android',
#  'Subscription Cards',
#  'Currency Cards',
#  'Light Guns',
#  'Mac Game Downloads',
#  'Interactive Gaming Figures',
#  'PlayStation 4',
#  'Cases & Sleeves',
#  '3D Glasses',
#  'Xbox One',
#  'Vehicle Electronics Accessories',
#  'Bluetooth Car Kits',
#  'MMO & Free-to-Play Games',
#  'Safety & Security',
#  'Personal Protective Equipment',
#  'Eye Protection',
#  'Safety Goggles & Glasses',
#  'Video Glasses',
#  'Business Accounting',
#  'Tax Preparation',
#  'Headphones',
#  'Systems & Accessories',
#  'Electronic Software & Books',
#  'Blu-ray Players & Recorders',
#  'Downloadable Content',
#  'Team Sports',
#  'Football',
#  'Exercise Videos',
#  'Kindle Store',
#  'Kindle Accessories',
#  'Fire TV Controllers',
#  'External Battery Packs',
#  'LIVE',
#  'Points & Currency Cards',
#  'Antivirus',
#  'Toys & Game Room',
#  'Toy Figures']

# %%
print("The number of categories is: " + str(len(categories_list_values)))
# Out:
# The number of categories is: 413

# %% [markdown]
# We have 413 categories!
#
# Even if it's possible to create 413 more binary columns for existence or non-existence of the category, it's a very inefficient method. Therefore, we will find later on another way to use the categories.
#
# One possible way is NLP Algorithms, for example - bag of words, when the number of words in the number of categories. Further research will be conducted in the next sector.

# %% [markdown]
# Yet, a small change that we can apply is to delete the nested lists, and replace them with a single list.
#
# We will do that with a lambda expression:

# %%
items_metadata_df['categories'] = items_metadata_df['categories'].apply(lambda x : x[0])

# %% [markdown]
# Now, before moving on, we will present one last time our final dataframe, after all the preprocessing:

# %%
items_metadata_df.head(5)
# Out:
#          asin                                        description  price  \
# 0  0078764343                                  Brand new sealed!  37.98
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95
# 3  0439342260  This software is BRAND NEW. Packaging may diff...    NaN
# 4  0439339960               a scholastic clubs fairs cd rom game    NaN
#
#                        categories  \
# 0  [Video Games, Xbox 360, Games]
# 1        [Video Games, PC, Games]
# 2        [Video Games, PC, Games]
# 3        [Video Games, PC, Games]
# 4        [Video Games, PC, Games]
#
#                                          also_bought bought_together  \
# 0  [B000TI836G, B003Q53VZC, B00EFFW0HC, B003VWGBC...    [B002I098JE]
# 1                                                NaN             NaN
# 2  [B000314VVU, B000PXUOTE, B00004TJCM, B0006U22X...             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#                                   buy_after_viewing  \
# 0  [B0050SY5BM, B000TI836G, B0037LTTRO, B002I098JE]
# 1  [B000067NP1, 0439573947, B00003W869, 0486406105]
# 2                          [B00004UCUS, B000YFIS00]
# 3                                               NaN
# 4                                               NaN
#
#                                          also_viewed  Video Games salesRank  \
# 0                                                NaN                28655.0
# 1  [B000067NP1, 0439573947, B00005V97H, B00004DIT...                44080.0
# 2                                                NaN                49836.0
# 3                                       [043934302X]                49156.0
# 4                                       [B00028D7TG]                52262.0
#
#    Toys & Games salesRank  ...  Cell Phones & Accessories salesRank  \
# 0                     NaN  ...                                  NaN
# 1                     NaN  ...                                  NaN
# 2                     NaN  ...                                  NaN
# 3                     NaN  ...                                  NaN
# 4                     NaN  ...                                  NaN
#
#    Camera &amp; Photo salesRank  Patio, Lawn & Garden salesRank  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    Arts, Crafts & Sewing salesRank  Industrial & Scientific salesRank  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#    Pet Supplies salesRank  Shoes salesRank  Health & Personal Care salesRank  \
# 0                     NaN              NaN                               NaN
# 1                     NaN              NaN                               NaN
# 2                     NaN              NaN                               NaN
# 3                     NaN              NaN                               NaN
# 4                     NaN              NaN                               NaN
#
#    Jewelry salesRank  Home Improvement salesRank
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                NaN                         NaN
# 3                NaN                         NaN
# 4                NaN                         NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 4.3 Attributes research (basic EDA)

# %% [markdown]
# We will split the EDA to 3 parts:
# 1. EDA of the ratings dataset
# 2. EDA of the items metadata dataset
# 3. EDA based on both datasets

# %% [markdown]
# As a reminder, we will perform the following steps for each dataset:

# %% [markdown]
# 1. Study each attribute we have in our datasets and its characteristics:
#         a. Name
#         b. Type (Categorial / Integer / text / etc.)
#         c. % of missing values
#         d. Noise of the attribute (outliers)
#         e. Usefulness analysis for our task
#         f. Data distribution
# 2. Visualize the data for further insights (continuing the EDA)
# 3. Study the possible correlation between features

# %% [markdown]
# Lastly, we will try to search for new attributes to create from the existing attributes

# %% [markdown]
# ---

# %% [markdown]
# #### 4.3.1 EDA for the ratings dataset

# %% [markdown]
# ##### 4.3.1.1 Attributes statistics

# %% [markdown]
# We will start by printing and analyzing the information about this dataset:

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1264752 entries, 0 to 1264751
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user       1264752 non-null  object
#  1   item       1264752 non-null  object
#  2   rating     1264752 non-null  float64
#  3   timestamp  1264752 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 38.6+ MB

# %% [markdown]
# And its head:

# %%
X_train.head()
# Out:
#              user        item  rating   timestamp
# 0  A35BKARXRL7XDD  B00DBCAS7E     5.0  1397088000
# 1  A1BHXHZHSLYU0P  B0007Z70YM     4.0  1315785600
# 2  A2T3KP9PIE5D9Y  B003BVIXWW     5.0  1397260800
# 3   ATDXFI4YZRGOM  B003JVCA9Q     4.0  1309996800
# 4  A13TO1ZFAH9SVN  B00005N6K3     5.0  1099958400

# %% [markdown]
# From this information we can understand many things:
# 1. All feature names are intuitive, no more explanation needed - user and items are ID's, rating is a value, and timestamp is intuitive as well.
# 2. All types except the timestamp fit what we would expect. The timestamp could have been in a date format, but instead in an "int" format.
# 3. No missing values exist! Soon we will look for outliers to find out if the all values were inserted correctly

# %% [markdown]
# Now we will try to find some more information about the attributes:

# %%
X_train.describe()
# Out:
#              rating     timestamp
# count  1.264752e+06  1.264752e+06
# mean   3.975340e+00  1.300276e+09
# std    1.385525e+00  1.087819e+08
# min    1.000000e+00  8.789472e+08
# 25%    3.000000e+00  1.254182e+09
# 50%    5.000000e+00  1.348099e+09
# 75%    5.000000e+00  1.380413e+09
# max    5.000000e+00  1.406074e+09

# %% [markdown]
# From the table above we start finding interesting information:
# 1. Ratings mean is almost 4 in value, and The median is 5.0 score (which is the maximum score!). Which means that more then half of our ratings are the maximum ratings. Only less then 50% of our data is between 1-4.
# 2. For the timestamp, mean and median are similar (around ~1.3), but the median is much closer to the maximum value rather then the minimal value. That might be because more ratings were collected as time passed by, and more customers joined our company.

# %% [markdown]
# As a rule of thumb, the timestamp does not seem like a usefull attribute to our data, **and it will be easier for us to assume that customer preferences does not change with time.**

# %% [markdown]
# ---

# %% [markdown]
# ##### 4.3.1.2 Attributes visualizations

# %% [markdown]
# Now, we will start plotting some graphs to look at the data distribution and analyze its meaning:

# %%
# Using matplotlib + pandas functionality
import matplotlib.pyplot as plt

# %% [markdown]
# We will start with using the pandas "hist" function:

# %%
# Plot the ratings distribution w. many bins to make sure what the values are
X_train['rating'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From this histogram we can infer that indeed most ratings are 5.0, and much less are less than the maximum value. **Data almost fits the geometric distribution, except the "1" score**.
#
# Also, we can see that the value is indeed discreet - 5 different values, between 1 to 5.

# %%
X_train['timestamp'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here as well the data fits geometric distribution. Yet as we explained before, this might be affected from the popularity of our store, and does not represent a change in customer behavior.

# %% [markdown]
# Next, we would like to try and get some more info about our items, and about our users.
#
# We will plot 4 different graphs:
# 1. Group users by amount of items rated
# 2. Group users by mean rating score
# 3. Group items by amount of users rated them
# 4. Group items by mean rating score

# %% [markdown]
# ---

# %% [markdown]
# **Group users by amount of items rated:**

# %% [markdown]
# The following histogram maps the number of users by numbers of ratings per user:
#
# 1. X axis - number of ratings
# 2. Y axis - number of users with this number of ratings

# %%
X_train['user'].value_counts().hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Many users (800,000+) rated only a small amount of products. **This will help us in future planning of the required algorithms**.

# %% [markdown]
# We will calculate the amount of distinct users:

# %%
unique_users = X_train['user'].nunique()
print(f"Number of unique users is: {unique_users}")
# Out:
# Number of unique users is: 826767

# %% [markdown]
# Out of the number of ratings:

# %%
m = X_train.shape[0]
print(f"Number of ratings are: {m}")
# Out:
# Number of ratings are: 1264752

# %% [markdown]
# By basic combinatorical concepts, we can understand (as we've seen in section 3) that most of our users, and therefore our data, consists of users with only very few ratings.
#
# We will plot the graph above without users rating only one item, to make the histogram more readable:

# %%
X_train[X_train.groupby('user').user.transform('count') > 1]['user'].value_counts().hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Even now, we can see that most users have The least amount of ratings.
#
# We will simply print the number of users for each amount of ratings to the scree, **instead of using the graphs which are harder to see**:

# %%
# copy the X_train
ratings_data = X_train.copy()

# calc number of ratings for each user and add to the new df:
ratings_data['ratings number'] = X_train.groupby('user').user.transform('count')

ratings_data.head()
# Out:
#              user        item  rating   timestamp  ratings number
# 0  A35BKARXRL7XDD  B00DBCAS7E     5.0  1397088000               4
# 1  A1BHXHZHSLYU0P  B0007Z70YM     4.0  1315785600               6
# 2  A2T3KP9PIE5D9Y  B003BVIXWW     5.0  1397260800              17
# 3   ATDXFI4YZRGOM  B003JVCA9Q     4.0  1309996800               9
# 4  A13TO1ZFAH9SVN  B00005N6K3     5.0  1099958400              13

# %%
# group by number of ratings, and count only uniques:
count_per_ratings = ratings_data.groupby('ratings number')['user'].nunique()

count_per_ratings
# Out:
# ratings number
# 1      636867
# 2      105627
# 3       36355
# 4       26317
# 5        5609
#         ...
# 379         1
# 417         1
# 637         1
# 653         1
# 704         1
# Name: user, Length: 127, dtype: int64

# %% [markdown]
# As we can see above, numbers are falling drasticaly in each increase of ratings number.
#
# In order to plot a relevant graph that is easier to understand, we will try to plot the **logarithm of the values, in order to show the change in order of magnitudes**.

# %%
# implement numpy's logarithm
np.log(count_per_ratings).plot(use_index=True)
# Out:
# <AxesSubplot:xlabel='ratings number'>

# %% [markdown]
# From the graph above we can understand that number of ratings per user drops exponentialy until the 50-100 ratings range, in which the graph is more linear. For 100+ ratings, we have only a single user with that amount of ratings (since the value of log(1) is zero)
#
# That is because a logarithmic graph **plots the percentage of change, instead of the absolute value**.

# %% [markdown]
# ---

# %% [markdown]
# **Group users by mean rating score:**

# %% [markdown]
# We will perform similar steps to above, first calculating the avg. score each user gives:

# %%
# group by average score of user:
ratings_data['avg_user_rating'] = ratings_data.groupby('user').rating.transform('mean')

ratings_data.head()
# Out:
#              user        item  rating   timestamp  ratings number  \
# 0  A35BKARXRL7XDD  B00DBCAS7E     5.0  1397088000               4
# 1  A1BHXHZHSLYU0P  B0007Z70YM     4.0  1315785600               6
# 2  A2T3KP9PIE5D9Y  B003BVIXWW     5.0  1397260800              17
# 3   ATDXFI4YZRGOM  B003JVCA9Q     4.0  1309996800               9
# 4  A13TO1ZFAH9SVN  B00005N6K3     5.0  1099958400              13
#
#    avg_user_rating
# 0         3.750000
# 1         2.833333
# 2         4.823529
# 3         3.555556
# 4         4.692308

# %% [markdown]
# Now we will plot both the histogram of the average ratings per user, and then the histogram of the ratings itself (which was presented above as well)

# %%
# user average ratings histogram : by counting each user only once
ratings_data.drop_duplicates(subset='user', keep='last')['avg_user_rating'].hist()
# Out:
# <AxesSubplot:>

# %%
# average rating histogram
ratings_data['rating'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We see almost no differences in the histograms, except decrease of numbers because of duplicates.
#
# We can infer that most ratings users gave to items are good and not bad.

# %% [markdown]
# We get an interesting histogram when we cut it to 100+ bins:

# %%
ratings_data.drop_duplicates(subset='user', keep='last')['avg_user_rating'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We see very high peeks in the 1,2,3,4,5 values, and that is because of users with only a single rating.
#
# This makes us understand, that maybe **the distrubtion of users with higher amount of ratings, are different**. In other words, maybe we have many positive ratings because we are looking at users with a small amount of ratings.
#
# **Now we will view the histogram of users with only 15+ ratings**. 15 Was chosen by the logarithmic graph we presented above - 15 is where the gradient start decreasing in value.

# %%
# keep only users with 15+ ratings:
MIN_RATINGS = 15
ratings_data[ratings_data['ratings number'] > MIN_RATINGS].drop_duplicates(subset='user')['avg_user_rating'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **And now we finally got some interesting results!!**
#
# By removing the outliers with small amount of ratings, we get a distribution that is more similar to a normal distribution. **An interesting conclusion is that data distributes not on the median score (which is 3), but around 4 - users yet tend to give more than average score to items**. And we need to remember that during training.
#
# Our dataset is much (much) smaller, but might be much better at predicting actual results.

# %%
# Viewing that dataframe with more bins:
ratings_data[ratings_data['ratings number'] > MIN_RATINGS].drop_duplicates(subset='user')['avg_user_rating'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Now we see the same histogram with more bins, for better view of the distribution, **which looks like a normal distribution excep the long 1.5-3.5 values "tail".**

# %% [markdown]
# ---

# %% [markdown]
# **Group items by amount of users rated them**

# %% [markdown]
# Now, we will plot graphs focused on the items and not on the users - with similar graphs:

# %%
ratings_data['item'].value_counts().hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The following histogram amove maps the number of items by numbers of ratings per item:
#
# 1. X axis - number of ratings
# 2. Y axis - number of items with this number of ratings

# %% [markdown]
# We see a similar distribution to what we've seeb before: **Most items are rated only a small number of times.**

# %% [markdown]
# We will view that number with a simple calculation:

# %%
# add column of "item ratings":
ratings_data['item_ratings'] = ratings_data.groupby('item')['item'].transform('count')

# group by number of ratings, and count only uniques:
count_per_items = ratings_data.groupby('item_ratings')['item'].nunique()

count_per_items
# Out:
# item_ratings
# 1        11098
# 2         6114
# 3         3911
# 4         2943
# 5         2229
#          ...
# 5090         1
# 5487         1
# 5711         1
# 7392         1
# 16198        1
# Name: item, Length: 680, dtype: int64

# %% [markdown]
# We can see here also a very steep decrease in ratings amount:
# 1. 11,098 items were rated only once
# 2. About half of it (6114) were rated twice
# 3. The number keep decreasing exponentialy

# %% [markdown]
# Plotting again the logarithmic graph for the **change in order of magnitudes:**

# %%
np.log(count_per_items).plot(use_index=True)
# Out:
# <AxesSubplot:xlabel='item_ratings'>

# %% [markdown]
# And we got an even steeper curve than before (the users logarithmic curve).

# %% [markdown]
# **Group items by mean rating score:**

# %% [markdown]
# Now we will perform the opposite mean rating calculation - on the items instead of on the users:

# %%
# Create a column for the items ratings
ratings_data['avg_item_rating'] = ratings_data.groupby('item').rating.transform('mean')

# %% [markdown]
# Let's peek at out new dataframe's column:

# %%
ratings_data.head()
# Out:
#              user        item  rating   timestamp  ratings number  \
# 0  A35BKARXRL7XDD  B00DBCAS7E     5.0  1397088000               4
# 1  A1BHXHZHSLYU0P  B0007Z70YM     4.0  1315785600               6
# 2  A2T3KP9PIE5D9Y  B003BVIXWW     5.0  1397260800              17
# 3   ATDXFI4YZRGOM  B003JVCA9Q     4.0  1309996800               9
# 4  A13TO1ZFAH9SVN  B00005N6K3     5.0  1099958400              13
#
#    avg_user_rating  item_ratings  avg_item_rating
# 0         3.750000            20         3.550000
# 1         2.833333            67         3.208955
# 2         4.823529            39         2.333333
# 3         3.555556          1115         3.496861
# 4         4.692308           342         4.438596

# %% [markdown]
# And build a histogram based on these ratings:

# %%
ratings_data['avg_item_rating'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# What we find interesting about this distribution, is that it is different from the average user ratings distribution. when we limited ourself to users with 15+ ratings. **The main difference is that the mean is higher in this histogram (closer to 4.5) than the previous user histogram (closer to 4).
#
# **Our explanation for this difference is dropping the users with small amount of ratings, mostly with high score ratings.** Their ratings increase the mean ratings of items, and moves the histogram's mean to the right (higher value).

# %% [markdown]
# ---

# %% [markdown]
# #### 4.3.2 EDA for the items dataset

# %% [markdown]
# ##### 4.3.2.1 Attributes statistics

# %% [markdown]
# We will start again by printing and analyzing the information about our dataset. We already made some changes to this dataframe in the previous part (4.1)

# %%
items_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50953 entries, 0 to 50952
# Data columns (total 31 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   asin                                 50953 non-null  object
#  1   description                          47063 non-null  object
#  2   price                                43905 non-null  float64
#  3   categories                           50953 non-null  object
#  4   also_bought                          28965 non-null  object
#  5   bought_together                      20654 non-null  object
#  6   buy_after_viewing                    39905 non-null  object
#  7   also_viewed                          14839 non-null  object
#  8   Video Games salesRank                45278 non-null  float64
#  9   Toys & Games salesRank               148 non-null    float64
#  10  Software salesRank                   2236 non-null   float64
#  11  Electronics salesRank                757 non-null    float64
#  12  Movies & TV salesRank                22 non-null     float64
#  13  Music salesRank                      12 non-null     float64
#  14  Sports &amp; Outdoors salesRank      36 non-null     float64
#  15  Home &amp; Kitchen salesRank         26 non-null     float64
#  16  Computers & Accessories salesRank    10 non-null     float64
#  17  Musical Instruments salesRank        9 non-null      float64
#  18  Kitchen & Dining salesRank           2 non-null      float64
#  19  Beauty salesRank                     2 non-null      float64
#  20  Clothing salesRank                   41 non-null     float64
#  21  Cell Phones & Accessories salesRank  17 non-null     float64
#  22  Camera &amp; Photo salesRank         14 non-null     float64
#  23  Patio, Lawn & Garden salesRank       2 non-null      float64
#  24  Arts, Crafts & Sewing salesRank      4 non-null      float64
#  25  Industrial & Scientific salesRank    2 non-null      float64
#  26  Pet Supplies salesRank               1 non-null      float64
#  27  Shoes salesRank                      2 non-null      float64
#  28  Health & Personal Care salesRank     4 non-null      float64
#  29  Jewelry salesRank                    1 non-null      float64
#  30  Home Improvement salesRank           1 non-null      float64
# dtypes: float64(24), object(7)
# memory usage: 12.1+ MB

# %% [markdown]
# And the dataframe's head:

# %%
items_metadata_df.head()
# Out:
#          asin                                        description  price  \
# 0  0078764343                                  Brand new sealed!  37.98
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95
# 3  0439342260  This software is BRAND NEW. Packaging may diff...    NaN
# 4  0439339960               a scholastic clubs fairs cd rom game    NaN
#
#                        categories  \
# 0  [Video Games, Xbox 360, Games]
# 1        [Video Games, PC, Games]
# 2        [Video Games, PC, Games]
# 3        [Video Games, PC, Games]
# 4        [Video Games, PC, Games]
#
#                                          also_bought bought_together  \
# 0  [B000TI836G, B003Q53VZC, B00EFFW0HC, B003VWGBC...    [B002I098JE]
# 1                                                NaN             NaN
# 2  [B000314VVU, B000PXUOTE, B00004TJCM, B0006U22X...             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#                                   buy_after_viewing  \
# 0  [B0050SY5BM, B000TI836G, B0037LTTRO, B002I098JE]
# 1  [B000067NP1, 0439573947, B00003W869, 0486406105]
# 2                          [B00004UCUS, B000YFIS00]
# 3                                               NaN
# 4                                               NaN
#
#                                          also_viewed  Video Games salesRank  \
# 0                                                NaN                28655.0
# 1  [B000067NP1, 0439573947, B00005V97H, B00004DIT...                44080.0
# 2                                                NaN                49836.0
# 3                                       [043934302X]                49156.0
# 4                                       [B00028D7TG]                52262.0
#
#    Toys & Games salesRank  ...  Cell Phones & Accessories salesRank  \
# 0                     NaN  ...                                  NaN
# 1                     NaN  ...                                  NaN
# 2                     NaN  ...                                  NaN
# 3                     NaN  ...                                  NaN
# 4                     NaN  ...                                  NaN
#
#    Camera &amp; Photo salesRank  Patio, Lawn & Garden salesRank  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    Arts, Crafts & Sewing salesRank  Industrial & Scientific salesRank  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#    Pet Supplies salesRank  Shoes salesRank  Health & Personal Care salesRank  \
# 0                     NaN              NaN                               NaN
# 1                     NaN              NaN                               NaN
# 2                     NaN              NaN                               NaN
# 3                     NaN              NaN                               NaN
# 4                     NaN              NaN                               NaN
#
#    Jewelry salesRank  Home Improvement salesRank
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                NaN                         NaN
# 3                NaN                         NaN
# 4                NaN                         NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# Our first conclusion is that we are missing most values from our new columns we made on the previous part!
#
# Some columns has only 1 value out of 50,000+ rows!

# %% [markdown]
# We have 2 options:
# 1. Delete all columns 9-30
# 2. Try to use the data in a different way

# %% [markdown]
# Since almost all items (90%+) has a Video Games rank, we can ignore the items that have another ranking in another category, and simply delete those columns for now. (We will remove them later in the preprocessing part)
#
# We have enoguh data in the existing columns to use for the items predictions.

# %% [markdown]
# Our next conclusion from looking at the data information, is that in opposite of the previous dataset (ratings), **here we have missing values in almost all attributes.**
#
# Yet, except the attributes:
# 1. also_bought
# 2. bought_together
# 3. buy_after_viewing
# 4. also_viewed
#
# (Which were created by us before)
#
# **Almost all other attributes have 90%+ of existing values.**
#
# Next we will analyze their usefulness for our task, and decide how to impute the missing values for our goal.

# %% [markdown]
# ---

# %% [markdown]
# #### 4.3.2.2 Attributes visualizations

# %% [markdown]
# Now we will try to plot each one of our attributes to get some more insights for our analysis.
#
# **We will start with the "price" attribute:**

# %%
items_metadata_df['price'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see a geometric destribution, with most items between the 0-100 level price. **This is reasonable, since video games should be at this price range.**
#
# We will try to see the distrubtion inside the 0-100 range:

# %%
MAX_PRICE = 100

items_metadata_df[items_metadata_df['price'] < MAX_PRICE]['price'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We see that even here, the distribution is geometric - almost all games are between the 0-20 price range, and very few are higher than 50$ per item.

# %% [markdown]
# Now we will try to find a more interesting connection, and plot the distribution of items only rated above a score of 4.5.
#
# Later we will look for concrete correlation between price and score.

# %%
# View only items rated more than 4.5, without all the duplicates
top_rated_items = ratings_data[ratings_data['avg_item_rating'] > 4.5]['item'].drop_duplicates()

# Get only the metadata of the top rated items, and plot their price
items_metadata_df.loc[items_metadata_df['asin'].isin(top_rated_items)]['price'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Distribution seems the same, which most items are in the 0-100 price range. We will try one more time to limit ourself to the 0-100 price range:

# %%
# Implementing both item's rating condition, and price condition
items_metadata_df.loc[(items_metadata_df['asin'].isin(top_rated_items)) & (items_metadata_df['price'] < 100)]['price'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Even here, we get a very similar distriution, which indicates that price is probably not a very good indicator for the average score.

# %% [markdown]
# **Next, the description attribute:**

# %% [markdown]
# Since the description is from type **string**, we can't visualize specific parameters about the text.
#
# Yet, we will do 2 things:
# 1. Plot the lengths of the descriptions
# 2. Plot the most common words that appear in the text

# %%
# Save the description's length in a dataframe
description_lengths = items_metadata_df['description'].apply(lambda x : len(str(x)))

# %%
description_lengths.hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that most descriptions are short, and very few are more then 3000 characters.
#
# We will try to plot the histogram again, and now to ignore the empty descriptions:

# %%
description_lengths[description_lengths > 0].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The difference is small, in around 5,000 descriptions which are empty.
#
# Although the disptibution fits the geometric distribution, we can view the 5,000+ chars descriptions as outliers, and consider it later in the training.

# %% [markdown]
# Now we will look for the 100 most common words. In order to do so, we will have to perform basic preprocess to our description column, implementing NLP transformations learned in the course:

# %%
# import nltk for NLP preprocess + downloads the required dictionaries
import nltk
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
# for iterating the text
import collections
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Now we try to get the top 100 words from all the description column:

# %%
collections.Counter(" ".join(items_metadata_df["description"]).split()).most_common(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-9b83a5fd5f67> in <module>
# ----> 1 collections.Counter(" ".join(items_metadata_df["description"]).split()).most_common(100)
#
# TypeError: sequence item 15: expected str instance, float found

# %% [markdown]
# We see that not all values exist, and instead we have floats in the dataframe - **which are the NaN values**.
#
# For now, we will create a copy of the text, and manipulate it for the visualizations. Later we will probably use some of these manipulations for the training as well.

# %%
# copy the descriptions
descriptions = items_metadata_df['description']

# %%
# Conver the "nan" values to empty strings
def convert_description_nan(x):
    return '' if pd.isna(x) else x

descriptions = descriptions.apply(convert_description_nan)

# %% [markdown]
# Now we will implement it again:

# %%
collections.Counter(" ".join(descriptions).split()).most_common(100)
# Out:
# [('the', 251091),
#  ('and', 181442),
#  ('of', 127270),
#  ('to', 125895),
#  ('a', 98022),
#  ('in', 67139),
#  ('your', 58211),
#  ('with', 55950),
#  ('you', 49827),
#  ('for', 46631),
#  ('is', 42075),
#  ('on', 31825),
#  ('as', 31475),
#  ('The', 29226),
#  ('that', 27889),
#  ('game', 25798),
#  ('or', 25726),
#  ('from', 24964),
#  ('are', 22705),
#  ('an', 20578),
#  ('new', 19897),
#  ('can', 19109),
#  ('will', 18436),
#  ('by', 15707),
#  ('all', 15010),
#  ('be', 14201),
#  ('this', 13898),
#  ('-', 12895),
#  ('it', 12763),
#  ('up', 12041),
#  ('their', 11956),
#  ('have', 11534),
#  ('more', 11311),
#  ('at', 10890),
#  ('players', 10567),
#  ('into', 10241),
#  ('has', 10022),
#  ('through', 9008),
#  ('one', 8866),
#  ('play', 8730),
#  ('out', 7807),
#  ('This', 7804),
#  ('his', 7693),
#  ('most', 7420),
#  ('not', 7345),
#  ('Xbox', 7308),
#  ('games', 7133),
#  ('over', 6907),
#  ('but', 6843),
#  ('world', 6787),
#  ('like', 6678),
#  ('they', 6521),
#  ('other', 6414),
#  ('also', 6141),
#  ('which', 6089),
#  ('Nintendo', 6040),
#  ('any', 6001),
#  ('than', 6001),
#  ('Wii', 5906),
#  ('take', 5885),
#  ('its', 5796),
#  ('each', 5669),
#  ('features', 5652),
#  ('them', 5572),
#  ('time', 5521),
#  ('In', 5403),
#  ('action', 5369),
#  ('You', 5351),
#  ('only', 5319),
#  ('own', 5260),
#  ('including', 5258),
#  ('use', 5170),
#  ('2', 5153),
#  ('experience', 5091),
#  ('get', 4975),
#  ('against', 4945),
#  ('unique', 4932),
#  ('control', 4925),
#  ('different', 4925),
#  ('even', 4869),
#  ('while', 4814),
#  ('Game', 4787),
#  ('way', 4780),
#  ('/>', 4763),
#  ('player', 4736),
#  ('no', 4709),
#  ('With', 4678),
#  ('where', 4624),
#  ('make', 4470),
#  ('when', 4450),
#  ('360', 4450),
#  ('first', 4417),
#  ('just', 4372),
#  ('who', 4354),
#  ('A', 4270),
#  ('controller', 4235),
#  ('so', 4233),
#  ('two', 4190),
#  ('must', 4084),
#  ('gameplay', 4021)]

# %% [markdown]
# And we got our top 100 words! the problem is that most of these words are in fact 'stopwords' - words that don't help us understand anything about the sentence.
#
# Therefore, we will have to remove them in advance, and then apply the calculation again.
#
# We will have to do 2 things:
# 1. Convert the text to lists holding the different words
# 2. Removing the stopwords

# %%
# Convert to list of words
descriptions = descriptions.apply(lambda text : nltk.word_tokenize(text))

# %%
# view top descriptions:
descriptions.head()
# Out:
# 0                              [Brand, new, sealed, !]
# 1    [In, Stock, NOW, ., Eligible, for, FREE, Super...
# 2    [Grandma, Groupers, kelp, seeds, are, missing,...
# 3    [This, software, is, BRAND, NEW, ., Packaging,...
# 4         [a, scholastic, clubs, fairs, cd, rom, game]
# Name: description, dtype: object

# %%
# stopwords corpus
english_stopwords = stopwords.words('english')

# %%
# Remove stopwords: (this will take a few minutes, since our corpus is huge)
descriptions = descriptions.apply(lambda text : [word for word in text if not word in english_stopwords])

# %%
# view the head again:
descriptions.head()
# Out:
# 0                              [Brand, new, sealed, !]
# 1    [In, Stock, NOW, ., Eligible, FREE, Super, Sav...
# 2    [Grandma, Groupers, kelp, seeds, missing, with...
# 3    [This, software, BRAND, NEW, ., Packaging, may...
# 4            [scholastic, clubs, fairs, cd, rom, game]
# Name: description, dtype: object

# %% [markdown]
# Now, we will try implementing it again to get some insights about the most common words:

# %%
descriptions = descriptions.apply(lambda words_list : " ".join(words_list))

# %%
# no need to split the descriptions again, since we already split it to lists
collections.Counter(" ".join(descriptions).split()).most_common(100)
# Out:
# [(',', 261965),
#  ('.', 180679),
#  (':', 68297),
#  (';', 62999),
#  ("''", 50700),
#  ('&', 42226),
#  ('game', 33854),
#  ('The', 31300),
#  ("'s", 30076),
#  ('!', 29979),
#  ('new', 20407),
#  ('#', 18714),
#  (')', 17742),
#  ('(', 17665),
#  ('-', 13210),
#  ('nbsp', 12918),
#  ('players', 11950),
#  ('play', 11131),
#  ('games', 10976),
#  ('false', 10820),
#  ('world', 10577),
#  ('``', 10082),
#  ('one', 9576),
#  ('--', 8658),
#  ('2', 8281),
#  ('This', 8170),
#  ('Xbox', 8102),
#  ('time', 7880),
#  ('You', 7314),
#  ('experience', 7294),
#  ('/', 7245),
#  ('action', 7119),
#  ('like', 6904),
#  ('Wii', 6793),
#  ('features', 6618),
#  ('Nintendo', 6579),
#  ('?', 6273),
#  ('way', 6273),
#  ('also', 6195),
#  ('It', 6170),
#  ('>', 6012),
#  ('3', 5976),
#  ('system', 5954),
#  ('<', 5942),
#  ('take', 5926),
#  ('including', 5823),
#  ('characters', 5746),
#  ('player', 5727),
#  ('use', 5665),
#  ('control', 5661),
#  ('In', 5625),
#  ('gameplay', 5570),
#  ('1', 5532),
#  ('controller', 5495),
#  ('Game', 5296),
#  ('360', 5294),
#  ("n't", 5261),
#  ('mode', 5180),
#  ('unique', 5107),
#  ('get', 5070),
#  ("'ll", 5066),
#  ('*', 5064),
#  ('different', 5025),
#  ('even', 4991),
#  ('With', 4929),
#  ('fun', 4755),
#  ('A', 4750),
#  ('w', 4741),
#  ('first', 4677),
#  ('make', 4543),
#  ('battle', 4540),
#  ('two', 4335),
#  ('online', 4198),
#  ('friends', 4189),
#  ('gaming', 4182),
#  ('weapons', 4179),
#  ('{', 4167),
#  ('}', 4167),
#  ('adventure', 4140),
#  ('series', 4137),
#  ('back', 4134),
#  ('must', 4105),
#  ('levels', 3997),
#  ('LsdException', 3973),
#  ('Locked=', 3973),
#  ('Name=', 3973),
#  ('multiplayer', 3916),
#  ('Priority=', 3915),
#  ('graphics', 3911),
#  ('set', 3890),
#  ('well', 3758),
#  ('find', 3732),
#  ('power', 3732),
#  ('combat', 3599),
#  ("'", 3595),
#  ('original', 3579),
#  ('character', 3568),
#  ('help', 3542),
#  ('best', 3509),
#  ('modes', 3488)]

# %% [markdown]
# It's interesting to see that most common words are charcters in sentences that are irrelevant to the sentence like "," or ".".
#
# We will try to look at the real words in our most common list to look for some insights. Some of the most interesting words are like "players", "graphics", "action" and "PlayStation", that give us some info about the most common video games - They might be related to multiplayer games, in the "action games" category, the graphics as an importent aspect, and PlayStation as a common consule.

# %% [markdown]
# **Lastly, we will check the salesRank attribute**

# %% [markdown]
# First we will plot the histogram of the sales Ranking of the videoGames. We are likely to see a flat distribution - given that we are analyzing all the items in the video games category:

# %%
# Plot the average sales Rank in the videoGames category
items_metadata_df['Video Games salesRank'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Here we get something interesting!**
#
# It seems like in the first 20,000 games we got all the rankings - each bar in the histogram is about 10,000 rankings, for the first two bars.
#
# Yet, we can see that:
# 1. **As the items become worse, their ranking amount drops** - meaning that we are missing more items
# 2. **There are more than 120,000 rankings!** - which means that our database does not hold all the possible video games that exist.

# %% [markdown]
# **Correlation**

# %% [markdown]
# At the end of the EDA, We will try to look for correlation between the Video Games salesRank, and the price of an item.
#
# It won't give us concrete conclusions about the preferences of each user, but will give us an idea about how the two features behave.

# %% [markdown]
# We will use the "corr" method in pandas for that calculation:

# %%
items_metadata_df['price'].corr(items_metadata_df['Video Games salesRank'])
# Out:
# -0.1235766859394814

# %% [markdown]
# We can see a very low correlation between the two, and a negative one - which was expected (When price is lower, the item is preferable)

# %% [markdown]
# When we try to plot the correlation we get a messy scatter plot that indicated that **the correlation is indeed very low (and negative)**:

# %%
items_metadata_df.plot(kind='scatter', x='price', y='Video Games salesRank', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Video Games salesRank'>

# %% [markdown]
# **Feature Engineering**

# %% [markdown]
# By understanding the data above, we can think of two new features we can add to the dataframe:
# 1. Description length - which might be related to how many people buy and like a product they understand (Our guess - the longer the description, the higher the rank will be)
# 2. Multiply the price and the salesRank score - since there is only small correlation between the two - a combined feature of them might be a strong feature in the process

# %% [markdown]
# **Note on feature engineering and the last 4 columns:**
#
# We didn't analyze the 4 attributes left in the metadata column yet: viewed, bought, bought together, etc.
#
# We will keep them to the 7th section, when we will use them in the data fine tuning process **with clustering implementation on the data for more features creation and for better results**. We don't do it now because it's much harder and we should implement it only when we have more information about our data and basic models results.

# %% [markdown]
# #### 4.3.3 EDA Conclusions

# %% [markdown]
# **Ratings dataframe**:
# 1. **Most items and most users rated items between 1-5 times**.
# 2. **Users with small amount of ratings tend to rate only products (items) they like (5 stars)**, and not products they hate (e.g. a user will register to the service to rate something he liked, and not something he didn't like).
# 3. **Users with bigger number of ratings tend to have a normal distribution of their ratings**, where ~4 is the mean rating.
# 4. Our mean rating is higher than the average, and **that is probably because of many user with very high ratings.**
#
# **Items Dataframe**:
# 1. Most salesRank data about the other categories is useless, **because it's almost entirly missing.**
# 2. Most items are cheap (0-20 budget), and by analyzing the two histograms of top rated items prices and all items prices, it **doesn't seems like there is a correlation between the price of an item and its average rating.**
# 3. Most descriptions are short, and no special words were found in the counter analysis.
# 4. We have more than 50,000 items in total by the salesRank category, so we have many missing items - most of them are not rated as top rated items: **It will probably be harder for us to predict ratings for items with lower rank sales**

# %% [markdown]
# ## 5. Data Preperation

# %% [markdown]
# In this section, we will perform the following steps:
# 1. Remove columns and features we decided are not relevant for us
# 2. Fill in missing values for some of the attributes
# 3. Create the new features we decided on the feature engineering section, and add more transformations of the data

# %% [markdown]
# ### 5.1 Features removal

# %% [markdown]
# #### 5.1.1 The ratings dataframe

# %% [markdown]
# As explained, the 'timestamp' column is irrelevant for us. Yet, **we won't remove it since it is required as a field in most recommendation system algorithms.** So for simpler implementation only we will keep this column.

# %% [markdown]
# #### 5.1.2 The items dataframe

# %% [markdown]
# All salesRank columns except the video games column are irrelevant.
#
# Therefore, we will remove them now:

# %%
# Using the sales_keys_columns from section 4, we will drop the 'Video Games' from it and then remove all other columns
new_sales_dict_keys.remove('Video Games salesRank')

# %%
# Remove all the columns
items_metadata_df = items_metadata_df.drop(new_sales_dict_keys, axis=1)

# %% [markdown]
# And the dataframe after the removal:

# %%
items_metadata_df.head()
# Out:
#          asin                                        description  price  \
# 0  0078764343                                  Brand new sealed!  37.98
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95
# 3  0439342260  This software is BRAND NEW. Packaging may diff...    NaN
# 4  0439339960               a scholastic clubs fairs cd rom game    NaN
#
#                        categories  \
# 0  [Video Games, Xbox 360, Games]
# 1        [Video Games, PC, Games]
# 2        [Video Games, PC, Games]
# 3        [Video Games, PC, Games]
# 4        [Video Games, PC, Games]
#
#                                          also_bought bought_together  \
# 0  [B000TI836G, B003Q53VZC, B00EFFW0HC, B003VWGBC...    [B002I098JE]
# 1                                                NaN             NaN
# 2  [B000314VVU, B000PXUOTE, B00004TJCM, B0006U22X...             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#                                   buy_after_viewing  \
# 0  [B0050SY5BM, B000TI836G, B0037LTTRO, B002I098JE]
# 1  [B000067NP1, 0439573947, B00003W869, 0486406105]
# 2                          [B00004UCUS, B000YFIS00]
# 3                                               NaN
# 4                                               NaN
#
#                                          also_viewed  Video Games salesRank
# 0                                                NaN                28655.0
# 1  [B000067NP1, 0439573947, B00005V97H, B00004DIT...                44080.0
# 2                                                NaN                49836.0
# 3                                       [043934302X]                49156.0
# 4                                       [B00028D7TG]                52262.0

# %% [markdown]
# ### 5.2  Complete missing values

# %% [markdown]
# The ratings dataframe does not miss any value, as we've seen above in section 4.
#
# Let's see again what is missing from our items dataframe:

# %%
items_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50953 entries, 0 to 50952
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   asin                   50953 non-null  object
#  1   description            47063 non-null  object
#  2   price                  43905 non-null  float64
#  3   categories             50953 non-null  object
#  4   also_bought            28965 non-null  object
#  5   bought_together        20654 non-null  object
#  6   buy_after_viewing      39905 non-null  object
#  7   also_viewed            14839 non-null  object
#  8   Video Games salesRank  45278 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 3.5+ MB

# %% [markdown]
# Categories: also_bought, bought_together, buy_after_viewing and also_viewed will be prepared later in the clustering part.
#
# We are left with 3 relevant missing categories:
# 1. Description
# 2. Price
# 3. Video Games salesRank

# %% [markdown]
# #### 5.2.1 Description missing values

# %% [markdown]
# We will fill the missing values as we've done in section 4 - switch the 'nan' values with an empty description string:

# %%
# Using lambda expression
items_metadata_df['description'] = items_metadata_df['description'].apply(lambda text : '' if pd.isna(text) else text)

# %% [markdown]
# Let's see that now we don't have any missing values:

# %%
items_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50953 entries, 0 to 50952
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   asin                   50953 non-null  object
#  1   description            50953 non-null  object
#  2   price                  43905 non-null  float64
#  3   categories             50953 non-null  object
#  4   also_bought            28965 non-null  object
#  5   bought_together        20654 non-null  object
#  6   buy_after_viewing      39905 non-null  object
#  7   also_viewed            14839 non-null  object
#  8   Video Games salesRank  45278 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 3.5+ MB

# %% [markdown]
# All description fields are full, as required.

# %% [markdown]
# #### 5.2.2 Price missing values

# %% [markdown]
# Since we know that most prices are in the 0-20 range, and that this attribute is numerical, we will use the Imputer in "Sklearn" to insert the mean price for each missing value:

# %%
from sklearn.impute import SimpleImputer

# %%
# Define the imputer strategy - mean
imputer = SimpleImputer(missing_values=np.NaN, strategy='mean')

# %%
# calculate the mean impute and add it to the column
items_metadata_df['price'] = imputer.fit_transform(np.array(items_metadata_df['price']).reshape(-1,1))

# %% [markdown]
# And let's check again that the price column is now full:

# %%
items_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50953 entries, 0 to 50952
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   asin                   50953 non-null  object
#  1   description            50953 non-null  object
#  2   price                  50953 non-null  float64
#  3   categories             50953 non-null  object
#  4   also_bought            28965 non-null  object
#  5   bought_together        20654 non-null  object
#  6   buy_after_viewing      39905 non-null  object
#  7   also_viewed            14839 non-null  object
#  8   Video Games salesRank  45278 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 3.5+ MB

# %% [markdown]
# It has 50,593 values as expected.

# %% [markdown]
# #### 5.2.3 salesRank missing values

# %% [markdown]
# We will use a similar strategy for the salesRank as we've used for the price attribute, but with one big change.
#
# We know that most of the first 20,000 items already has a rank, but from then on, many items are missing a rank. When calculated, we can see that the mean salesRank is about ~35,000 in value:

# %%
print(f"The mean value of the salesRank attribute is: {items_metadata_df['Video Games salesRank'].mean()}.")
# Out:
# The mean value of the salesRank attribute is: 35478.28232254075.

# %% [markdown]
# The only problem with taking the mean value for all the missing fields, is that all of them will get the same rank, and we won't be able to compare them to one another if we would like to do so later in the training.
#
# Therefore, we will implement by ourself a more complex imputation strategy, and we will impute values from a normal distribution with a mean of the current mean:

# %%
# mean calculated
MU_SALES_RANK = items_metadata_df['Video Games salesRank'].mean()

# standard deviation, approx. according to the visualizations in section 4
SIGMA_SALES_RANK = 5000

def mean_dist_imputation(value):
    if pd.isna(value):
        return np.random.normal(MU_SALES_RANK, SIGMA_SALES_RANK)
    else:
        return value

# %%
# Applying the imputation
items_metadata_df['Video Games salesRank'] = items_metadata_df['Video Games salesRank'].apply(mean_dist_imputation)

# %% [markdown]
# And finally, let's look again at the dataframe's info, and make sure that we have no more values missing other than the 4 categories:

# %%
items_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50953 entries, 0 to 50952
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   asin                   50953 non-null  object
#  1   description            50953 non-null  object
#  2   price                  50953 non-null  float64
#  3   categories             50953 non-null  object
#  4   also_bought            28965 non-null  object
#  5   bought_together        20654 non-null  object
#  6   buy_after_viewing      39905 non-null  object
#  7   also_viewed            14839 non-null  object
#  8   Video Games salesRank  50953 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 3.5+ MB

# %% [markdown]
# ### 5.3 Feature engineering

# %% [markdown]
# Now we will add all the features we discussed before, and we will add some more transformation column. In summary, we will add the following features:
# 1. Description length
# 2. Multiply the price and salesRank column
# 3. Add a price^2 feature
# 4. Add a log(price) feature
# 5. Add a salesRank^2 feature
# 6. Add a log(salesRank) feature

# %% [markdown]
# #### 5.3.1 Description length

# %% [markdown]
# This feature is the easiest to add:

# %%
items_metadata_df['description_length'] = items_metadata_df['description'].apply(lambda text : len(str(text)))

# %% [markdown]
# Our new column:

# %%
items_metadata_df['description_length']
# Out:
# 0          17
# 1         497
# 2         772
# 3         152
# 4          36
#          ...
# 50948       0
# 50949    1089
# 50950    1089
# 50951       0
# 50952       0
# Name: description_length, Length: 50953, dtype: int64

# %% [markdown]
# #### 5.3.2 Multiply price and salesRank

# %% [markdown]
# Will be created in the same method as the description length: (Note: we will add the square root, since the values will be high)

# %%
items_metadata_df['price_salesRank_mult'] = np.sqrt(items_metadata_df['price'] * items_metadata_df['Video Games salesRank'])

# %% [markdown]
# Our new column:

# %%
items_metadata_df['price_salesRank_mult']
# Out:
# 0        1043.224281
# 1        1017.781902
# 2         667.856422
# 3        1417.490219
# 4        1461.587486
#             ...
# 50948     658.644220
# 50949    1094.664473
# 50950    1081.931134
# 50951     921.115511
# 50952     626.194178
# Name: price_salesRank_mult, Length: 50953, dtype: float64

# %% [markdown]
# #### 5.3.3 Add $price^2$

# %% [markdown]
# All the 4 new features are created in order to try and find better usage of these attributes - using the magnitude of change, or non-linear relations

# %%
items_metadata_df['price_squared'] = items_metadata_df['price'] ** 2

# %% [markdown]
# #### 5.3.4 Add $\sqrt{price}$

# %%
items_metadata_df['price_sqrt'] = items_metadata_df['price'] ** 0.5

# %% [markdown]
# #### 5.3.5 Add $salesRank^2$

# %%
items_metadata_df['salesRank_squared'] = items_metadata_df['Video Games salesRank'] ** 2

# %% [markdown]
# #### 5.3.4 Add $\sqrt{salesRank}$

# %%
items_metadata_df['salesRank_sqrt'] = items_metadata_df['Video Games salesRank'] ** 0.5

# %% [markdown]
# Finally, we will view our dataframe after adding all the features:

# %%
items_metadata_df.head()
# Out:
#          asin                                        description     price  \
# 0  0078764343                                  Brand new sealed!  37.98000
# 1  043933702X  In Stock NOW.  Eligible for FREE Super Saving ...  23.50000
# 2  0439339987  Grandma Groupers kelp seeds are missing and wi...   8.95000
# 3  0439342260  This software is BRAND NEW. Packaging may diff...  40.87555
# 4  0439339960               a scholastic clubs fairs cd rom game  40.87555
#
#                        categories  \
# 0  [Video Games, Xbox 360, Games]
# 1        [Video Games, PC, Games]
# 2        [Video Games, PC, Games]
# 3        [Video Games, PC, Games]
# 4        [Video Games, PC, Games]
#
#                                          also_bought bought_together  \
# 0  [B000TI836G, B003Q53VZC, B00EFFW0HC, B003VWGBC...    [B002I098JE]
# 1                                                NaN             NaN
# 2  [B000314VVU, B000PXUOTE, B00004TJCM, B0006U22X...             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#                                   buy_after_viewing  \
# 0  [B0050SY5BM, B000TI836G, B0037LTTRO, B002I098JE]
# 1  [B000067NP1, 0439573947, B00003W869, 0486406105]
# 2                          [B00004UCUS, B000YFIS00]
# 3                                               NaN
# 4                                               NaN
#
#                                          also_viewed  Video Games salesRank  \
# 0                                                NaN                28655.0
# 1  [B000067NP1, 0439573947, B00005V97H, B00004DIT...                44080.0
# 2                                                NaN                49836.0
# 3                                       [043934302X]                49156.0
# 4                                       [B00028D7TG]                52262.0
#
#    description_length  price_salesRank_mult  price_squared  price_sqrt  \
# 0                  17           1043.224281    1442.480400    6.162792
# 1                 497           1017.781902     552.250000    4.847680
# 2                 772            667.856422      80.102500    2.991655
# 3                 152           1417.490219    1670.810564    6.393399
# 4                  36           1461.587486    1670.810564    6.393399
#
#    salesRank_squared  salesRank_sqrt
# 0       8.211090e+08      169.277878
# 1       1.943046e+09      209.952376
# 2       2.483627e+09      223.239781
# 3       2.416312e+09      221.711524
# 4       2.731317e+09      228.608836

# %% [markdown]
# ---

# %% [markdown]
# ## 6 Choosing and training models

# %% [markdown]
# This section will be divided into a few parts:
# 1. Explaining the strategy behind training the models
# 2. Introduction to the recommendation system algorithms
# 3. Training different models with different algorithms

# %% [markdown]
# ---

# %% [markdown]
# ### 6.1 Strategy of training

# %% [markdown]
# Our strategy will be to try and train many different models, with many different algorithms, to check fast what is working and what's not, before dwelling into one or two algorithms and trying to improve them (Section number 7).
#
# We will analyze the matrices of each model and algorithm as we decided in section no. 2 (RMSE as the performance measurment), then try to make some more feature engineering and data preperation. **e.g. we might try to use the text in the description better, or use the "bought together" columns w. clustering methods**.
#
# At the end, we will present a short list of the most promising models to work with at the fine-tuning section.

# %% [markdown]
# ---

# %% [markdown]
# ### 6.2 Introduction to the algorithms

# %% [markdown]
# Recommendation systems has three main paradigms of solving its problem statement (predicting what rating will a user give to given item):
# 1. Collaborative filtering
# 2. Content-based
# 3. Hybrid methods

# %% [markdown]
# #### 6.2.1 Collaborative filtering models

# %% [markdown]
# A method that is based only on the user-item interactions, a.k.a ratings matrix. In our example, the ratings dataframe is another way to present the ratings matrix: with users as rows, and items as columns:

# %% [markdown]
# ![ratings.png](attachment:ratings.png)

# %% [markdown]
# Image from: https://towardsdatascience.com/introduction-to-recommender-systems-6c66cf15ada

# %%
# Our ratings matrix in another formation:
X_train.head()
# Out:
#              user        item  rating   timestamp
# 0  A35BKARXRL7XDD  B00DBCAS7E     5.0  1397088000
# 1  A1BHXHZHSLYU0P  B0007Z70YM     4.0  1315785600
# 2  A2T3KP9PIE5D9Y  B003BVIXWW     5.0  1397260800
# 3   ATDXFI4YZRGOM  B003JVCA9Q     4.0  1309996800
# 4  A13TO1ZFAH9SVN  B00005N6K3     5.0  1099958400

# %% [markdown]
# **Collaborative filtering has two types of methods:**
# 1. Memory based
# 2. Model based

# %% [markdown]
# ##### 6.2.1.1 Memory based

# %% [markdown]
# The memory based method will try to find similar items or similar users, according to known ratings, and with that information will try to **predict the ratings on items for users that haven't rated them**

# %% [markdown]
# ##### 6.2.1.2 Model based

# %% [markdown]
# In the model based method, we use the user-item interactions to build a new model of our users and items, that represents them with a new vector that suppose to hold all the information about them.
#
# This process is called **embedding**, and is done with an algorithm called **matrix factorization**.

# %% [markdown]
# #### 6.2.2 Content based models

# %% [markdown]
# Content based models are what they imply they are - based solely on the content (metadata) about the users and items.
#
# In this method, we build a model that gets as input information about users and items (and **not** ratings), and predicts the rating of that user to that perticular item.
#
# Many types of algorithms can be used in that part - Artificial neural networks, basic regressions, random forests, SVM's, etc. (Every machine learning algorithm that can take some input "X" and map it to output "Y").

# %% [markdown]
# #### 6.2.3 Hybrid methods

# %% [markdown]
# Hybrid methods are exactly what they are - hybrid. They combine both paradigms presented above: using both the user-item interactions (ratings) and the metadata (content-based) to predict a rating for a given user.

# %% [markdown]
# ---

# %% [markdown]
# In our exercise, **we will try to implement all 3 paradigms: collaborative filtering, content based, and hybrid methods.**
#
# We will describe each algorithm before using him in each one of the sections below.

# %% [markdown]
# ---

# %% [markdown]
# ### 6.3 Training the models

# %% [markdown]
# Now we finally get to the fun part - trying to find good models that fit the data and produce good recommendations.
#
# **Yet, in this part we will not use the test set at all!** The test set will be kept aside until we finish all training and fine-tuning, to evaluate our real model performance.

# %% [markdown]
# #### 6.3.1 Training collaborative filtering algorithms

# %% [markdown]
# ##### Default model - mean

# %% [markdown]
# Our first step in training will be to build a default performance measurment that we can compare ourself to.
#
# In our business objective above (section 1), we've said that our company corrently simply predicts the mean score for each item not rated by a given user.
#
# Therefore, in our usecase of 1-5 ratings range, the mean rating is 3.

# %% [markdown]
# For CF algorithms we will use the surprise framework, that implement most algorithms for recommendation systems that are based on collaborative filtering. In implementing content based and hybrid models, we will have to use different libraries.

# %%
# Imports from surprise to declare our default algorithm
from surprise import AlgoBase
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import Reader

# %% [markdown]
# Now we will define our basic algorithm, that returs the mean 3.0 for each item:

# %%
"""
Default model that always return 3.0 - the mean score between 1 and 5. Will be used for comparisons
"""
class DefaultModel(AlgoBase):
    
    def __init__(self):
        AlgoBase.__init__(self)
        
    def estimate(self, user, item):
        # always return the mean value
        return 3.0

# %% [markdown]
# Now we will read our data, and define our basic model on it:

# %%
# define a Reader class for the data in surprise
reader = Reader(rating_scale=(1, 5))

# %%
# read the data
full_dataset = Dataset.load_from_df(df=X_train[['user', 'item', 'rating']], reader=reader)

# define the algorithm for the training
alg = DefaultModel()

# %% [markdown]
# And implement the cross-validation technique for training (splitting the data to k sets and training on k-1 of the data, and testing on the rest, for k times):

# %%
cross_validate(alg, full_dataset, cv=3, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm DefaultModel on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.6930  1.6956  1.6946  1.6944  0.0011
# MAE (testset)     1.5601  1.5639  1.5620  1.5620  0.0015
# Fit time          0.00    0.32    0.33    0.22    0.15
# Test time         2.56    1.76    2.51    2.27    0.37
# {'test_rmse': array([1.69296377, 1.69559229, 1.69461976]),
#  'test_mae': array([1.56011851, 1.56389237, 1.56198053]),
#  'fit_time': (0.0, 0.31940174102783203, 0.32760024070739746),
#  'test_time': (2.564206600189209, 1.7552292346954346, 2.505216360092163)}

# %% [markdown]
# And we got our first results! A pretty high RMSE: **1.69 RMSE value**, very far from our goal.
#
# Now we will move on, and implement some more interesting algorithms. **We will explain each one of them before implementing them**

# %% [markdown]
# ---

# %% [markdown]
# ##### Baseline estimator

# %% [markdown]
# The concept of baseline estimators is best explained at [Koren 2010](https://courses.ischool.berkeley.edu/i290-dm/s11/SECURE/a1-koren.pdf).
#
# The main idea is that we are trying to calculate $b_{ui}$ which is the estimated rating of item $i$ for user $u$.
#
# The calculation is:
# $b_{ui} = \mu + b_i + b_u$, where $b_i$ and $b_u$ are the deviations of item ratings and user ratings. $\mu$ is the average value over all items.
#
# For example: let's say that our item is the video game "Planetside 2", the average score for video games is 3.5, "Planetside 2" is rated 0.5 above ($b_i$ = 0.5), but user "u" tends to rank items 0.3 points below average ($b_u = -0.3$), therefore our estimate should be: $3.5 + 0.5 - 0.3 = 3.7$
#
# Baselines can be estimated in two different ways: using gradient descent (SGD), or using alternating least squares (ALS).

# %% [markdown]
# Now we will implement this on our dataset (explanations inside the cells):

# %%
# import the baseline algorithm
from surprise import BaselineOnly

# %%
# configure the training parameters: we will choose SGD for the training method, and use the recommended settings
baseline_configuration = {
    'method': 'sgd', # SGD Algorithm
    'reg': 0.02, # default regularization
    'learning_rate': 0.005, # default learning rate
    'n_epochs': 20
}

# %%
# define the algorithm
baseline_alg = BaselineOnly(bsl_options=baseline_configuration)

# %%
# use the same data as above in the default model
cross_validate(algo=baseline_alg,
               data=full_dataset,
               cv=3,
               verbose=True)
# Out:
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Evaluating RMSE, MAE of algorithm BaselineOnly on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.2591  1.2587  1.2553  1.2577  0.0017
# MAE (testset)     0.9880  0.9874  0.9874  0.9876  0.0003
# Fit time          7.90    8.23    8.58    8.23    0.28
# Test time         4.02    4.09    3.58    3.90    0.22
# {'test_rmse': array([1.25908635, 1.25868521, 1.25532412]),
#  'test_mae': array([0.988     , 0.98739667, 0.98743349]),
#  'fit_time': (7.896510601043701, 8.227323055267334, 8.577688455581665),
#  'test_time': (4.0224668979644775, 4.089518070220947, 3.583204746246338)}

# %% [markdown]
# And we already got **Huge improvement from our default benchmark - avg. RMSE of 1.25 instead of 1.69.**

# %% [markdown]
# ---

# %% [markdown]
# ##### k-NN algorithms (Clustering based)

# %% [markdown]
# Also noted at [Koren 2010](https://courses.ischool.berkeley.edu/i290-dm/s11/SECURE/a1-koren.pdf), neighborhood models are the most common approach to CF algorithms. They are based on the concept that users that rate simliarly are similar, and items that are rated similarly are similar. Therefore, this approach is divided into 2 types:
# 1. User-user comparison
# 2. Item-item comparison

# %% [markdown]
# The algorithm that is applied works as follows:
# 1. Clusters up to k neighbours that are close to the required rating (rating of item by specific user)
# 2. Calcalute the ratings by weighted average by similarity of those neighbours:
#
# $\hat{r}_{ui} = \frac{
# \sum\limits_{v \in N^k_i(u)} \text{sim}(u, v) \cdot r_{vi}}
# {\sum\limits_{v \in N^k_i(u)} \text{sim}(u, v)}$
#
#
# The difference between user-user and item-item approaches **is whether we choose the neighbours based on the user, or based on the item** (we always look for a specific user and a specific item, and can cluster by each one of them seperately)

# %% [markdown]
# Example of user-user:

# %% [markdown]
# ![user-user.png](attachment:user-user.png)

# %% [markdown]
# And item-item:

# %% [markdown]
# ![item-item.png](attachment:item-item.png)

# %% [markdown]
# **Basic KNN Implementation**

# %% [markdown]
# We will start with basic KNN configuration. **As a reminder, we do not try to implement hyperparameter tuning in this part, but rather simply train and test many different models to decide on which one of them to focus later.**

# %%
# import the KNN algorithm
from surprise import KNNBasic

# %% [markdown]
# Configuring similarity measures:

# %%
# measuring by user-user distance
similarity_configuration_uu = {
    'name': 'msd', # use the mean squared
    'user_based': True # user-user comparison
}

# %% [markdown]
# Trying to train on user-user comparison:

# %%
# define on user-user
knn_basic_alg = KNNBasic(k=40,
                         min_k=1,
                         sim_options=similarity_configuration_uu)

# train on user-user data
cross_validate(algo=knn_basic_alg,
               data=full_dataset,
               cv=3,
               verbose=True)
# Out:
# Computing the msd similarity matrix...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-144-39529e920920> in <module>
#       8                data=full_dataset,
#       9                cv=3,
# ---> 10                verbose=True)
#
# ~\anaconda3\envs\omertorch\lib\site-packages\surprise\model_selection\validation.py in cross_validate(algo, data, measures, cv, return_train_measures, n_jobs, pre_dispatch, verbose)
#     101                                            return_train_measures)
#     102                     for (trainset, testset) in cv.split(data))
# --> 103     out = Parallel(n_jobs=n_jobs, pre_dispatch=pre_dispatch)(delayed_list)
#     104
#     105     (test_measures_dicts,
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~\anaconda3\envs\omertorch\lib\site-packages\surprise\model_selection\validation.py in fit_and_score(algo, trainset, testset, measures, return_train_measures)
#     164
#     165     start_fit = time.time()
# --> 166     algo.fit(trainset)
#     167     fit_time = time.time() - start_fit
#     168     start_test = time.time()
#
# ~\anaconda3\envs\omertorch\lib\site-packages\surprise\prediction_algorithms\knns.py in fit(self, trainset)
#      97
#      98         SymmetricAlgo.fit(self, trainset)
# ---> 99         self.sim = self.compute_similarities()
#     100
#     101         return self
#
# ~\anaconda3\envs\omertorch\lib\site-packages\surprise\prediction_algorithms\algo_base.py in compute_similarities(self)
#     247             if getattr(self, 'verbose', False):
#     248                 print('Computing the {0} similarity matrix...'.format(name))
# --> 249             sim = construction_func[name](*args)
#     250             if getattr(self, 'verbose', False):
#     251                 print('Done computing similarity matrix.')
#
# ~\anaconda3\envs\omertorch\lib\site-packages\surprise\similarities.pyx in surprise.similarities.msd()
#
# MemoryError: Unable to allocate 2.62 TiB for an array with shape (600612, 600612) and data type float64

# %% [markdown]
# And we get a memory error error!
#
# In order to get the similarity matrix in the size of all different users, we need to allocate 2.63 terabyte of space!
#
# Since its not possible in any way, **we will try working with the item-item comparison instead.**

# %%
# measuring by item-item distance
similarity_configuration_ii = {
    'name': 'cosine', # use the cosine similarity
    'user_based': False # item-item comparison
}

# %%
# define now on item-item
knn_basic_alg = KNNBasic(k=40,
                         min_k=1,
                         sim_options=similarity_configuration_ii)

# train on user-user data
cross_validate(algo=knn_basic_alg,
               data=full_dataset,
               cv=3,
               verbose=True)
# Out:
# Computing the cosine similarity matrix...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-146-7b1666cd731a> in <module>
#       8                data=full_dataset,
#       9                cv=3,
# ---> 10                verbose=True)
#
# ~\anaconda3\envs\omertorch\lib\site-packages\surprise\model_selection\validation.py in cross_validate(algo, data, measures, cv, return_train_measures, n_jobs, pre_dispatch, verbose)
#     101                                            return_train_measures)
#     102                     for (trainset, testset) in cv.split(data))
# --> 103     out = Parallel(n_jobs=n_jobs, pre_dispatch=pre_dispatch)(delayed_list)
#     104
#     105     (test_measures_dicts,
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~\anaconda3\envs\omertorch\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~\anaconda3\envs\omertorch\lib\site-packages\surprise\model_selection\validation.py in fit_and_score(algo, trainset, testset, measures, return_train_measures)
#     164
#     165     start_fit = time.time()
# --> 166     algo.fit(trainset)
#     167     fit_time = time.time() - start_fit
#     168     start_test = time.time()
#
# ~\anaconda3\envs\omertorch\lib\site-packages\surprise\prediction_algorithms\knns.py in fit(self, trainset)
#      97
#      98         SymmetricAlgo.fit(self, trainset)
# ---> 99         self.sim = self.compute_similarities()
#     100
#     101         return self
#
# ~\anaconda3\envs\omertorch\lib\site-packages\surprise\prediction_algorithms\algo_base.py in compute_similarities(self)
#     247             if getattr(self, 'verbose', False):
#     248                 print('Computing the {0} similarity matrix...'.format(name))
# --> 249             sim = construction_func[name](*args)
#     250             if getattr(self, 'verbose', False):
#     251                 print('Done computing similarity matrix.')
#
# ~\anaconda3\envs\omertorch\lib\site-packages\surprise\similarities.pyx in surprise.similarities.cosine()
#
# MemoryError: Unable to allocate 15.0 GiB for an array with shape (44920, 44920) and data type float64

# %% [markdown]
# Now we need a smaller amount of space, but yet we need 15GB+ for this action.
#
# We will reduce the dataset to reduce the number of items, and therefore the size of the similarity matrix.
#
# As we've seen in the EDA, **most items have no more than a few ratings.** We will simply remove those items from our dataframe:

# %%
# Copy the dataframe
X_train_copy = X_train.copy()

# keep only items with more than 30 ratings
X_train_copy = X_train_copy[X_train_copy.groupby('item').user.transform('count') >= 30]

# print number of items in the dataset now
X_train_copy['item'].nunique()
# Out:
# 7874

# %%
# load the smaller dataframe
smaller_data = Dataset.load_from_df(df=X_train_copy[['user', 'item', 'rating']], reader=reader)

# %% [markdown]
# **Note: indexes change below and are not in the right order because I restarted the kernel for a few time to free my RAM for more model trainings**

# %% [markdown]
# And now we will try to train the algorithm again:

# %%
# define now on item-item
knn_basic_alg = KNNBasic(k=40,
                         min_k=1,
                         sim_options=similarity_configuration_ii)

# train on the smaller dataset
cross_validate(algo=knn_basic_alg,
               data=smaller_data,
               cv=3,
               verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.3851  1.3842  1.3883  1.3859  0.0017
# MAE (testset)     1.0570  1.0561  1.0594  1.0575  0.0014
# Fit time          2.67    2.94    2.91    2.84    0.12
# Test time         4.25    5.07    4.01    4.44    0.45
# {'test_rmse': array([1.38513741, 1.38417398, 1.38827009]),
#  'test_mae': array([1.05695137, 1.05611662, 1.05942952]),
#  'fit_time': (2.665048599243164, 2.936866044998169, 2.910006523132324),
#  'test_time': (4.245177745819092, 5.0664613246917725, 4.01201319694519)}

# %% [markdown]
# And now **our RMSE is worse - 1.38 SCORE.**

# %% [markdown]
# We will try some more knn-based algorithms, and check fast if we get any improvement:

# %% [markdown]
# **KNN With means**

# %% [markdown]
# Similar to KNN Basics, but taking into account the mean ratings of each user.

# %%
from surprise import KNNWithMeans

# %% [markdown]
# Train the algorithm:

# %%
# define now on item-item
knn_mean_alg = KNNWithMeans(k=40,
                        min_k=1,
                        sim_options=similarity_configuration_ii)

# train on the smaller dataset
cross_validate(algo=knn_mean_alg,
               data=smaller_data,
               cv=3,
               verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.3464  1.3468  1.3466  1.3466  0.0001
# MAE (testset)     1.0363  1.0362  1.0362  1.0362  0.0001
# Fit time          3.33    3.85    3.41    3.53    0.23
# Test time         5.66    5.56    4.14    5.12    0.70
# {'test_rmse': array([1.34644776, 1.3467679 , 1.34663523]),
#  'test_mae': array([1.03632117, 1.03618808, 1.0361581 ]),
#  'fit_time': (3.328677177429199, 3.8494136333465576, 3.4122118949890137),
#  'test_time': (5.6570725440979, 5.564011096954346, 4.135252952575684)}

# %% [markdown]
# We got a small improvement, but not a big one - to **1.34 RMSE**

# %% [markdown]
# **KNN With z-score (normalization)**

# %% [markdown]
# Now we will take into account the z-score normalization of each user.

# %%
from surprise import KNNWithZScore

# %%
# define now on item-item
knn_zscore_alg = KNNWithZScore(k=40,
                        min_k=1,
                        sim_options=similarity_configuration_ii)

# train on the smaller dataset
cross_validate(algo=knn_zscore_alg,
               data=smaller_data,
               cv=3,
               verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithZScore on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.3459  1.3464  1.3473  1.3465  0.0006
# MAE (testset)     1.0338  1.0338  1.0346  1.0341  0.0004
# Fit time          3.69    3.95    3.96    3.87    0.12
# Test time         4.50    4.67    4.89    4.69    0.16
# {'test_rmse': array([1.34590116, 1.34638059, 1.3473352 ]),
#  'test_mae': array([1.03380838, 1.03380805, 1.03462078]),
#  'fit_time': (3.6918396949768066, 3.9476089477539062, 3.962406873703003),
#  'test_time': (4.500218152999878, 4.673296689987183, 4.892421245574951)}

# %% [markdown]
# No improvement compared to the KNN with mean - **still 1.34 RMSE**

# %% [markdown]
# **KNN With baseline**

# %% [markdown]
# Closer to the baseline model - we implement a clustering algorithm based on the baseline model - taking into account its results as well:

# %%
from surprise import KNNBaseline

# %%
# define now on item-item
knn_baseline_alg = KNNBaseline(k=40,
                        min_k=1,
                        sim_options=similarity_configuration_ii)

# train on user-user data
cross_validate(algo=knn_baseline_alg,
               data=smaller_data,
               cv=3,
               verbose=True)
# Out:
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBaseline on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.2585  1.2538  1.2587  1.2570  0.0023
# MAE (testset)     0.9606  0.9580  0.9612  0.9599  0.0014
# Fit time          5.90    6.28    6.26    6.15    0.17
# Test time         4.60    4.04    4.66    4.43    0.28
# {'test_rmse': array([1.25848023, 1.25380394, 1.2587435 ]),
#  'test_mae': array([0.96058592, 0.95803974, 0.9611969 ]),
#  'fit_time': (5.9042158126831055, 6.275483131408691, 6.260438680648804),
#  'test_time': (4.601219415664673, 4.035212755203247, 4.66101598739624)}

# %% [markdown]
# Now we got a bigger improvement, and a result that is similar to our baseline model - **RMSE of 1.25**

# %% [markdown]
# ---

# %% [markdown]
# ##### Matrix factorization algorithms

# %% [markdown]
# Now we turn to the last approach of pure collaborative filtering method - which is matrix factorization.
#
# The concept behind matrix factorization is to find two representations of matrices, one that represent the users, and one that represents the items, each one of the matrices in a much smaller dimension - in (m * k) and (n * k) dimensions respectively, as "k" is the smaller matrix size.
#
# Then, **the dot product of these metrices will produce the predicted rating.**

# %% [markdown]
# ![matrix_factorization.png](attachment:matrix_factorization.png)

# %% [markdown]
# Three main types of matrix factorization algorithms exist:
# 1. SVD - Made popular in 2008 during the Netflix recommendation contest
# 2. SVD++ - Same concept as the SVD, but with improvements to the calculation
# 3. NMF - Based on non-negative matrix factorization

# %% [markdown]
# **SVD**

# %% [markdown]
# Starting with the SVD, the SVD predicts ratings with the following formula:
#
# $\hat{r}_{ui} = \mu + b_u + b_i + q_i^Tp_u$

# %% [markdown]
# Where $q_i$ is the item vector for the specific item (from the new matrix produced for the items by the matrix factorization formula) and $p_u$ stands for the user vector

# %%
from surprise import SVD

# %%
# Use all the default initializations
svd_alg = SVD(verbose=True)

# train on user-user data
svd_result = cross_validate(algo=svd_alg,
               data=data,
               cv=3,
               verbose=True)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.2655  1.2637  1.2648  1.2647  0.0007
# MAE (testset)     0.9933  0.9933  0.9939  0.9935  0.0003
# Fit time          68.19   70.30   75.78   71.42   3.20
# Test time         4.74    4.41    4.34    4.50    0.17

# %% [markdown]
# And we got a pretty good result with tthe SVD - **RMSE of 1.26**

# %% [markdown]
# **SVD++**

# %% [markdown]
# As explained, this algorithm is similar to the SVD, but it uses implicit ratings as well. The formula is as follows:
#
# $\hat{r}_{ui} = \mu + b_u + b_i + q_i^T\left(p_u +
# |I_u|^{-\frac{1}{2}} \sum_{j \in I_u}y_j\right)$

# %%
from surprise import SVDpp

# %%
# Use all the default initializations
svdpp_alg = SVDpp(verbose=True)

# train on user-user data
svdpp_result = cross_validate(algo=svdpp_alg,
               data=data,
               cv=3,
               verbose=True)
# Out:
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
# Evaluating RMSE, MAE of algorithm SVDpp on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.2944  1.2901  1.2901  1.2915  0.0020
# MAE (testset)     1.0147  1.0120  1.0132  1.0133  0.0011
# Fit time          194.64  196.45  199.89  196.99  2.18
# Test time         9.41    8.74    9.52    9.22    0.34

# %% [markdown]
# Even that this algorithm should be more sophisticated than the simple SVD, its results are worse - **RMSE of 1.29 instead of 1.26 in the simpler SVD.**

# %% [markdown]
# **NMF**

# %% [markdown]
# And lastly, we will implement the NMF algorithm - computes the same matrices as above, but the ratings is now computed solely on the dot product of the item and user matrices:
#
# $\hat{r}_{ui} = q_i^Tp_u$

# %%
from surprise import NMF

# %%
# Use all the default initializations
nmf_alg = NMF(verbose=True)

# train on user-user data
nmf_result = cross_validate(algo=nmf_alg,
               data=data,
               cv=3,
               verbose=True)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Evaluating RMSE, MAE of algorithm NMF on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.4415  1.4408  1.4426  1.4416  0.0007
# MAE (testset)     1.1399  1.1403  1.1412  1.1404  0.0005
# Fit time          132.48  127.67  125.53  128.56  2.91
# Test time         3.77    4.83    3.54    4.05    0.56

# %% [markdown]
# And this model has **the worse performance so far - RMSE of 1.44**

# %% [markdown]
# And now, we've done running all main CF algorithms. Our main results are (all results will be presented at the end of this section):
# 1. Best is SVD + KNN with baseline **which are ~1.25 RMSE**
# 2. Worse is the NMF **with ~1.44 RMSE**

# %% [markdown]
# #### 6.3.2 Training content-based models

# %% [markdown]
# Now we're moving onto the next stage - training models based only on the content (metadata) of our use-case.
#
# As explained before, the idea behind content-based models is to use the metadata of the items and of the users to get an evaluation of a rating of some user.
#
# In our use-case, **we have no metadata about any user that is rating items.** Therefore, **we cannot predict based on metadata only the rating of an item** - we have no way to distinct between different user since we have no information about them.
#
# And because of that, in this training step we will skip the content-based models, and move to the hybrid models.

# %% [markdown]
# #### 6.3.3 Training Hybrid Models

# %% [markdown]
# Now we go to the last part - training hybrid models.
#
# By researching the common way to implement hybrid models, a major implementation rise. This algorithm is as follows:
# 1. Get the user you wish recommendations for
# 2. Get top rated items by this user
# 3. Get the closest items to this item (Content-based similarity)
# 4. Apply collaborative filtering algorithm to these items only to predict which gets the highest rating
# 5. Rank the results as recommendations to the user.
#
# **Our problem with this common method is that we cannot test it the way we defined in this project - since we can't get concrete predictions for all items, but only get the best recommendations for a specific user.**
#
# Therefore, implementing hybrid systems are problematic as well in our business use-case.

# %% [markdown]
# **Bonus: Trying to implement my own hybrid recommendation algorithm from scratch**

# %% [markdown]
# In this section, I will try to implement my own version of recommendation system algorithm, based on what i've learned on recommendation systems in this project (but not based on any algorithm or version found while researching).
#
# I've designed an architecture that gets us our metrices that are relevant for our business use-case: In case of user-item pair, get a rating prediction for this item, for this specific user.
#
# The architecture is as follows:

# %% [markdown]
# ![ARCHITECTURE-3.PNG](attachment:ARCHITECTURE-3.PNG)

# %% [markdown]
# Now, we will organize our data for training:

# %% [markdown]
# **Content Metadata**

# %% [markdown]
# Here, we will use our post-processed metadata dataframe. Since we try to make fast iterations, we will use for now only the features we already have for easy usage:
# 1. Price
# 2. Video games salesRank
# 3. Description Length
# 4. price_salesRank_mult
# 5. price_squared
# 6. price_sqrt
# 7. salesRank_squared
# 8. salesRank_sqrt

# %%
hybrid_metadata = items_metadata_df[['price', 'Video Games salesRank', 'description_length', 'price_salesRank_mult',
                                     'price_squared', 'price_sqrt', 'salesRank_squared', 'salesRank_sqrt']]
hybrid_metadata = hybrid_metadata.set_index(keys=items_metadata_df['asin'])

# %%
# print the metadata dataframe
hybrid_metadata
# Out:
#                price  Video Games salesRank  description_length  \
# asin
# 0078764343  37.98000           28655.000000                  17
# 043933702X  23.50000           44080.000000                 497
# 0439339987   8.95000           49836.000000                 772
# 0439342260  40.87555           49156.000000                 152
# 0439339960  40.87555           52262.000000                  36
# ...              ...                    ...                 ...
# B00LCLV730  40.87555           10613.000000                   0
# B00LGBKSK4  36.99000           40521.463020                1089
# B00LGBJIQ4  35.99000           47758.362768                1089
# B00LI0VTS8  40.87555           20757.000000                   0
# B00LIWF1GW  40.87555            9593.000000                   0
#
#             price_salesRank_mult  price_squared  price_sqrt  \
# asin
# 0078764343           1043.224281    1442.480400    6.162792
# 043933702X           1017.781902     552.250000    4.847680
# 0439339987            667.856422      80.102500    2.991655
# 0439342260           1417.490219    1670.810564    6.393399
# 0439339960           1461.587486    1670.810564    6.393399
# ...                          ...            ...         ...
# B00LCLV730            658.644220    1670.810564    6.393399
# B00LGBKSK4           1224.291190    1368.260100    6.081940
# B00LGBJIQ4           1311.039083    1295.280100    5.999167
# B00LI0VTS8            921.115511    1670.810564    6.393399
# B00LIWF1GW            626.194178    1670.810564    6.393399
#
#             salesRank_squared  salesRank_sqrt
# asin
# 0078764343       8.211090e+08      169.277878
# 043933702X       1.943046e+09      209.952376
# 0439339987       2.483627e+09      223.239781
# 0439342260       2.416312e+09      221.711524
# 0439339960       2.731317e+09      228.608836
# ...                       ...             ...
# B00LCLV730       1.126358e+08      103.019416
# B00LGBKSK4       1.641989e+09      201.299436
# B00LGBJIQ4       2.280861e+09      218.536868
# B00LI0VTS8       4.308530e+08      144.072898
# B00LIWF1GW       9.202565e+07       97.943861
#
# [50953 rows x 8 columns]

# %% [markdown]
# Now we will use the standard scaler of sk-learn to scale the features:

# %%
from sklearn.preprocessing import StandardScaler

# %%
# define the scaler
scaler = StandardScaler()

# scale the data
hybrid_metadata_scaled = scaler.fit_transform(hybrid_metadata)

# %%
# return the scaled values to pandas df
hybrid_metadata_scaled = pd.DataFrame(hybrid_metadata_scaled, index=items_metadata_df['asin'],
                                           columns=['price', 'Video Games salesRank', 'description_length', 'price_salesRank_mult',
                                             'price_squared', 'price_sqrt', 'salesRank_squared', 'salesRank_sqrt'])

# %%
# print the scaled dataframe
hybrid_metadata_scaled
# Out:
#                price  Video Games salesRank  description_length  \
# asin
# 0078764343 -0.045893              -0.273120           -0.586773
# 043933702X -0.275396               0.344337           -0.139370
# 0439339987 -0.506008               0.574748            0.116955
# 0439342260  0.000000               0.547528           -0.460941
# 0439339960  0.000000               0.671860           -0.569063
# ...              ...                    ...                 ...
# B00LCLV730  0.000000              -0.995335           -0.602619
# B00LGBKSK4 -0.061584               0.201890            0.412428
# B00LGBJIQ4 -0.077434               0.491581            0.412428
# B00LI0VTS8  0.000000              -0.589274           -0.602619
# B00LIWF1GW  0.000000              -1.036166           -0.602619
#
#             price_salesRank_mult  price_squared  price_sqrt  \
# asin
# 0078764343              0.155014      -0.124836    0.197308
# 043933702X              0.114892      -0.151240   -0.212480
# 0439339987             -0.436938      -0.165243   -0.790816
# 0439342260              0.745229      -0.118064    0.269165
# 0439339960              0.814770      -0.118064    0.269165
# ...                          ...            ...         ...
# B00LCLV730             -0.451466      -0.118064    0.269165
# B00LGBKSK4              0.440556      -0.127038    0.172115
# B00LGBJIQ4              0.577357      -0.129202    0.146322
# B00LI0VTS8             -0.037550      -0.118064    0.269165
# B00LIWF1GW             -0.502639      -0.118064    0.269165
#
#             salesRank_squared  salesRank_sqrt
# asin
# 0078764343          -0.414008       -0.085897
# 043933702X           0.023510        0.502563
# 0439339987           0.234319        0.694798
# 0439342260           0.208069        0.672688
# 0439339960           0.330910        0.772475
# ...                       ...             ...
# B00LCLV730          -0.690290       -1.044492
# B00LGBKSK4          -0.093892        0.377376
# B00LGBJIQ4           0.155247        0.626759
# B00LI0VTS8          -0.566195       -0.450550
# B00LIWF1GW          -0.698327       -1.117923
#
# [50953 rows x 8 columns]

# %% [markdown]
# **Collaborative filtering data**

# %% [markdown]
# Now we have to use all our training data to train the SVD algorithm, and get the following features:
# 1. User embedded matrix - for user vector
# 2. Item embedded matrix - for item vector
# 3. User + Item biases - for the bias vector

# %% [markdown]
# **Important warning - data leakage!**
#
# Before starting training the model, i've realised that training the SVD model and getting the vectors on all the X_train data **will result in data leakage!**
#
# That is because we will get the user and item metrices trained on all data, and therefore fitted to produce the right result for ratings in the train set. Therefore, when we will use these vectors in predictings those ratings, we actually already "told" the algorithm what the right rating is - since it's already embedded in the user+item vectors itself - they where trained on the result!

# %% [markdown]
# Therefore, we will have no choice but make another split to the trainset, and use only this dataset for getting the SVD algorithm and the user-item matrices and biases. **We will call that new split: svd_set**
#
# We will use the surprise train-test split for that cause:

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Now we can use the svd_set for the SVD training and for getting the matrices, and the train_set for actually training the model:

# %%
# import again the SVD algorithm
from surprise import SVD

# %% [markdown]
# Before we start, we face another problem: We might get in the svd_set missing users / items, that won't get a user / item vector, and that will make our system not work.
#
# In order to solve this problem, we will only use X_train data on users with more than 4 ratings, and will make sure that all users get into the svd_set.
#
# Then, we will make sure that each item has at least one representation in the svd_set as well, to create a perfect matrice for training.

# %%
X_train_for_hybrid_model = X_train[X_train.groupby('item').item.transform('count') >= 10]
X_train_for_hybrid_model = X_train_for_hybrid_model[X_train_for_hybrid_model.groupby('user').user.transform('count') >= 4]

# %%
print(str(X_train_for_hybrid_model['user'].nunique()) + " is the number of unique users")
print(str(X_train_for_hybrid_model['item'].nunique()) + " is the number of unique items")
# Out:
# 40535 is the number of unique users
# 16758 is the number of unique items

# %%
X_train_for_hybrid_model
# Out:
#                    user        item  rating   timestamp
# 0        A35BKARXRL7XDD  B00DBCAS7E     5.0  1397088000
# 1        A1BHXHZHSLYU0P  B0007Z70YM     4.0  1315785600
# 2        A2T3KP9PIE5D9Y  B003BVIXWW     5.0  1397260800
# 3         ATDXFI4YZRGOM  B003JVCA9Q     4.0  1309996800
# 4        A13TO1ZFAH9SVN  B00005N6K3     5.0  1099958400
# ...                 ...         ...     ...         ...
# 1264501   AAZN9543247VJ  B00KAI3KW2     5.0  1402617600
# 1264504  A39URTTYF2QI5L  B00KAI3KW2     5.0  1402790400
# 1264507  A3PRTPSAW8ZE5J  B00KAI3KW2     1.0  1405555200
# 1264724  A2R3WD5KVU55HV  B00L2Q5KWE     5.0  1405036800
# 1264728   AVD1F18USVLM3  B00L2Q5KWE     1.0  1404691200
#
# [259381 rows x 4 columns]

# %%
# Define 'y' again on the smaller ratings dataframe
y = X_train_for_hybrid_model['user']

# using stratify to get data for each user, and random_state (equals meaning of life) for consistency
# We don't need the 'y_train' and 'y_test' because as we explained before, y only used for  stratifing
X_train_hybrid, X_test_svd, _, _ = train_test_split(X_train_for_hybrid_model, y, test_size=0.50, stratify=y, random_state=42)

# %% [markdown]
# Now we will test the number of unique users and items in our svd_set:

# %%
print(str(X_test_svd['user'].nunique()) + " is the number of unique users")
print(str(X_test_svd['item'].nunique()) + " is the number of unique items")
# Out:
# 40535 is the number of unique users
# 15399 is the number of unique items

# %% [markdown]
# And the train set:

# %%
print(str(X_train_hybrid['user'].nunique()) + " is the number of unique users")
print(str(X_train_hybrid['item'].nunique()) + " is the number of unique items")
# Out:
# 40535 is the number of unique users
# 15394 is the number of unique items

# %%
X_train_hybrid = X_train_hybrid[X_train_hybrid['item'].isin(X_test_svd['item'])]

# %% [markdown]
# And making a final check for the hybrid training set:

# %%
print(str(X_train_hybrid['user'].nunique()) + " is the number of unique users")
print(str(X_train_hybrid['item'].nunique()) + " is the number of unique items")
# Out:
# 40513 is the number of unique users
# 14035 is the number of unique items

# %% [markdown]
# Now we made sure that no values in the train dataset exists that do not exist in the svd set.

# %%
# set svd alg
svd_set_alg = SVD(verbose=True, n_epochs=50)

# set the reader again
reader = Reader(rating_scale=(1, 5))

# load data
svd_data_surprise = Dataset.load_from_df(df=X_test_svd[['user', 'item', 'rating']], reader=reader)

# %%
# load the svd data for surprise
svd_trainset = svd_data_surprise.build_full_trainset()

# train the SVD algorithm
svd_set_alg.fit(svd_trainset)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49

# %% [markdown]
# Now we've trained the svd model!
#
# Now we have to load from it the:
# 1. Users matrix
# 2. Items matrix
# 3. User-bias matrix
# 4. Item-bias matrix

# %% [markdown]
# **Users Matrix**

# %%
# set the indexes
users_indexes = X_test_svd['user'].unique()

# load the users matrix to a dataframe, as the users as indexes
users_matrix = pd.DataFrame(svd_set_alg.pu, index=users_indexes, columns=[(str(i) + " u_feature") for i in range(100)])

# present the dataframe
users_matrix
# Out:
#                 0 u_feature  1 u_feature  2 u_feature  3 u_feature  \
# A9P4Q7KX35RS2      0.095938     0.032464     0.094653     0.035107
# ANZUZTIBMGK4S      0.337314     0.127740     0.136661    -0.003554
# A2IMLOJ2Z2QEU2    -0.095019     0.044849     0.204093    -0.098238
# A13NFQWGPZ6ZWF    -0.150361    -0.043389     0.115799    -0.168799
# A2S6IEOS35432J     0.082142     0.033363    -0.116758     0.095972
# ...                     ...          ...          ...          ...
# A30WPFRE250IHP    -0.146910     0.231247     0.117124     0.089348
# A2L6GDFGKYC6GP     0.158621     0.000460     0.052043     0.099727
# A2QPB42Q1XO8GZ    -0.132164    -0.326041     0.003743    -0.035086
# A27GA298ZWO31B    -0.112476     0.062061    -0.062213    -0.105133
# AC6TVS8FA6OEA     -0.079920     0.035170     0.082502     0.108188
#
#                 4 u_feature  5 u_feature  6 u_feature  7 u_feature  \
# A9P4Q7KX35RS2      0.141782     0.088983    -0.029983    -0.028213
# ANZUZTIBMGK4S     -0.181889     0.041706    -0.017283    -0.088311
# A2IMLOJ2Z2QEU2     0.027030     0.224029     0.057948     0.065000
# A13NFQWGPZ6ZWF     0.168425    -0.139111     0.032304     0.048395
# A2S6IEOS35432J     0.037362     0.029133    -0.082993     0.102418
# ...                     ...          ...          ...          ...
# A30WPFRE250IHP     0.016784    -0.022611    -0.151951    -0.216815
# A2L6GDFGKYC6GP     0.043655     0.275932     0.017750    -0.037372
# A2QPB42Q1XO8GZ    -0.071679    -0.011692     0.069708     0.164265
# A27GA298ZWO31B     0.186178    -0.001913    -0.043692    -0.232834
# AC6TVS8FA6OEA      0.126737     0.046566     0.122457    -0.035074
#
#                 8 u_feature  9 u_feature  ...  90 u_feature  91 u_feature  \
# A9P4Q7KX35RS2     -0.162027     0.057832  ...      0.043080     -0.061142
# ANZUZTIBMGK4S     -0.334343     0.074075  ...      0.143062      0.059324
# A2IMLOJ2Z2QEU2    -0.157863    -0.125855  ...     -0.169398     -0.210446
# A13NFQWGPZ6ZWF    -0.235161    -0.169259  ...     -0.169219      0.044792
# A2S6IEOS35432J     0.039585    -0.057253  ...     -0.083136      0.086832
# ...                     ...          ...  ...           ...           ...
# A30WPFRE250IHP    -0.108945     0.029150  ...     -0.075947     -0.010598
# A2L6GDFGKYC6GP    -0.102537    -0.076996  ...      0.055123      0.045773
# A2QPB42Q1XO8GZ     0.064121    -0.071077  ...      0.112927      0.100087
# A27GA298ZWO31B    -0.207747    -0.082545  ...      0.027053     -0.016100
# AC6TVS8FA6OEA     -0.059435    -0.136519  ...     -0.060670      0.071744
#
#                 92 u_feature  93 u_feature  94 u_feature  95 u_feature  \
# A9P4Q7KX35RS2      -0.141148      0.052261      0.033686      0.049480
# ANZUZTIBMGK4S       0.182452     -0.066213     -0.135300     -0.104439
# A2IMLOJ2Z2QEU2      0.083317     -0.047888     -0.031155     -0.192284
# A13NFQWGPZ6ZWF     -0.067461     -0.005388     -0.090999      0.000277
# A2S6IEOS35432J     -0.019346     -0.075712      0.014068     -0.044563
# ...                      ...           ...           ...           ...
# A30WPFRE250IHP      0.067659      0.232704      0.112192     -0.177429
# A2L6GDFGKYC6GP      0.008216      0.005480      0.014795      0.075816
# A2QPB42Q1XO8GZ     -0.177105     -0.156816     -0.140966     -0.041828
# A27GA298ZWO31B     -0.018822     -0.077556      0.043564      0.051113
# AC6TVS8FA6OEA       0.142691      0.159058     -0.031820      0.091148
#
#                 96 u_feature  97 u_feature  98 u_feature  99 u_feature
# A9P4Q7KX35RS2      -0.021645     -0.006166      0.112409     -0.092507
# ANZUZTIBMGK4S       0.162292     -0.186437      0.170544      0.030362
# A2IMLOJ2Z2QEU2     -0.101540      0.055635      0.041217     -0.118036
# A13NFQWGPZ6ZWF     -0.045291     -0.114661     -0.125640      0.149473
# A2S6IEOS35432J      0.091609      0.007111     -0.023816     -0.004151
# ...                      ...           ...           ...           ...
# A30WPFRE250IHP     -0.046799     -0.076691      0.038422     -0.019209
# A2L6GDFGKYC6GP     -0.125694      0.008966      0.182630      0.077612
# A2QPB42Q1XO8GZ      0.096980     -0.116524     -0.083158      0.090367
# A27GA298ZWO31B      0.054173     -0.097436      0.032121     -0.166031
# AC6TVS8FA6OEA       0.059257      0.064508      0.162432     -0.011997
#
# [40535 rows x 100 columns]

# %% [markdown]
# And we got a (40,535 * 100) matrix as expected!

# %% [markdown]
# **Users biases**

# %%
# load the users biases matrix to a dataframe, as the users as indexes
users_bias_matrix = pd.DataFrame(svd_set_alg.bu, index=users_indexes, columns=['user_bias'])

# present the dataframe
users_bias_matrix
# Out:
#                 user_bias
# A9P4Q7KX35RS2    0.103600
# ANZUZTIBMGK4S   -0.034330
# A2IMLOJ2Z2QEU2  -0.343037
# A13NFQWGPZ6ZWF   0.045633
# A2S6IEOS35432J   0.475746
# ...                   ...
# A30WPFRE250IHP  -0.324345
# A2L6GDFGKYC6GP  -0.118464
# A2QPB42Q1XO8GZ  -0.531689
# A27GA298ZWO31B  -0.727949
# AC6TVS8FA6OEA   -0.060469
#
# [40535 rows x 1 columns]

# %% [markdown]
# And again, one bias per user as required

# %% [markdown]
# **Items Matrix**

# %%
# set the indexes
items_indexes = X_test_svd['item'].unique()

# load the users matrix to a dataframe, as the users as indexes
items_matrix = pd.DataFrame(svd_set_alg.qi, index=items_indexes, columns=[(str(i) + " i_feature") for i in range(100)])

# present the dataframe
items_matrix
# Out:
#             0 i_feature  1 i_feature  2 i_feature  3 i_feature  4 i_feature  \
# B0050SYK44    -0.253528     0.163129    -0.384980     0.200495    -0.096911
# B001HB7K6I     0.165983    -0.100524    -0.046206    -0.001309     0.039745
# B002FQM5OG     0.084093     0.073662    -0.284963    -0.020572    -0.086809
# B002I0HJG8    -0.106688    -0.213955     0.180343     0.124350     0.072579
# B0001XE0OS     0.213244    -0.089160     0.022479    -0.049149     0.071068
# ...                 ...          ...          ...          ...          ...
# B000BTICMS     0.163231    -0.076808     0.053588    -0.078210     0.061342
# B000T22Q5Q     0.117941     0.074559    -0.061250    -0.164890     0.034384
# B002BUUKP2    -0.182731    -0.085664     0.054719    -0.057846    -0.117870
# B001BNNHUA     0.010704    -0.169171    -0.054617    -0.084443    -0.154191
# B00GJSUXLS    -0.129826    -0.107450    -0.012630    -0.103276     0.044282
#
#             5 i_feature  6 i_feature  7 i_feature  8 i_feature  9 i_feature  \
# B0050SYK44     0.127762    -0.184632     0.012530     0.000010     0.045690
# B001HB7K6I    -0.166583    -0.093629    -0.028339     0.027804    -0.005765
# B002FQM5OG    -0.168841    -0.118544    -0.001130     0.145532     0.089792
# B002I0HJG8    -0.093450    -0.261851     0.275383     0.070171     0.021547
# B0001XE0OS    -0.065584    -0.141996     0.054724     0.232828    -0.077106
# ...                 ...          ...          ...          ...          ...
# B000BTICMS     0.045630     0.045564     0.081341    -0.151513    -0.115243
# B000T22Q5Q     0.027483     0.172453    -0.266392     0.212530     0.151378
# B002BUUKP2    -0.030885     0.016209     0.080263    -0.037236     0.048446
# B001BNNHUA     0.019899     0.104796     0.066836     0.028231     0.077500
# B00GJSUXLS     0.045536     0.122038    -0.310713     0.156379     0.019649
#
#             ...  90 i_feature  91 i_feature  92 i_feature  93 i_feature  \
# B0050SYK44  ...     -0.178757     -0.070442      0.110015     -0.121474
# B001HB7K6I  ...     -0.022517      0.067118      0.060753      0.143484
# B002FQM5OG  ...     -0.068802      0.191727      0.177099      0.067445
# B002I0HJG8  ...      0.125576      0.340805      0.037482      0.267764
# B0001XE0OS  ...     -0.080969      0.099333      0.080090     -0.059407
# ...         ...           ...           ...           ...           ...
# B000BTICMS  ...     -0.099729     -0.043030      0.047146     -0.048983
# B000T22Q5Q  ...      0.091685     -0.061130      0.051984      0.009061
# B002BUUKP2  ...     -0.034293     -0.059053      0.082258      0.048361
# B001BNNHUA  ...      0.029698     -0.054248     -0.045752     -0.203308
# B00GJSUXLS  ...     -0.018446      0.018078     -0.014784     -0.098097
#
#             94 i_feature  95 i_feature  96 i_feature  97 i_feature  \
# B0050SYK44      0.132700     -0.000695      0.020503     -0.083735
# B001HB7K6I      0.171123     -0.023361     -0.085198     -0.029385
# B002FQM5OG     -0.005937      0.341405      0.032186      0.029862
# B002I0HJG8      0.009264     -0.005196     -0.027397      0.082929
# B0001XE0OS      0.098234      0.066132      0.072809      0.178480
# ...                  ...           ...           ...           ...
# B000BTICMS      0.165004      0.075847     -0.182642      0.108383
# B000T22Q5Q     -0.124827     -0.100835     -0.102636     -0.011693
# B002BUUKP2      0.131660      0.118781      0.047324     -0.035150
# B001BNNHUA      0.129560      0.104212     -0.033929      0.051668
# B00GJSUXLS     -0.049213     -0.017530      0.086694      0.104292
#
#             98 i_feature  99 i_feature
# B0050SYK44     -0.176111     -0.090566
# B001HB7K6I      0.020889      0.014363
# B002FQM5OG      0.128978      0.130728
# B002I0HJG8     -0.085839     -0.141956
# B0001XE0OS     -0.191642     -0.071474
# ...                  ...           ...
# B000BTICMS      0.024743      0.076992
# B000T22Q5Q     -0.139011     -0.064313
# B002BUUKP2     -0.001778      0.192356
# B001BNNHUA     -0.207369     -0.216446
# B00GJSUXLS      0.051831      0.070338
#
# [15399 rows x 100 columns]

# %% [markdown]
# And we got a (15,399 * 100) matrix as expected!

# %% [markdown]
# **Items biases**

# %%
# load the users biases matrix to a dataframe, as the users as indexes
items_bias_matrix = pd.DataFrame(svd_set_alg.bi, index=items_indexes, columns=['item_bias'])

# present the dataframe
items_bias_matrix
# Out:
#             item_bias
# B0050SYK44   0.591338
# B001HB7K6I   0.406922
# B002FQM5OG  -0.381066
# B002I0HJG8  -0.271786
# B0001XE0OS   0.035659
# ...               ...
# B000BTICMS  -0.038102
# B000T22Q5Q  -0.416492
# B002BUUKP2   0.154740
# B001BNNHUA  -0.445642
# B00GJSUXLS  -0.474776
#
# [15399 rows x 1 columns]

# %% [markdown]
# And again, one bias per item as required

# %% [markdown]
# **Bringing all data together**

# %% [markdown]
# Now we will get all of our data in one unified dataframe - in the "X_train_hybrid" dataset:

# %%
# set index for the ratings
X_train_hybrid = X_train_hybrid.set_index(X_train_hybrid['user'])

# %% [markdown]
# Concat user matices:

# %%
# join the user biases
X_train_hybrid = X_train_hybrid.join(users_bias_matrix)

# join the user matrix
X_train_hybrid = X_train_hybrid.join(users_matrix)

# %% [markdown]
# Concat item matrices:

# %%
# set index again
X_train_hybrid = X_train_hybrid.set_index(X_train_hybrid['item'])

# join the item biases
X_train_hybrid = X_train_hybrid.join(items_bias_matrix)

# join the item matrix
X_train_hybrid = X_train_hybrid.join(items_matrix)

# %%
# join the items metadata
X_train_hybrid = X_train_hybrid.join(hybrid_metadata_scaled)

# %%
# drop unused columns:
X_train_hybrid_clean = X_train_hybrid.drop(['user', 'item', 'timestamp'], axis=1)

# %%
# lastly, view the final dataset:
X_train_hybrid_clean
# Out:
#             rating  user_bias  0 u_feature  1 u_feature  2 u_feature  \
# 0700026657     5.0   0.305770     0.055542     0.050361     0.107677
# 0700099867     1.0   0.205778    -0.218245    -0.143858    -0.070598
# 0700099867     2.0  -0.035081    -0.225482    -0.133608     0.037281
# 0700099867     3.0  -0.642471     0.029733     0.056340     0.110528
# 0700099867     3.0   0.410420     0.019985    -0.069429     0.032229
# ...            ...        ...          ...          ...          ...
# B00KAI3KW2     4.0   0.220039     0.052946    -0.061736    -0.024237
# B00KAI3KW2     5.0  -0.226823     0.156325     0.104973    -0.021490
# B00KAI3KW2     5.0   0.190770     0.137961    -0.204492    -0.170623
# B00L2Q5KWE     5.0  -0.220773     0.239390    -0.027687     0.016063
# B00L2Q5KWE     5.0  -0.083000    -0.046941     0.032741     0.118569
#
#             3 u_feature  4 u_feature  5 u_feature  6 u_feature  7 u_feature  \
# 0700026657     0.201655     0.058160    -0.143544    -0.134988    -0.104710
# 0700099867     0.063390     0.025503    -0.082457     0.066939     0.131377
# 0700099867    -0.056390    -0.129245    -0.091697     0.080342     0.094303
# 0700099867    -0.034056     0.072262    -0.031370    -0.114059     0.076192
# 0700099867    -0.116651     0.024674     0.052263     0.072395     0.195719
# ...                 ...          ...          ...          ...          ...
# B00KAI3KW2     0.015807     0.044445     0.038222    -0.179072    -0.035544
# B00KAI3KW2    -0.030151     0.040593     0.062380     0.160398    -0.097473
# B00KAI3KW2    -0.003115     0.060296    -0.282302    -0.098056    -0.219822
# B00L2Q5KWE    -0.180577    -0.076790     0.077039     0.220751     0.001594
# B00L2Q5KWE     0.167167    -0.359121    -0.163154    -0.020895    -0.149997
#
#             ...  98 i_feature  99 i_feature     price  Video Games salesRank  \
# 0700026657  ...     -0.033753      0.074558 -0.014036              -1.115104
# 0700099867  ...      0.116692     -0.014690  3.261130              -1.154814
# 0700099867  ...      0.116692     -0.014690  3.261130              -1.154814
# 0700099867  ...      0.116692     -0.014690  3.261130              -1.154814
# 0700099867  ...      0.116692     -0.014690  3.261130              -1.154814
# ...         ...           ...           ...       ...                    ...
# B00KAI3KW2  ...     -0.315858      0.190892  5.676137              -1.418329
# B00KAI3KW2  ...     -0.315858      0.190892  5.676137              -1.418329
# B00KAI3KW2  ...     -0.315858      0.190892  5.676137              -1.418329
# B00L2Q5KWE  ...      0.045784     -0.051137 -0.101050              -1.413405
# B00L2Q5KWE  ...      0.045784     -0.051137 -0.101050              -1.413405
#
#             description_length  price_salesRank_mult  price_squared  \
# 0700026657            0.424545             -0.619557      -0.120188
# 0700099867           -0.079716              0.526257       1.636430
# 0700099867           -0.079716              0.526257       1.636430
# 0700099867           -0.079716              0.526257       1.636430
# 0700099867           -0.079716              0.526257       1.636430
# ...                        ...                   ...            ...
# B00KAI3KW2           -0.602619             -1.276497       4.554125
# B00KAI3KW2           -0.602619             -1.276497       4.554125
# B00KAI3KW2           -0.602619             -1.276497       4.554125
# B00L2Q5KWE           -0.602619             -1.369727      -0.132317
# B00L2Q5KWE           -0.602619             -1.369727      -0.132317
#
#             price_sqrt  salesRank_squared  salesRank_sqrt
# 0700026657    0.247467          -0.711565       -1.271937
# 0700099867    3.170485          -0.717077       -1.357002
# 0700099867    3.170485          -0.717077       -1.357002
# 0700099867    3.170485          -0.717077       -1.357002
# 0700099867    3.170485          -0.717077       -1.357002
# ...                ...                ...             ...
# B00KAI3KW2    4.501179          -0.734213       -2.436805
# B00KAI3KW2    4.501179          -0.734213       -2.436805
# B00KAI3KW2    4.501179          -0.734213       -2.436805
# B00L2Q5KWE    0.107218          -0.734203       -2.346850
# B00L2Q5KWE    0.107218          -0.734203       -2.346850
#
# [126959 rows x 211 columns]

# %% [markdown]
# And view some data about our new dataframe:

# %%
X_train_hybrid_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126959 entries, 0700026657 to B00L2Q5KWE
# Columns: 211 entries, rating to salesRank_sqrt
# dtypes: float64(211)
# memory usage: 205.3+ MB

# %% [markdown]
# **Building the model architecture**

# %% [markdown]
# Now, after defining all of our data, we will finally start to build the architecture.

# %% [markdown]
# In order to build a functional model architecture, I decided to use the pytorch library.
#
# The pytorch library is much lower-level implementation of deep learning models than sklearn, and will be easier to implement my required arcihtecture.

# %% [markdown]
# Import the required pytorch modules:

# %%
import torch
import torch.utils.data
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %% [markdown]
# First, I will start by defining the architecture class.
#
# In pytorch, in this part we define all the network layers, the activation functions, the loss functions, etc.
#
# We will also define a training and validation lists to plot the loss over iterations over the data.

# %%
class NewArchitectureRegression(torch.nn.Module):
    def __init__(self, inputSize, outputSize):
        super(NewArchitectureRegression, self).__init__()
        
        # Hardcoded network architecture as defined:
        
        # First layer, with input size and then 100 neurons
        self.hidden_layer1 = torch.nn.Linear(inputSize, 100)
        
        # Second layer, keep the number of neurons
        self.hidden_layer2 = torch.nn.Linear(100, 100)

        # Last layer, produce the result
        self.output_layer = torch.nn.Linear(100, outputSize)
        
        # put the root in the training function itself
        self.loss_function = torch.nn.MSELoss()
        self.training_loss = []
        self.validation_loss = []
        
    def forward(self, x):
        # Apply the relu function on each layer
        x = F.relu(self.hidden_layer1(x))
        x = F.relu(self.hidden_layer2(x))
        out = self.output_layer(x)
        return out
    
    def reset_loss_values(self):
        self.training_loss = []
        self.validation_loss = []

# %% [markdown]
# Next, in pytorch we need to define a "Data" class, so that we can load our data into our algorithm:

# %%
class Data(torch.utils.data.Dataset):
    def __init__(self, x, y):
        super(Data, self).__init__()
        
        device = 'cuda' if torch.cuda.is_available() else 'cpu'
        
        self.x = torch.as_tensor(x.values, dtype=torch.float, device=device)
        self.y = torch.as_tensor(y.values, dtype=torch.float, device=device)
        
    def __len__(self):
        return self.x.shape[0]
    
    def __getitem__(self, index):
        return self.x[index], self.y[index]

# %% [markdown]
# In order to load the data, we will first split our training data to train and validation data, for fine-tuning later (Section 7)

# %%
X_train, X_val, y_train, y_val = train_test_split(df.drop('rating', axis=1), 
                                                    df['rating'],
                                                    test_size=0.25,
                                                    random_state=42)

# %% [markdown]
# Now, we will load both sets:

# %%
train_dataset = Data(X_train, y_train)
val_dataset = Data(X_val, y_val)

# %% [markdown]
# Now we build the main function that defines the algorithm.
#
# We apply the algorithm according to pytorch documentation, defining both feed-forward and backpropagation.
#
# In this main function, we also set an option to define the number of epoches, the learning rate, and one of three models we will try to optimize the loss:
# 1. Simple gradient descent, noted as "SGD"
# 2. Adagrad optimizer (sgd with momentum), noted as "adagrad"
# 3. Adam optimizer (using the momentum from adagrad, and also using an adaptive learning rate), noted as "adam"

# %%
def train_model(train_dataset,
                val_dataset,
                model,
                defined_optimizer,
                loss_function,
                epochs,
                lr,
                print_loss_values=False,
                print_loss_graph=False):
    
    
    if defined_optimizer == "sgd" or defined_optimizer == "SGD":
        optimizer = torch.optim.SGD(params=model.parameters(), lr=lr)
    elif defined_optimizer == "Adam" or defined_optimizer == "adam":
        optimizer = torch.optim.Adam(params=model.parameters(), lr=lr)
    elif defined_optimizer == "Adagrad" or defined_optimizer == "adagrad":
        optimizer = torch.optim.Adagrad(params=model.parameters(), lr=lr, weight_decay=1e-4)
    
    X_train_torch = train_dataset.x
    y_train_torch = train_dataset.y
    X_val_torch = val_dataset.x
    y_val_torch = val_dataset.y
    
    for epoch in range(epochs):
        
        if print_loss_graph and epoch % 10 == 0:
            print(f"Processing epoch no. {epoch}")
            
        
        # Training Part - Start
        
        model.train()
    
        optimizer.zero_grad()

        train_outputs = model(X_train_torch)

        train_loss = loss_function(train_outputs, y_train_torch)

        train_loss.backward()

        optimizer.step()

        if print_loss_values:
            print("In epoch {}, loss: {}".format(epoch, train_loss.item()))

        model.training_loss.append(np.sqrt(train_loss.item()))
        
        # Training Part - End
        
        # Evaluation Part - Start
        
        model.eval()
        
        val_outputs = model(X_val_torch)
        
        val_loss = loss_function(val_outputs, y_val_torch)
        
        model.validation_loss.append(np.sqrt(val_loss.item()))
        
        # Evaluation Part - End
        
    if print_loss_graph:
        plot_loss(train_loss=model.training_loss, val_loss=model.validation_loss)

# %% [markdown]
# Build a helper function for plotting the loss in the train and validation sets:

# %%
def plot_loss(train_loss, val_loss):
    plt.plot(range(len(train_loss)), train_loss, label="train_error")
    plt.plot(range(len(val_loss)), val_loss, label="val_error")
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.legend()
    plt.show()

# %% [markdown]
# Now we will initialize a model, for the SGD different optimizer:

# %%
deep_nn_model_sgd = NewArchitectureRegression(inputSize=X_train.shape[1], outputSize=1)

# %%
# train the SGD model
train_model(train_dataset=train_dataset, 
            val_dataset=val_dataset,
            model=deep_nn_model_sgd,
            defined_optimizer="sgd",
            loss_function=deep_nn_model_sgd.loss_function,
            epochs=150,
            lr=0.0025, 
            print_loss_values=False,
            print_loss_graph=True)
# Out:
# Processing epoch no. 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-139-e237ca376b0e> in <module>
#       8             lr=0.0025,
#       9             print_loss_values=False,
# ---> 10             print_loss_graph=True)
#
# <ipython-input-136-88cb99c3838e> in train_model(train_dataset, val_dataset, model, defined_optimizer, loss_function, epochs, lr, print_loss_values, print_loss_graph)
#      38         train_loss = loss_function(train_outputs, y_train_torch)
#      39
# ---> 40         train_loss.backward()
#      41
#      42         optimizer.step()
#
# ~\anaconda3\envs\omertorch\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# ~\anaconda3\envs\omertorch\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# RuntimeError: $ Torch: not enough memory: you tried to allocate 33GB. Buy new RAM! at ..\aten\src\TH\THGeneral.cpp:201

# %% [markdown]
# And now we see that we run into a memory problem.
#
# Unfortunately, I wasn't able to solve the memory problem in any way, even after trying many things and digging in the interent for solutions.
#
# In order to not lose all the hard work about the models, I decided to run theצ wiאי a much smaller dataset that will fit my ram (8 GM), but also to try a simpler method, **and apply the linear regression simply with sklearn**

# %%
# Cut only a small part of the train set - that was the maximum set my RAM could handle
train_dataset = Data(X_train[0:30000], y_train[0:30000])

# %% [markdown]
# And now, train the models again:

# %%
# train the SGD model
train_model(train_dataset=train_dataset, 
            val_dataset=val_dataset,
            model=deep_nn_model_sgd,
            defined_optimizer="sgd",
            loss_function=deep_nn_model_sgd.loss_function,
            epochs=150,
            lr=0.0025,
            print_loss_values=False,
            print_loss_graph=True)
# Out:
# Processing epoch no. 0
# Processing epoch no. 10
# Processing epoch no. 20
# Processing epoch no. 30
# Processing epoch no. 40
# Processing epoch no. 50
# Processing epoch no. 60
# Processing epoch no. 70
# Processing epoch no. 80
# Processing epoch no. 90
# Processing epoch no. 100
# Processing epoch no. 110
# Processing epoch no. 120
# Processing epoch no. 130
# Processing epoch no. 140

# %% [markdown]
# Now we can use the validation loss saved in the model object to view it:

# %%
print(f"The validation loss is: {deep_nn_model_sgd.validation_loss[-1]}")
# Out:
# The validation loss is: 1.3762534670391986

# %% [markdown]
# **Not such bad results for such a small amount of the data for our new algorithm!! - RMSE of 1.37**
#
# Our best results yet are with the SVD algorithm alone, getting us RMSE of 1.25.

# %% [markdown]
# We will try to run the other optimizers in the fine-tuning section (Section 7).

# %% [markdown]
# ---

# %% [markdown]
# **Linear regression algorithm**

# %% [markdown]
# Next, we will try to run the linear regression simple algorithm on our hybrid data model.
#
# Implementing linear regression with sklearn is rather simple:

# %%
# import the linear regressions algorithm
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()

# %%
# We try to fit our data on the full dataset (~100,000 example, much more data than our advanced algorithm)
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# import metrices to compute the RMSE
from sklearn.metrics import mean_squared_error

# %%
# now we calculate the RMSE based on the full test (validation) set:
rmse_linear_performance = mean_squared_error(y_true=y_val, 
                                             y_pred=lin_reg.predict(X_val),
                                             squared=False)

# %% [markdown]
# And the RMSE is:

# %%
print(f"The RMSE of the linear regression model is: {rmse_linear_performance}")
# Out:
# The RMSE of the linear regression model is: 1.0844222753330248

# %% [markdown]
# **And finally, we got a huge improvement in our performance again, implementing the SVD with the content metadata gets us RMSE of 1.08!**

# %% [markdown]
# #### Basic training summary

# %% [markdown]
# Now we will summarize our results from training all the algorithms:

# %% [markdown]
# 1. 1.69 RMSE - Default model
# 2. 1.25 RMSE - Baseline model
# 3. 1.38 RMSE - Basic KNN model
# 4. 1.34 RMSE - KNN with mean model
# 5. 1.34 RMSE - KNN with z-score model
# 6. 1.25 RMSE - KNN with baseline model
# 6. 1.26 RMSE - SVD algorithm
# 7. 1.29 RMSE - SVD++ algorithm
# 8. 1.44 RMSE - NMF algorithm
# 9. 1.37 RMSE - Hybrid model, my new deep learning architecture (very partial dataset)
# 10. 1.08 RMSE - Linear regression model (full dataset)

# %% [markdown]
# ## 7 Fine tuning and finding the best models

# %% [markdown]
# In the fine tuning section we will do 2 things:
# 1. Get new data attributes according to our results in the first model training
# 2. Try to train our best performing model with different hyperparameters

# %% [markdown]
# ### 7.1 Set new attributes

# %% [markdown]
# Now, in the attribute settings, we can finally turn back to some of the features we've decided to left over for now:
# 1. Clustering the "bought together" columns to get more insights
# 2. Implement NLP Algorithms on the description itself to create more features

# %% [markdown]
# After many trials and errors, **I've decided to drop these columns and keep them for further research.**
#
# The reason for that is that each implementation with the TF-IDF / CountVectorizer for the text processing, or the clustering based (which is also an NLP processing), **we are left with too many attributes and a huge dataframe.**
#
# By applying this dataframe we cannot use more than a very small portion of the dataset (it does not fit into memory on the hybrid algorithms), and therefore can't get any good results with them.
#
# Therefore, we will keep them for further reaseach and elavorate on this later in the conclusions section (9).

# %% [markdown]
# ### 7.2 Fine tune the best models

# %% [markdown]
# In this section, we will try to get even better results from our best performing algorithms.
#
# We will try to fie tune our best performing models, in that order:
# 1. Linear regression
# 2. My deep learning hybrid architecture
# 3. SVD
# 4. SVD++
# 5. Baseline

# %% [markdown]
# **IMPORTANT NOTE:** After training all the algorithms fast, now we will use a default benchmark for all:
#
# We will use the new dataset that was created for the hybrid model, consisting of 126,959 rows of ratings.
#
# **We will use only those for the train and validation in the following section for consistency**

# %% [markdown]
# #### 7.2.1 Linear regression fine-tuning

# %% [markdown]
# In the linear regression case **there are no hyperparameters to tune in the sklearn implementation.**
#
# If we could, we might've tried to change the learning rate to achieve better results.
#
# Therefore we will **stay with our current result - RMSE of 1.08**

# %% [markdown]
# #### 7.2.2 Deep learning hybrid model fine-tuning

# %% [markdown]
# Here we have some more fine-tuning options. we will try to change:
# 1. The optimization algorithm
# 2. The learning rate
# 3. The number of epochs
#
# We will print the loss graph and the final validation value when we finish the training.

# %% [markdown]
# **Adagrad optimizer**

# %%
deep_nn_model_adagrad = NewArchitectureRegression(inputSize=X_train.shape[1], outputSize=1)

# %%
train_model(train_dataset=train_dataset, 
            val_dataset=val_dataset,
            model=deep_nn_model_adagrad,
            defined_optimizer="adagrad",
            loss_function=deep_nn_model_adagrad.loss_function,
            epochs=150,
            lr=0.0025,
            print_loss_values=False,
            print_loss_graph=True)
# Out:
# Processing epoch no. 0
# Processing epoch no. 10
# Processing epoch no. 20
# Processing epoch no. 30
# Processing epoch no. 40
# Processing epoch no. 50
# Processing epoch no. 60
# Processing epoch no. 70
# Processing epoch no. 80
# Processing epoch no. 90
# Processing epoch no. 100
# Processing epoch no. 110
# Processing epoch no. 120
# Processing epoch no. 130
# Processing epoch no. 140

# %%
print(f"The validation loss is: {deep_nn_model_adagrad.validation_loss[-1]}")
# Out:
# The validation loss is: 1.4477141350724

# %% [markdown]
# The adagrad optimizer seems worse than the SGD - RMSE of 1.44

# %% [markdown]
# **Adam optimizer**

# %%
deep_nn_model_adam = NewArchitectureRegression(inputSize=X_train.shape[1], outputSize=1)

# %%
train_model(train_dataset=train_dataset, 
            val_dataset=val_dataset,
            model=deep_nn_model_adam,
            defined_optimizer="adam",
            loss_function=deep_nn_model_adam.loss_function,
            epochs=150,
            lr=0.0025,
            print_loss_values=False,
            print_loss_graph=True)
# Out:
# Processing epoch no. 0
# Processing epoch no. 10
# Processing epoch no. 20
# Processing epoch no. 30
# Processing epoch no. 40
# Processing epoch no. 50
# Processing epoch no. 60
# Processing epoch no. 70
# Processing epoch no. 80
# Processing epoch no. 90
# Processing epoch no. 100
# Processing epoch no. 110
# Processing epoch no. 120
# Processing epoch no. 130
# Processing epoch no. 140

# %%
print(f"The validation loss is: {deep_nn_model_adam.validation_loss[-1]}")
# Out:
# The validation loss is: 1.2212824308995298

# %% [markdown]
# And here we got a winning model - with the best results so far for the hybrid deep learning model - **RMSE of 1.22**

# %% [markdown]
# **Changing adagrad**

# %% [markdown]
# One more thing that is interesting is the adagrad loss graph - **which does not seem completely flat.**
#
# We will try to train in once again with more epochs:

# %%
deep_nn_model_adagrad_tweak = NewArchitectureRegression(inputSize=X_train.shape[1], outputSize=1)

# %%
train_model(train_dataset=train_dataset, 
            val_dataset=val_dataset,
            model=deep_nn_model_adagrad_tweak,
            defined_optimizer="adagrad",
            loss_function=deep_nn_model_adagrad_tweak.loss_function,
            epochs=200, # more epochs
            lr=0.0025,
            print_loss_values=False,
            print_loss_graph=True)
# Out:
# Processing epoch no. 0
# Processing epoch no. 10
# Processing epoch no. 20
# Processing epoch no. 30
# Processing epoch no. 40
# Processing epoch no. 50
# Processing epoch no. 60
# Processing epoch no. 70
# Processing epoch no. 80
# Processing epoch no. 90
# Processing epoch no. 100
# Processing epoch no. 110
# Processing epoch no. 120
# Processing epoch no. 130
# Processing epoch no. 140
# Processing epoch no. 150
# Processing epoch no. 160
# Processing epoch no. 170
# Processing epoch no. 180
# Processing epoch no. 190

# %%
print(f"The validation loss is: {deep_nn_model_adagrad_tweak.validation_loss[-1]}")
# Out:
# The validation loss is: 1.4163210204078456

# %% [markdown]
# We indeed got an improvement (from 1.44 to 1.41), but the improvement was very small for the number of iterations we added.

# %% [markdown]
# **Changing Adam**

# %% [markdown]
# And now, we will try the adam optimizer one more time with smaller learning rate and more epochs

# %%
deep_nn_model_adam_tweak = NewArchitectureRegression(inputSize=X_train.shape[1], outputSize=1)

# %%
train_model(train_dataset=train_dataset, 
            val_dataset=val_dataset,
            model=deep_nn_model_adam_tweak,
            defined_optimizer="adam",
            loss_function=deep_nn_model_adam_tweak.loss_function,
            epochs=200, # more epochs
            lr=0.001, # smaller learning rate
            print_loss_values=False,
            print_loss_graph=True)
# Out:
# Processing epoch no. 0
# Processing epoch no. 10
# Processing epoch no. 20
# Processing epoch no. 30
# Processing epoch no. 40
# Processing epoch no. 50
# Processing epoch no. 60
# Processing epoch no. 70
# Processing epoch no. 80
# Processing epoch no. 90
# Processing epoch no. 100
# Processing epoch no. 110
# Processing epoch no. 120
# Processing epoch no. 130
# Processing epoch no. 140
# Processing epoch no. 150
# Processing epoch no. 160
# Processing epoch no. 170
# Processing epoch no. 180
# Processing epoch no. 190

# %%
print(f"The validation loss is: {deep_nn_model_adam_tweak.validation_loss[-1]}")
# Out:
# The validation loss is: 1.2263665498336056

# %% [markdown]
# Using more iterations with smaller learning rate **did not help us get the RMSE to a smaller value than what was acheived before.**

# %% [markdown]
# #### 7.2.3 SVD fine-tuning

# %% [markdown]
# Here and in the SVD++ tuning we can change a few parameters:
# 1. n_factors
# 2. epochs
# 3. learning rate
# 4. regularization
#
# We will train all of them using the gridSearch option, and getting only the best parameters out of the options

# %%
from surprise.model_selection import GridSearchCV

# %%
param_grid = {'n_epochs': [10, 20],
              'lr_all': [0.002, 0.005],
              'reg_all': [0.4, 0.6],
              'n_factors': [100, 200]}

# %% [markdown]
# We will load the data to "surprise" class, and then train on it:

# %%
data = Dataset.load_from_df(X_train_hybrid[['user', 'item', 'rating']], reader)

# %%
svd_gs = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=4)

# train on the data
svd_gs.fit(data)

# %% [markdown]
# And the best results on the SVD are:

# %%
print(f"The validation loss is: {svd_gs.best_score['rmse']}")
# Out:
# The validation loss is: 1.1289032460109067

# %% [markdown]
# We got a big improvement from last time!
#
# **The RMSE is reduced from ~1.26 to 1.12** - which is a big improvement.

# %%
# print the parameters for the best results:
svd_gs.best_params['rmse']
# Out:
# {'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0.4, 'n_factors': 100}

# %% [markdown]
# #### 7.2.4 SVD++ fine-tuning

# %% [markdown]
# Now we will implement the same thing on the SVD++ algorithm:

# %%
svdpp_param_grid = {'n_epochs': [10, 20],
                    'lr_all': [0.002, 0.005],
                    'reg_all': [0.4, 0.6],
                    'n_factors': [100, 200]}

# %%
svdpp_gs = GridSearchCV(SVDpp, param_grid, measures=['rmse'], cv=4)

# train on the data
svdpp_gs.fit(data)

# %% [markdown]
# And the best results on the SVD++ are:

# %%
print(f"The validation loss is: {svdpp_gs.best_score['rmse']}")
# Out:
# The validation loss is: 1.1320404331095266

# %% [markdown]
# **We got a much better result than last time (1.29)**, but still not a better result than the regular SVD.

# %%
# print the parameters for the best results:
svd_gs.best_params['rmse']
# Out:
# {'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0.4, 'n_factors': 100}

# %% [markdown]
# #### 7.2.5 Baseline fine-tuning

# %% [markdown]
# There are not many changes we can apply to the baseline algorithm, but we will try to train it a few times with different algorithms and epochs:

# %%
baseline_param_grid = {'bsl_options': {'method': ['als', 'sgd'],
                                       'n_epochs': [10, 20]}
                      }

# %%
baseline_gs = GridSearchCV(BaselineOnly, baseline_param_grid, measures=['rmse'], cv=4)

# train on the data
baseline_gs.fit(data)
# Out:
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...

# %% [markdown]
# And the best results on the baseline are:

# %%
print(f"The validation loss is: {baseline_gs.best_score['rmse']}")
# Out:
# The validation loss is: 1.123446129003872

# %% [markdown]
# Again, a big improvement in results - **to 1.12 RMSE, same as in the SVD algorithm.**

# %%
# print the parameters for the best results:
baseline_gs.best_params['rmse']
# Out:
# {'bsl_options': {'method': 'sgd', 'n_epochs': 20}}

# %% [markdown]
# #### 7.3 Summary of fine tuning results

# %% [markdown]
# And the best models we got, in that order, are:
# 1. 1.08 RMSE - Linear regression (hybrid model data)
# 2. 1.12 RMSE - SVD
# 3. 1.12 RMSE - Baseline model
# 4. 1.13 RMSE - SVD++
# 5. 1.22 RMSE - My deep learning architecture

# %% [markdown]
# ## 8 Final results and presenting the solution

# %% [markdown]
# This part will be divided into 2 sub-sections:
# 1. Getting the final result on the test-set
# 2. Presenting the solution to the management of the company

# %% [markdown]
# ### 8.1 Final results on the test set

# %% [markdown]
# We will choose the best performing model as the winning model to try on the test set. Therefore, our **Linear regression model was chosing for the testing result**
#
# For us to be able to test this model, we need to take the test set and append to it all the data we've added in the hybrid model data preperation part

# %% [markdown]
# Here we encounter a problem - maybe we have users or items that do not have any vector that was calculated on the train set.
#
# In that case, we decided to remove those columns from the test set. **It will make the test set overfit in some way** to the train data, but we have no other option for those users.

# %%
# Save only existing columns in the features dataset
X_test_copy = X_test[X_test['item'].isin(X_train_hybrid['item'])]
X_test_copy = X_test_copy[X_test_copy['user'].isin(X_train_hybrid['user'])]

# %% [markdown]
# And now, we will add those features:

# %%
# set index for the ratings
X_test_copy = X_test_copy.set_index(X_test_copy['user'])

# join the user biases
X_test_copy = X_test_copy.join(users_bias_matrix)

# join the user matrix
X_test_copy = X_test_copy.join(users_matrix)

# set index again
X_test_copy = X_test_copy.set_index(X_test_copy['item'])

# join the item biases
X_test_copy = X_test_copy.join(items_bias_matrix)

# join the item matrix
X_test_copy = X_test_copy.join(items_matrix)

# join the items metadata
X_test_copy = X_test_copy.join(hybrid_metadata_scaled)

# drop unused columns:
X_test_copy_clean = X_test_copy.drop(['user', 'item', 'timestamp'], axis=1)

# %% [markdown]
# And view our new test dataframe:

# %%
X_test_copy_clean
# Out:
#             rating  user_bias  0 u_feature  1 u_feature  2 u_feature  \
# 0700026657     5.0  -0.461895    -0.048258     0.078664     0.113002
# 0700099867     1.0  -0.038024    -0.084400     0.065536     0.108337
# 0700099867     1.0  -0.965118     0.090245     0.314688    -0.039527
# 0700099867     2.0   0.229227     0.077439     0.111579    -0.249326
# 0700099867     5.0  -0.834896    -0.182781    -0.174661    -0.010453
# ...            ...        ...          ...          ...          ...
# B00KAI3KW2     5.0   0.089519    -0.017998     0.024380    -0.046465
# B00KAI3KW2     1.0  -0.178286     0.028175    -0.053768    -0.194040
# B00KAI3KW2     1.0  -0.703204    -0.061102    -0.057317    -0.018659
# B00KAI3KW2     5.0   0.532623    -0.017696     0.138714    -0.103489
# B00L2Q5KWE     5.0  -0.097465     0.084463    -0.085255     0.045071
#
#             3 u_feature  4 u_feature  5 u_feature  6 u_feature  7 u_feature  \
# 0700026657    -0.111592    -0.188237     0.001300    -0.133277    -0.038950
# 0700099867    -0.115074     0.041143    -0.154603     0.172837     0.138656
# 0700099867     0.122442     0.108401     0.227736     0.153903    -0.093880
# 0700099867     0.050833     0.054829     0.148243    -0.165950    -0.123346
# 0700099867     0.053146    -0.011842    -0.256815    -0.139623    -0.003305
# ...                 ...          ...          ...          ...          ...
# B00KAI3KW2    -0.089872    -0.015653     0.054748     0.015059    -0.004106
# B00KAI3KW2     0.116586    -0.019019    -0.215070     0.119276    -0.114832
# B00KAI3KW2     0.067730     0.080961     0.014145     0.058843    -0.163208
# B00KAI3KW2     0.096466     0.026952    -0.043808    -0.092730     0.009704
# B00L2Q5KWE     0.207486    -0.067476    -0.163348     0.038989     0.105809
#
#             ...  98 i_feature  99 i_feature     price  Video Games salesRank  \
# 0700026657  ...     -0.033753      0.074558 -0.014036              -1.115104
# 0700099867  ...      0.116692     -0.014690  3.261130              -1.154814
# 0700099867  ...      0.116692     -0.014690  3.261130              -1.154814
# 0700099867  ...      0.116692     -0.014690  3.261130              -1.154814
# 0700099867  ...      0.116692     -0.014690  3.261130              -1.154814
# ...         ...           ...           ...       ...                    ...
# B00KAI3KW2  ...     -0.315858      0.190892  5.676137              -1.418329
# B00KAI3KW2  ...     -0.315858      0.190892  5.676137              -1.418329
# B00KAI3KW2  ...     -0.315858      0.190892  5.676137              -1.418329
# B00KAI3KW2  ...     -0.315858      0.190892  5.676137              -1.418329
# B00L2Q5KWE  ...      0.045784     -0.051137 -0.101050              -1.413405
#
#             description_length  price_salesRank_mult  price_squared  \
# 0700026657            0.424545             -0.619557      -0.120188
# 0700099867           -0.079716              0.526257       1.636430
# 0700099867           -0.079716              0.526257       1.636430
# 0700099867           -0.079716              0.526257       1.636430
# 0700099867           -0.079716              0.526257       1.636430
# ...                        ...                   ...            ...
# B00KAI3KW2           -0.602619             -1.276497       4.554125
# B00KAI3KW2           -0.602619             -1.276497       4.554125
# B00KAI3KW2           -0.602619             -1.276497       4.554125
# B00KAI3KW2           -0.602619             -1.276497       4.554125
# B00L2Q5KWE           -0.602619             -1.369727      -0.132317
#
#             price_sqrt  salesRank_squared  salesRank_sqrt
# 0700026657    0.247467          -0.711565       -1.271937
# 0700099867    3.170485          -0.717077       -1.357002
# 0700099867    3.170485          -0.717077       -1.357002
# 0700099867    3.170485          -0.717077       -1.357002
# 0700099867    3.170485          -0.717077       -1.357002
# ...                ...                ...             ...
# B00KAI3KW2    4.501179          -0.734213       -2.436805
# B00KAI3KW2    4.501179          -0.734213       -2.436805
# B00KAI3KW2    4.501179          -0.734213       -2.436805
# B00KAI3KW2    4.501179          -0.734213       -2.436805
# B00L2Q5KWE    0.107218          -0.734203       -2.346850
#
# [49281 rows x 211 columns]

# %% [markdown]
# We will split the X and y values for the test:

# %%
X = X_test_copy_clean.drop('rating', axis=1)
y = X_test_copy_clean['rating']

# %% [markdown]
# Now we can finally view **our final RMSE on the test set**:

# %%
mean_squared_error(y_true=y, 
                   y_pred=lin_reg.predict(X),
                   squared=False)
# Out:
# 1.0742931363262707

# %% [markdown]
# ## And our final RMSE is 1.07!
#
# This score is even better from the results on the validation set, and from 2 possible reasons:
# 1. The test set does not consist of users with less then 4 ratings, and therefore is easier to predict the results for them
# 2. We are testing only on users and items with vectors from the validation set - And missing predictions on some users and items.
#
# Therefore, we could say that our RMSE was probably higher if we would include those ideas, but for now we will use this performance measurement.

# %% [markdown]
# ### 8.2 Presenting our solution

# %% [markdown]
# Now, we would like to present our final solution to management.
#
# After thinking about many ways of visualizations, we realized that most graphs will be irrelevant for the managers to get concrete insights from, and we decided on two presenting tools for our solution:
# 1. Feature importance graph with SHAP
# 2. Simple Error distribution to visualize the kind of errors our model does on the test set. Such that we can understand what is the distance between a prediction and its true value

# %% [markdown]
# **Why we decided on these presentation solutions:**
# 1. Getting to know what influences the model will help management understand what is important and what is not in buying decisions
# 2. Interaction with the error is a great indicator for later model training and tweaking, and also for comparing with other categories we have on the store (rather than video games) - we will know what recommender system is better

# %% [markdown]
# #### 8.2.2 SHAP Visualization

# %% [markdown]
# First, we will import and use the SHAP visualization to see which features were the most important ones in predicting our results:

# %%
import shap

# %%
# define a linear explainer
explainer = shap.LinearExplainer(lin_reg, X_train, feature_perturbation='interventional')
# Out:
# The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, or maskers.Impute)

# %%
# save the shap values
shap_values = explainer.shap_values(X_test)

# %% [markdown]
# And finally, plot the SHAP values:

# %%
shap.summary_plot(shap_values, X_test, max_display=15)

# %% [markdown]
# **We get some very interesting results! Some conclusions from looking at the graph**
# 1. The biases were very important features in the model, and even the most important ones. Also, the correlation between the bias value and the model output is positive, which is what we thought we would see.
# 2. salesRank  feature is important only when applied the sqrt formula on him. We can understand from that that the relation between salesRank and rating is not linear - the importance of this feature decreases as the rank increases.
# 3. In general, the 6 most imporant features (or the ones with most influence on the model) where the metadata features (content features) - which might explain why the linear regression work better than the SVD algorithm - it has more important data than the ratings matrix only (that the SVD has).

# %% [markdown]
# #### 8.2.3 Error distribution

# %% [markdown]
# Plotting the error is rather easy when we have our model:

# %%
(lin_reg.predict(X) - y).hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# From this distribution we can see that we have what looks like a normal distribution, but on the other hand - with longer "tail" on the positive side of error: **our model tends to predict higher scores for products than the real value, rather then lower scores.**

# %% [markdown]
# ## 9 Summary, conclusions and further research

# %% [markdown]
# ### 9.1 Summary

# %% [markdown]
# In this project, we've researched the topic of recommendation system with the imagionary use-case of a big corporate that is trying to implement machine learning processes into its day-to-day operations.
#
# We've went through 8 main sections:
# 1. Introduction and explanation about the research
# 2. Framing the problem and the solution
# 3. Get the data
# 4. EDA
# 5. Data preperation
# 6. Model selection and basic model training
# 7. Fine tuning to the best models
# 8. Presenting the solution

# %% [markdown]
# ### 9.2 Main conclusions

# %% [markdown]
# Here I will list my main conclusions from this projects, and I will order my conclusions by topic:
#
# (Most conclusions yet are in each one of the sections above, for example most EDA conclusions are in section 4)

# %% [markdown]
# **Data preprocessing:**
# 1. The train-test split is much more complex in some cases. For example, in our case, when we just started out and split the train-test, we would'nt think that later on we will have a problem with users and items that are unknown to the system, and therefore had to be dropped.
# 2. Stratifying the data might have overfitted us to better results that we didn't realy have - because its easier to predict on users with more ratings.

# %% [markdown]
# **Data preperation:**
# 1. Altough felt not so necessary, the sqrt and squared attributes created were important to the hybrid model, as we saw in the SHAP analysis.
# 2. Many data preperation processes were useless at the end because of memory problems - both text (TF-IDF features) and "bought together" clustering weren't used.

# %% [markdown]
# **EDA:**
# 1. Getting to know the data distribution and characteristics helped us understand future problems and possibilities with the data. E.g. knowing that most items and users have a very small amount of ratings, helped us reduce the dataset later on to fit it on larger algorithms
# 2. Insights about the target value (y) distribution can help us get a better solution without doing much - by simply seeing that the rating distribution is centered around 4.0 and not 3.0 we are able to understand that probably our dataset is wrong, and aimed at users trying to upvote items

# %% [markdown]
# **Model training:**
# 1. "Keep it simple" wins everything - the 2 best algorithms trained were the linear regression and the baseline algorithm - the simplest algorithms of all.
# 2. Yet, my new architecture worked not so bad with a small portion of the data - a more complex architecture and more RAM that could fit more data in might have been able to surpass the simpler algorithms
# 3. Clustering methods (KNN-Based) did not work well as the other algorithms. Another reason for that is that we trained the KNN's on smaller datasets, because of insufficient memory (RAM).

# %% [markdown]
# **Fine-tuning:**
# 1. Fine-tuning helped us improve our models by a relative good portion (10%+ improvement simply by changing hyperparameters and optimizers).
# 2. The fine-tuning helped the complex algorithms more then it helped the simple algorithms. for examples, we've seen a drop from ~1.30 RMSE of the SVD++ to 1.13 RMSE after fine-tuning (yet that fine-tuning itself took more than 1 hour of training...)

# %% [markdown]
# **General conclusions:**
# 1. SHAP analysis should've come before - it could have helped us change and choose even more parameters, if we didn't present it only in the last section of the research.

# %% [markdown]
# ### 9.3 Reflection

# %% [markdown]
# Some short anecdotes by me, after finishing the project:
# 1. I've understood how important it is to keep the data in complete order to avoid confusion. After a few days I realised I have many overlapping datasets holding the same data in different name. Since each dataset is 100MB+, soon my RAM wouldn't be able to train the more complex models, and I had to restart the kernels and load the data each time.
# 2. I've got much more memory problem then I ever expected, and didn't know how to handle them well. It took me much more time than I expected to handle all memory errors. I've had hundreds of kernel reseting and computer crashing because of wrong decisions about loading data to the memory and trying to train too complex methods.
# 3. I understood the exponentialy problem of features - when I wanted in section 7 to finally add the clustering of "bought together" and the NLP features (TF-IDF) I simply understood after planning how to add them that it will be impossible to train on them.
# 4. Completing the data preperation and EDA even before training the first model was a good decision - i've knew the data and my goals well before "throwing" them into a model and hoping for good results. When results came, I knew how to handle them and how to try and find better algorithms and methods, simply because i've knew the data and what else I can try.
# 4. Training many algorithms, fast, first, was a great decision. Instead of trying to fine-tune many different models (which could've taken hours or even days), I've seen that some algorithms are doing poorly (NMF for examples), and others are restricted because of other reasons, memory issues for example (the KNN algorithms)

# %% [markdown]
# ### 9.4 Further Research

# %% [markdown]
# In this section i've included a few ideas for further research:

# %% [markdown]
# 1. Trying to use the ratings time as a feature in a time-sequence model (RNN) - all literature i've found about recommendation system completely ignored the time attribute and found it irrelevant to the task. Yet, a complex model might try to use them for better prediction.
# 2. Handle users with single rated item - since they are very profitable for business. If business could find a way to recommend new users good new items, they might retain them as customers and decrease their customer acquisition cost.
# 3. More accurate results on the test set for unknown users - trying to come up with a method to evalute unknown users in the test set, based on information in the train set.
# 4. The content (items) dataset - the items metadata - contained items images as well. In further research, a CV model can be used on top of these photos to try and extract features from the photos (vector representing the picture), and using those features in the learning process. I didn't do it because of high requirement of processing images and knowledge about this domain I didn't want to enter since that project was already long.
# 5. Using the text (TF-IDF) and bought together clusetring data: I haven't used all metadata because I couldn't fit any more attributes to my RAM. The top features were NLP context (description of the items) and clustering the items bought together for finding similarities between items (also in text representation method).
# 6. Solving the memory problem to implement more complex architectures (like the one I tried to implement), and use more data in them - i've used only a small portion of the data on the deep architecture and the results weren't bad.
# 7. Trying to find more dataset of items purchased and rated by same users - to get more insights about ratings habits and with that getting better predictions for items. For example, looking for users in the video games dataset that rated books or movies as well.

# %% [markdown]
# ### 9.5 References

# %% [markdown]
# 1. [(Book) Hands-On Recommendation Systems with Python](https://www.amazon.com/Hands-Recommendation-Systems-Python-recommendation/dp/1788993756/) - I read this book from start to the end for this project - A great introduction to all types of recommendation systems and algorithms. Yet, most algorithms in this book are implemented from scartch, without the complex algorithms used in this research.
# 2. [(Book) Hands-On Machine Learning with Scikit-Learn](https://www.amazon.com/Hands-Machine-Learning-Scikit-Learn-TensorFlow/dp/1491962291) - Used the appendix (2) of this book and some chapters to orginize my research by sections
# 3. [Koren 2010](https://courses.ischool.berkeley.edu/i290-dm/s11/SECURE/a1-koren.pdf) - Discussing the baseline and neighbour recommendation system methods.
# 4. [Shani and Gunawardana](https://www.bgu.ac.il/~shanigu/Publications/EvaluationMetrics.17.pdf) - Discussion about recommendation methods history and types, and best performance indicators for them.
# 5. [Intro to recommendation systems](https://towardsdatascience.com/introduction-to-recommender-systems-6c66cf15ada) - By Baptiste Rocca, a thorough beginners guide to recommendation system. Much of the pictures were taken from this great article
# 6. Surprise documentation
# 7. SK-Learn documentation
