# %% [markdown]
# # הצעת מחקר לסדנה במדעי הנתונים - עומר חפץ

# %% [markdown]
# ### פרטי המגיש

# %% [markdown]
# שם: עומר חפץ
#
# ת.ז: 208786244

# %% [markdown]
# ### מטרת הפרויקט

# %% [markdown]
# מערכות המלצה הן בעלות פוטנציאל גדול לקדם את המכירות של עסקים ממגוון סוגים. עם זאת, כל מסד נתונים של חברה הוא ייחודי, ודורש התאמות כדי שיגיע לביצועים טובים

# %% [markdown]
# הבעיה אותה אני מעוניין לפתור היא בהינתן דאטה איכותי של חברה, לבנות את מערכת ההמלצה הטובה ביותר בהתבסס על מגוון השיטות הקיימות ועל מחקר של מימוש מערכות המלצה באזרחות

# %% [markdown]
# במילים אחרות, להנגיש למשתמש בלחיצת כפתור את מודל ההמלצות המוצלח ביותר, וכמובן גם את הביצועים שלו

# %% [markdown]
# ### מוטיבציה

# %% [markdown]
# מערכות המלצה הן בעלות ערך אדיר לשוק הפרטי, ומימוש טוב שלהן יכול להביא לפוטנציאל רווחי משמעותי כפי שאנו רואים בחברות הגדולות (נטפליקס, אמזון, ופייסבוק)

# %% [markdown]
# ### הסבר על הדאטה והאתגר הקיים בפרויקט

# %% [markdown]
# על המערכת שתיבנה בפרויקט למצוא את המודל המוצלח ביותר ללא כל היכרות עם כמות וסוגי הפיצ'רים שיעמדו לרשותה.
#
# באופן בסיסי, הדאטה בוודאות יכיל רצפים של דירוגים והמלצות של משתמשים מהשירות - על הימצאות הדאטה זה ניתן לסמוך.
#
# עם זאת, לא ניתן יהיה לדעת מראש את המידע הבא, וזה יהווה האתגר הגדול בפרויקט:
# * מהו המטא-דאטה שמוצמד למוצר או למשתמשים, וכיצד נכון להשתמש בו כדי לקבל תוצאות אופטימליות
# * שימוש בפיצ'רים מבוססי תוכן (NLP)
# * מהי סקאלת הדירוגים האפשרית של המוצר
# * כיצד מתפלג הדאטה בין כמות המשתמשים, כמות המוצרים, וכמות הדירוגים
# * פיצ'רים ייחודיים נוספים? (זמנים? תמונות? שפה כמצוין למעלה?) - כל אחד מהם ידרוש לבנות ארכיטקטורה מורכבת יותר שתכיל כמה רכיבים מבוססי למידת מכונה שמתקשרים האחד עם השני

# %% [markdown]
# ### המקור של הדאטה

# %% [markdown]
# מקור הדאטה במאגרי נתונים אותם איתרתי באינטרנט, אשר מופיעים בפורמטים שונים. חלקם מופיעים בתוך קבצי טקסט, חלק בג'ייסון וחלק כסי-אס-וי (מתנצל על העברית, לא ניתן לשלב עברית ואנגלית בצורה נוחה במחברת). מטרת הפרויקט תהיה לעבוד עם מספר סטים לפחות, ולמצוא את הפתרונות הטובים ביותר והשימוש היעיל ביותר באלגוריתמים.
#
# דוגמה לקישור לדאטה סטים רצויים לפרויקט: https://cseweb.ucsd.edu/~jmcauley/datasets.html
# כאשר המאגרים הרלוונטיים לפרויקט לדוגמה יכולים להיות:
#
# * ביקורות על מוצרי אמזון - מהדאטה סטים הגדולים ביותר במאגר
# * ביקורות על מתכוני בישול
# * מאגר של ביקרות על סרטים שנקרא MovieLens שמשמש גם כסטנדרנט לבחינת ביצועי מנוע וישמש עבורנו כהשוואה לשאר הדברים
# * ביקורות על סוגי בירות שונות
# * וכדומה

# %% [markdown]
# ### הכלים בהם אשתמש

# %% [markdown]
# ממחקר קצר שעשיתי באינטרנט, גיליתי שהעולם של מערכות המלצה הוא רחב במיוחד וקיים בו שימוש במספר גבוה מאוד של אלגוריתמים שונים אפשריים.
#
# מעבר לכך, בניית מערכות מסוג זה מאפשרות חופש גבוה, יצירתיות ודמיון מפותח לטובת שילוב בין שיטות אלגוריתמיות שונות לקבלת הביצועים הטובים ביותר. דוגמה לאלגוריתמים השונים וסוגי הפי'צרים השונים בהם ארצה להשתמש מצורפת פה למטה
#
# הפירוט הבא והחלוקה שעשיתי מבוססת על מחקר שעשיתי בנוגע לשיטות אפשריות לפתרון בעיות במערכות המלצה
# * Content Based Recommendors:
#     * Linear Regression
#     * Neural Networks ( + Deep neural networks)
#     * Metadata Numerical features
#     * Language based Features:
#         * Count Vectorizer Embedding
#         * TF-IDF Embedding
#         * RNN's / Advanced techniques for document embeddings (Possibility)
#     * Similarities Metrices for vector Embeddings:
#         * Cosine similarity
#         * Euclidean distance
#         * Pearson correlation
# * Collaborative Filtering Recommendors:
#     * implementing both user-based CF and item-based CF:
#         * Mean and weighted Mean
#         * Feature based mean
#         * Clustering Algorithms (KNN's, etc)
#     * Model based approaches (Ratings matrix embeddings based on SVD):
#         * SVD-Like
#         * SVD++
#         * NMF
# * Hybrid Methods:
#     * Using both methods described above (Content-based + CF) to improve the results. might try many ideas:
#     * CF model-based approaches (Embeddings) as features in a NN, combined with content-based features
#     * Using content based model and features to cluster the items/users, then use CF algorithm
#
# חלק מהכיוונים שהצעתי למעלה הם כיוונים שחשבתי עליהם וללא אזכור באינטרנט, וכשאתחיל את הפרויקט אעמיק ברוב השיטות שציינתי. יתכן שלחלקן אמצא פירוט מחקרי שנעשה, לחלקן לא, ויכול להיות שאגלה שחלקן לא מתאימות מסיבות כאלו ואחרות. כל זאת ארצה לשלב בפרויקט המחקרי.

# %% [markdown]
# ### ספריות פוטנציאליות

# %% [markdown]
# אשתמש הן בספריות כלליות אשר למדנו במהלך הקורס, והן בספריות פוטנציאליות שיכולות לסייע במימוש האלגוריתמים שקשורים למערכות המלצה:

# %%
import torch
import sklearn
import numpy as np
import pandas as pd
import scipy
## etc...

# %% [markdown]
# ספריות שקשורות למערכות המלצה:

# %%
import surprise
import lenskit
import crab
# and more possibilities like spotlight, lightFM, tensorRec, etc..

# %% [markdown]
# ## תודה רבה!
